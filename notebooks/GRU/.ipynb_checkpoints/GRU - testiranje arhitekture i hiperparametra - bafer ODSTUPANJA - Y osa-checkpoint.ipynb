# %%
import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, SimpleRNN, RNN, LSTM, GRU, SpatialDropout1D, Dropout
# Out:
# WARNING:tensorflow:From D:\Users\mata2\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt
# %matplotlib tk

# %%
import os, os.path, sys

# %%
path = r"C:\Users\mata2\Desktop\master\podaci\0k\Y"

# %%
dir = os.listdir(path)

# %% [markdown]
# Ucitavanje fajlova

# %%
file_names = []
for file in dir:
    file_names.append(file)

# %%
percent_train = 0.8

# %%
percent_val = 0.2

# %%
train_files_names = file_names[:int(percent_train*len(file_names))]
#test_file_names = file_names[int(percent_train*len(file_names))::]

# %% [markdown]
# Ucitavanje zadate koordinate

# %%
y_command = np.asarray(pd.read_csv(r"C:\Users\mata2\Desktop\master\podaci\yCmd.txt",header=None).astype('int'))

# %%
train_ = np.concatenate([pd.read_csv(path + "/" + file, header=None)[:61000].astype('int')
                              for file in train_files_names], axis=0)
# test_ = np.concatenate([pd.read_csv(path + "/" + file, header=None)[:61000].astype('int')
#                               for file in test_file_names], axis=0)

# %%
std_dev = []
with open(r"C:\Users\mata2\Desktop\master\Axis-projection-RNN\odstupanja\0k Y\Y_std_dev.txt", 'r') as lines:
    for line in lines:
        std_dev.append(float(line.strip('\n')))

# %%
sr_vrednost = []
with open(r"C:\Users\mata2\Desktop\master\Axis-projection-RNN\odstupanja\0k Y\Y_sr_vrednost.txt", 'r') as lines:
    for line in lines:
        sr_vrednost.append(float(line.strip('\n')))

# %% [markdown]
# Adekvatno rasporedjivanje podataka kako bi se izbeglo fiktivno stanje

# %%
for j in range(len(train_files_names)):
    exec(f"razlika_trening_{j} = []")
    for i in range(61000):
        exec(f"razlika_trening_{j}.append(y_command[i] - train_[j*61000+i])")
    exec(f'razlika_trening_{j} = np.asarray(razlika_trening_{j})')

# %%
def create_timeseries_split(data, time_steps):

  # Get the number of samples in the data
  num_samples = len(data) - time_steps

  # Create empty arrays to store features and target values
  x_train = np.zeros((num_samples, time_steps, 1))
  y_train = np.zeros((num_samples, 1))

  # Loop through the data and create features and target values
  for i in range(num_samples):
    # Extract a slice of data for the current feature
    x_train[i] = data[i:i+time_steps, :]

    # The target value is the next value after the feature
    y_train[i] = data[i+time_steps, 0]

  return x_train, y_train

# %%
min_kord = [float('inf') for x in range(61000)]
max_kord = [float('-inf') for x in range(61000)]

for i in range(61000):    
    for j in range(len(train_files_names)):
        exec(f'current_file = razlika_trening_{j}')
        if current_file[i][0] < min_kord[i]:
            min_kord[i] = current_file[i][0]
        if current_file[i][0] > max_kord[i]:
            max_kord[i] = current_file[i][0]

# %% [raw]
# time_steps = 10
# input_shape = (time_steps,1)

# %% [raw]
# for i in range(len(train_files_names)):
#     exec(f'train_X_{i}, train_y_{i} = create_timeseries_split(razlika_trening_{i}, time_steps)')
#
# train_X = np.asarray(train_X_0)
# for i in range(1,len(train_files_names)):
#     exec(f'train_X = np.append(train_X, train_X_{i}, axis=0)')
#
# train_y = np.asarray(train_y_0)
# for i in range(1,len(train_files_names)):
#     exec(f'train_y = np.append(train_y, train_y_{i}, axis=0)')

# %% [raw]
# val_x = train_X[-int(len(train_X)*percent_val)-1:-1]
# val_y = train_y[-int(len(train_X)*percent_val)-1:-1]

# %% [raw]
# train_X = train_X[:len(train_X)-val_x.shape[0]]
# train_y = train_y[:len(train_y)-val_x.shape[0]]

# %% [markdown]
# # TESTIRANJE ARHITEKTURE i LR/BATCH

# %% [markdown]
# radjeno u vise iteracija sa razlicitim vrednostima zbog vremenske kompleksnosti

# %%
gru_unit = [8,16]
unit1 = [8,16]
unit2 = [8,16]
batch_size = [128,256]
time_steps_list = [8,10]

# %%
best_skor = float('-inf')
best_gru = None
best_unit1 = None
best_unit2 = None
best_batch = None
best_step = None
for step in time_steps_list:

    #delimo podatke na osnovu velicine buffera
    input_shape = (step,1)

    for i in range(len(train_files_names)):
        exec(f'train_X_{i}, train_y_{i} = create_timeseries_split(razlika_trening_{i}, step)')

    train_X = np.asarray(train_X_0)
    for i in range(1,len(train_files_names)):
        exec(f'train_X = np.append(train_X, train_X_{i}, axis=0)')

    train_y = np.asarray(train_y_0)
    for i in range(1,len(train_files_names)):
        exec(f'train_y = np.append(train_y, train_y_{i}, axis=0)')  

    #uzimamo percent_val sa kraja train_X skupa     
    val_x = train_X[-int(len(train_X)*percent_val)-1:-1]
    val_y = train_y[-int(len(train_X)*percent_val)-1:-1]

    train_X = train_X[:len(train_X)-val_x.shape[0]]
    train_y = train_y[:len(train_y)-val_x.shape[0]]
    
    for batch in batch_size:        
        for gru in gru_unit:
            for uni1 in unit1:
                for uni2 in unit2:

                    keras.utils.set_random_seed(7)
                    optimizerMSE = keras.optimizers.Adam(learning_rate=0.0001)

                    model = Sequential()
                    model.add(GRU(units = gru, input_shape = input_shape, activation = keras.layers.LeakyReLU()))
                    model.add(Dense(units = uni1, activation=keras.layers.LeakyReLU()))
                    model.add(Dense(units = uni2, activation=keras.layers.LeakyReLU()))
                    model.add(Dense(units = 1, activation=keras.layers.LeakyReLU(), bias_initializer='zeros', kernel_initializer='normal'))
                    model.compile(loss='mean_squared_error', optimizer = optimizerMSE)

                    model.fit(train_X, train_y, epochs = 10, batch_size = batch, verbose = 2, shuffle = False)
                    test_predict_MSE = model.predict(val_x)
                    
                    #zato sto smo uzeli 20% od kraja, ne pocinje indeks od samog pocetka rada masine
                    #radimo evaluaciju na mean 3 sigma testu
                    i =(61000-step) - val_x.shape[0]%(61000-step) -1
                    mean_3std = 0
                    for j in range(len(test_predict_MSE)):
                        if i%61000 == 0:
                            i = step
                        if sr_vrednost[i] - 3*std_dev[i] <= test_predict_MSE[j] <= sr_vrednost[i] + 3*std_dev[i]:
                                mean_3std += 1
                        i += 1


                    if mean_3std > best_skor:
                        best_skor = mean_3std
                        best_gru = gru
                        best_unit1 = uni1
                        best_unit2 = uni2
                        best_step = step
                        best_batch = batch

                        print('best_skor: ', best_skor,'best_gru: ', best_gru,'best_unit1: ', best_unit1,'best_unit2: ', best_unit2, 'best_batch', best_batch, 'best_step', best_step)
print('best_skor: ', best_skor)                    
print('best_gru: ', best_gru)
print('best_unit1: ', best_unit1)
print('best_unit2: ', best_unit2)
print('best_batch: ', best_batch)
print('best_step: ', best_step)
# Out:
# Epoch 1/10
# 9149/9149 - 44s - loss: 19.4844 - 44s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 38s - loss: 3.4600 - 38s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 38s - loss: 2.5302 - 38s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 38s - loss: 2.3084 - 38s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 38s - loss: 2.1847 - 38s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 38s - loss: 2.0860 - 38s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 38s - loss: 2.0022 - 38s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 42s - loss: 1.9401 - 42s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 40s - loss: 1.8895 - 40s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 41s - loss: 1.8485 - 41s/epoch - 5ms/step
# 9149/9149 [==============================] - 22s 2ms/step
# best_skor:  277422 best_gru:  8 best_unit1:  8 best_unit2:  8 best_batch 128 best_step 8
# Epoch 1/10
# 9149/9149 - 45s - loss: 19.4802 - 45s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 43s - loss: 3.1745 - 43s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 43s - loss: 2.5044 - 43s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 40s - loss: 2.2803 - 40s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 41s - loss: 2.1449 - 41s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 41s - loss: 2.0511 - 41s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 41s - loss: 1.9814 - 41s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 42s - loss: 1.9170 - 42s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 42s - loss: 1.8654 - 42s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 40s - loss: 1.8289 - 40s/epoch - 4ms/step
# 9149/9149 [==============================] - 21s 2ms/step
# best_skor:  277536 best_gru:  8 best_unit1:  8 best_unit2:  16 best_batch 128 best_step 8
# Epoch 1/10
# 9149/9149 - 50s - loss: 20.3065 - 50s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 42s - loss: 3.3896 - 42s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 41s - loss: 2.7812 - 41s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 42s - loss: 2.5383 - 42s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 43s - loss: 2.3718 - 43s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 41s - loss: 2.2593 - 41s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 41s - loss: 2.1875 - 41s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 41s - loss: 2.1304 - 41s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 41s - loss: 2.0772 - 41s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 40s - loss: 2.0301 - 40s/epoch - 4ms/step
# 9149/9149 [==============================] - 23s 2ms/step
# Epoch 1/10
# 9149/9149 - 47s - loss: 16.2710 - 47s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 39s - loss: 3.1175 - 39s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 36s - loss: 2.5012 - 36s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 34s - loss: 2.2785 - 34s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 34s - loss: 2.1479 - 34s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 34s - loss: 2.0670 - 34s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 35s - loss: 2.0100 - 35s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 38s - loss: 1.9633 - 38s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 34s - loss: 1.9234 - 34s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 38s - loss: 1.8826 - 38s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 9149/9149 - 39s - loss: 12.3631 - 39s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 35s - loss: 2.2998 - 35s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 34s - loss: 2.0086 - 34s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 34s - loss: 1.8677 - 34s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 35s - loss: 1.7802 - 35s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 35s - loss: 1.7153 - 35s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 35s - loss: 1.6540 - 35s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 35s - loss: 1.6006 - 35s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 35s - loss: 1.5569 - 35s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 36s - loss: 1.5205 - 36s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  277698 best_gru:  16 best_unit1:  8 best_unit2:  8 best_batch 128 best_step 8
# Epoch 1/10
# 9149/9149 - 37s - loss: 15.4158 - 37s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 34s - loss: 2.1807 - 34s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 34s - loss: 1.8644 - 34s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 34s - loss: 1.7513 - 34s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 34s - loss: 1.6780 - 34s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 35s - loss: 1.6275 - 35s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 34s - loss: 1.5886 - 34s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 34s - loss: 1.5542 - 34s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 34s - loss: 1.5215 - 34s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 34s - loss: 1.4881 - 34s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 9149/9149 - 37s - loss: 13.3359 - 37s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 34s - loss: 2.1436 - 34s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 34s - loss: 1.9119 - 34s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 34s - loss: 1.7523 - 34s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 34s - loss: 1.6430 - 34s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 34s - loss: 1.5713 - 34s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 34s - loss: 1.5189 - 34s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 34s - loss: 1.4781 - 34s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 34s - loss: 1.4460 - 34s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 34s - loss: 1.4228 - 34s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  277746 best_gru:  16 best_unit1:  16 best_unit2:  8 best_batch 128 best_step 8
# Epoch 1/10
# 9149/9149 - 39s - loss: 11.7919 - 39s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 37s - loss: 2.1131 - 37s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 36s - loss: 1.8894 - 36s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 34s - loss: 1.7575 - 34s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 35s - loss: 1.6677 - 35s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 37s - loss: 1.5976 - 37s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 36s - loss: 1.5504 - 36s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 42s - loss: 1.5115 - 42s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 48s - loss: 1.4770 - 48s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 37s - loss: 1.4430 - 37s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 27s - loss: 25.9170 - 27s/epoch - 6ms/step
# Epoch 2/10
# 4575/4575 - 24s - loss: 5.1462 - 24s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 20s - loss: 3.3110 - 20s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 18s - loss: 2.6280 - 18s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 17s - loss: 2.2951 - 17s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 17s - loss: 2.1381 - 17s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 18s - loss: 2.0494 - 18s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 17s - loss: 1.9811 - 17s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 18s - loss: 1.9192 - 18s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 18s - loss: 1.8645 - 18s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 21s - loss: 26.4520 - 21s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 20s - loss: 4.4574 - 20s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 19s - loss: 2.8613 - 19s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 19s - loss: 2.5015 - 19s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 19s - loss: 2.3551 - 19s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 22s - loss: 2.2607 - 22s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 20s - loss: 2.1839 - 20s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 19s - loss: 2.1215 - 19s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 19s - loss: 2.0617 - 19s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 19s - loss: 2.0113 - 19s/epoch - 4ms/step
# 9149/9149 [==============================] - 18s 2ms/step
# Epoch 1/10
# 4575/4575 - 22s - loss: 27.8708 - 22s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 19s - loss: 4.7550 - 19s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 20s - loss: 3.1478 - 20s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 19s - loss: 2.7042 - 19s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 18s - loss: 2.4946 - 18s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 18s - loss: 2.3420 - 18s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 17s - loss: 2.2251 - 17s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 18s - loss: 2.1382 - 18s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 20s - loss: 2.0679 - 20s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 19s - loss: 2.0125 - 19s/epoch - 4ms/step
# 9149/9149 [==============================] - 19s 2ms/step
# Epoch 1/10
# 4575/4575 - 20s - loss: 22.0909 - 20s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 19s - loss: 3.9330 - 19s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 20s - loss: 2.6698 - 20s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 18s - loss: 2.2733 - 18s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 17s - loss: 2.1296 - 17s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 17s - loss: 2.0528 - 17s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 18s - loss: 2.0023 - 18s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 18s - loss: 1.9637 - 18s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 18s - loss: 1.9326 - 18s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 17s - loss: 1.9058 - 17s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 22s - loss: 17.5959 - 22s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 20s - loss: 2.5394 - 20s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 21s - loss: 2.1198 - 21s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 21s - loss: 1.9356 - 21s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 21s - loss: 1.8300 - 21s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 20s - loss: 1.7559 - 20s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 24s - loss: 1.6910 - 24s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 25s - loss: 1.6332 - 25s/epoch - 6ms/step
# Epoch 9/10
# 4575/4575 - 21s - loss: 1.5876 - 21s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 23s - loss: 1.5556 - 23s/epoch - 5ms/step
# 9149/9149 [==============================] - 18s 2ms/step
# Epoch 1/10
# 4575/4575 - 22s - loss: 21.4862 - 22s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 21s - loss: 2.7515 - 21s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 22s - loss: 1.9757 - 22s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 21s - loss: 1.8430 - 21s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 21s - loss: 1.7647 - 21s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 21s - loss: 1.7048 - 21s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 21s - loss: 1.6558 - 21s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 20s - loss: 1.6139 - 20s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 22s - loss: 1.5801 - 22s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 22s - loss: 1.5499 - 22s/epoch - 5ms/step
# 9149/9149 [==============================] - 19s 2ms/step
# Epoch 1/10
# 4575/4575 - 24s - loss: 18.4890 - 24s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 20s - loss: 2.4193 - 20s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 20s - loss: 2.0849 - 20s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 20s - loss: 1.9692 - 20s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 20s - loss: 1.8907 - 20s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 20s - loss: 1.8284 - 20s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 20s - loss: 1.7716 - 20s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 20s - loss: 1.7204 - 20s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 20s - loss: 1.6771 - 20s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 20s - loss: 1.6378 - 20s/epoch - 4ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 21s - loss: 16.9662 - 21s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 17s - loss: 2.3458 - 17s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 20s - loss: 2.0366 - 20s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 24s - loss: 1.8969 - 24s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 25s - loss: 1.8051 - 25s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 24s - loss: 1.7409 - 24s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 24s - loss: 1.6860 - 24s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 24s - loss: 1.6322 - 24s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 24s - loss: 1.5818 - 24s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 24s - loss: 1.5385 - 24s/epoch - 5ms/step
# 9149/9149 [==============================] - 21s 2ms/step
# Epoch 1/10
# 9149/9149 - 44s - loss: 18.9854 - 44s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 41s - loss: 3.8485 - 41s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 41s - loss: 2.8521 - 41s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 36s - loss: 2.4421 - 36s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 39s - loss: 2.2627 - 39s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 40s - loss: 2.1606 - 40s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 44s - loss: 2.0663 - 44s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 42s - loss: 1.9908 - 42s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 43s - loss: 1.9256 - 43s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 44s - loss: 1.8693 - 44s/epoch - 5ms/step
# 9149/9149 [==============================] - 21s 2ms/step
# best_skor:  286052 best_gru:  8 best_unit1:  8 best_unit2:  8 best_batch 128 best_step 10
# Epoch 1/10
# 9149/9149 - 47s - loss: 19.3711 - 47s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 41s - loss: 3.7456 - 41s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 42s - loss: 2.6964 - 42s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 42s - loss: 2.4097 - 42s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 42s - loss: 2.2647 - 42s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 42s - loss: 2.1570 - 42s/epoch - 5ms/step
# Epoch 7/10
# 9149/9149 - 42s - loss: 2.0834 - 42s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 42s - loss: 2.0200 - 42s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 42s - loss: 1.9561 - 42s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 43s - loss: 1.8937 - 43s/epoch - 5ms/step
# 9149/9149 [==============================] - 24s 3ms/step
# Epoch 1/10
# 9149/9149 - 46s - loss: 21.0027 - 46s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 39s - loss: 3.8650 - 39s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 42s - loss: 2.8798 - 42s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 42s - loss: 2.4245 - 42s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 42s - loss: 2.2579 - 42s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 42s - loss: 2.1495 - 42s/epoch - 5ms/step
# Epoch 7/10
# 9149/9149 - 50s - loss: 2.0861 - 50s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 43s - loss: 2.0415 - 43s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 42s - loss: 2.0038 - 42s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 48s - loss: 1.9681 - 48s/epoch - 5ms/step
# 9149/9149 [==============================] - 21s 2ms/step
# best_skor:  286445 best_gru:  8 best_unit1:  16 best_unit2:  8 best_batch 128 best_step 10
# Epoch 1/10
# 9149/9149 - 47s - loss: 16.0489 - 47s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 42s - loss: 3.1209 - 42s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 43s - loss: 2.2719 - 43s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 50s - loss: 2.0108 - 50s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 41s - loss: 1.8773 - 41s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 43s - loss: 1.7764 - 43s/epoch - 5ms/step
# Epoch 7/10
# 9149/9149 - 43s - loss: 1.7056 - 43s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 42s - loss: 1.6541 - 42s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 42s - loss: 1.6119 - 42s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 42s - loss: 1.5744 - 42s/epoch - 5ms/step
# 9149/9149 [==============================] - 19s 2ms/step
# Epoch 1/10
# 9149/9149 - 43s - loss: 11.8093 - 43s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 38s - loss: 2.4322 - 38s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 43s - loss: 2.0168 - 43s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 42s - loss: 1.8378 - 42s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 47s - loss: 1.7421 - 47s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 48s - loss: 1.6701 - 48s/epoch - 5ms/step
# Epoch 7/10
# 9149/9149 - 47s - loss: 1.6151 - 47s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 46s - loss: 1.5732 - 46s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 47s - loss: 1.5342 - 47s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 47s - loss: 1.4988 - 47s/epoch - 5ms/step
# 9149/9149 [==============================] - 20s 2ms/step
# Epoch 1/10
# 9149/9149 - 53s - loss: 15.4939 - 53s/epoch - 6ms/step
# Epoch 2/10
# 9149/9149 - 43s - loss: 2.3595 - 43s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 46s - loss: 1.7636 - 46s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 46s - loss: 1.6069 - 46s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 44s - loss: 1.5126 - 44s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 41s - loss: 1.4481 - 41s/epoch - 5ms/step
# Epoch 7/10
# 9149/9149 - 42s - loss: 1.4006 - 42s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 41s - loss: 1.3618 - 41s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 41s - loss: 1.3294 - 41s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 45s - loss: 1.3024 - 45s/epoch - 5ms/step
# 9149/9149 [==============================] - 19s 2ms/step
# Epoch 1/10
# 9149/9149 - 45s - loss: 13.6107 - 45s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 42s - loss: 2.4828 - 42s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 41s - loss: 2.0151 - 41s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 41s - loss: 1.8614 - 41s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 41s - loss: 1.7608 - 41s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 41s - loss: 1.6831 - 41s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 42s - loss: 1.6217 - 42s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 41s - loss: 1.5680 - 41s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 43s - loss: 1.5153 - 43s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 45s - loss: 1.4664 - 45s/epoch - 5ms/step
# 9149/9149 [==============================] - 21s 2ms/step
# Epoch 1/10
# 9149/9149 - 46s - loss: 11.8679 - 46s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 43s - loss: 2.1418 - 43s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 41s - loss: 1.9332 - 41s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 43s - loss: 1.7993 - 43s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 42s - loss: 1.6731 - 42s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 45s - loss: 1.5714 - 45s/epoch - 5ms/step
# Epoch 7/10
# 9149/9149 - 45s - loss: 1.4826 - 45s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 43s - loss: 1.4094 - 43s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 44s - loss: 1.3616 - 44s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 54s - loss: 1.3304 - 54s/epoch - 6ms/step
# 9149/9149 [==============================] - 35s 4ms/step
# Epoch 1/10
# 4575/4575 - 26s - loss: 25.2087 - 26s/epoch - 6ms/step
# Epoch 2/10
# 4575/4575 - 21s - loss: 4.7690 - 21s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 21s - loss: 3.0221 - 21s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 22s - loss: 2.5476 - 22s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 22s - loss: 2.2343 - 22s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 23s - loss: 2.1182 - 23s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 17s - loss: 2.0440 - 17s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 16s - loss: 1.9743 - 16s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 17s - loss: 1.9171 - 17s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 20s - loss: 1.8664 - 20s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 19s - loss: 25.8997 - 19s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 16s - loss: 5.1643 - 16s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 16s - loss: 3.2786 - 16s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 2.7213 - 16s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 16s - loss: 2.4447 - 16s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 16s - loss: 2.2829 - 16s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 21s - loss: 2.1680 - 21s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 19s - loss: 2.0762 - 19s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 18s - loss: 2.0113 - 18s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 17s - loss: 1.9626 - 17s/epoch - 4ms/step
# 9149/9149 [==============================] - 21s 2ms/step
# best_skor:  286459 best_gru:  8 best_unit1:  8 best_unit2:  16 best_batch 256 best_step 10
# Epoch 1/10
# 4575/4575 - 20s - loss: 27.7519 - 20s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 17s - loss: 4.8931 - 17s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 19s - loss: 3.2827 - 19s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 21s - loss: 2.9062 - 21s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 21s - loss: 2.6666 - 21s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 21s - loss: 2.4718 - 21s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 23s - loss: 2.2965 - 23s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 22s - loss: 2.1488 - 22s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 22s - loss: 2.0480 - 22s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 21s - loss: 1.9888 - 21s/epoch - 5ms/step
# 9149/9149 [==============================] - 19s 2ms/step
# Epoch 1/10
# 4575/4575 - 25s - loss: 21.7383 - 25s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 22s - loss: 3.9953 - 22s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 22s - loss: 2.6313 - 22s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 22s - loss: 2.2259 - 22s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 22s - loss: 2.0408 - 22s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 21s - loss: 1.9215 - 21s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 20s - loss: 1.8411 - 20s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 21s - loss: 1.7717 - 21s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 22s - loss: 1.7144 - 22s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 23s - loss: 1.6671 - 23s/epoch - 5ms/step
# 9149/9149 [==============================] - 20s 2ms/step
# Epoch 1/10
# 4575/4575 - 26s - loss: 16.6659 - 26s/epoch - 6ms/step
# Epoch 2/10
# 4575/4575 - 25s - loss: 2.9118 - 25s/epoch - 6ms/step
# Epoch 3/10
# 4575/4575 - 25s - loss: 2.3271 - 25s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 25s - loss: 2.0600 - 25s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 26s - loss: 1.9184 - 26s/epoch - 6ms/step
# Epoch 6/10
# 4575/4575 - 26s - loss: 1.8277 - 26s/epoch - 6ms/step
# Epoch 7/10
# 4575/4575 - 25s - loss: 1.7554 - 25s/epoch - 6ms/step
# Epoch 8/10
# 4575/4575 - 26s - loss: 1.6923 - 26s/epoch - 6ms/step
# Epoch 9/10
# 4575/4575 - 26s - loss: 1.6376 - 26s/epoch - 6ms/step
# Epoch 10/10
# 4575/4575 - 25s - loss: 1.5937 - 25s/epoch - 6ms/step
# 9149/9149 [==============================] - 20s 2ms/step
# Epoch 1/10
# 4575/4575 - 28s - loss: 20.9555 - 28s/epoch - 6ms/step
# Epoch 2/10
# 4575/4575 - 26s - loss: 3.6332 - 26s/epoch - 6ms/step
# Epoch 3/10
# 4575/4575 - 26s - loss: 2.2654 - 26s/epoch - 6ms/step
# Epoch 4/10
# 4575/4575 - 25s - loss: 1.9407 - 25s/epoch - 6ms/step
# Epoch 5/10
# 4575/4575 - 25s - loss: 1.7949 - 25s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 24s - loss: 1.7030 - 24s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 24s - loss: 1.6379 - 24s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 24s - loss: 1.5825 - 24s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 28s - loss: 1.5345 - 28s/epoch - 6ms/step
# Epoch 10/10
# 4575/4575 - 27s - loss: 1.4969 - 27s/epoch - 6ms/step
# 9149/9149 [==============================] - 23s 2ms/step
# Epoch 1/10
# 4575/4575 - 33s - loss: 18.3698 - 33s/epoch - 7ms/step
# Epoch 2/10
# 4575/4575 - 26s - loss: 2.9929 - 26s/epoch - 6ms/step
# Epoch 3/10
# 4575/4575 - 26s - loss: 2.1899 - 26s/epoch - 6ms/step
# Epoch 4/10
# 4575/4575 - 25s - loss: 1.9855 - 25s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 25s - loss: 1.8681 - 25s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 26s - loss: 1.7654 - 26s/epoch - 6ms/step
# Epoch 7/10
# 4575/4575 - 25s - loss: 1.6818 - 25s/epoch - 6ms/step
# Epoch 8/10
# 4575/4575 - 26s - loss: 1.6111 - 26s/epoch - 6ms/step
# Epoch 9/10
# 4575/4575 - 24s - loss: 1.5508 - 24s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 25s - loss: 1.5006 - 25s/epoch - 5ms/step
# 9149/9149 [==============================] - 23s 2ms/step
# Epoch 1/10
# 4575/4575 - 28s - loss: 17.1871 - 28s/epoch - 6ms/step
# Epoch 2/10
# 4575/4575 - 25s - loss: 2.8393 - 25s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 25s - loss: 2.2457 - 25s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 24s - loss: 2.0390 - 24s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 25s - loss: 1.9152 - 25s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 25s - loss: 1.8220 - 25s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 26s - loss: 1.7435 - 26s/epoch - 6ms/step
# Epoch 8/10
# 4575/4575 - 26s - loss: 1.6723 - 26s/epoch - 6ms/step
# Epoch 9/10
# 4575/4575 - 25s - loss: 1.6008 - 25s/epoch - 6ms/step
# Epoch 10/10
# 4575/4575 - 26s - loss: 1.5385 - 26s/epoch - 6ms/step
# 9149/9149 [==============================] - 26s 3ms/step
# best_skor:  286459
# best_gru:  8
# best_unit1:  8
# best_unit2:  16
# best_batch:  256
# best_step:  10

# %% [raw]
# MSE:
# best_skor:  286459
# best_gru:  8
# best_unit1:  8
# best_unit2:  16
# best_batch:  256
# best_step:  10
#
# best_skor:  286445 best_gru:  8 best_unit1:  16 best_unit2:  8 best_batch 128 best_step 10
# best_skor:  286459 best_gru:  8 best_unit1:  8 best_unit2:  16 best_batch 256 best_step 10
