# %%
import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, SimpleRNN, RNN, LSTM, GRU, SpatialDropout1D, Dropout

# %%
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt
# %matplotlib tk

# %%
import os, os.path, sys

# %%
path = r"C:\Users\mata2\Desktop\master\podaci\0k\Y"

# %%
dir = os.listdir(path)

# %% [markdown]
# Ucitavanje fajlova

# %%
file_names = []
for file in dir:
    file_names.append(file)

# %%
percent_train = 0.8

# %%
percent_val = 0.2

# %%
train_files_names = file_names[:int(percent_train*len(file_names))]
#test_file_names = file_names[int(percent_train*len(file_names))::]

# %% [markdown]
# Ucitavanje zadate koordinate

# %%
y_command = np.asarray(pd.read_csv(r"C:\Users\mata2\Desktop\master\podaci\yCmd.txt",header=None).astype('int'))

# %%
train_ = np.concatenate([pd.read_csv(path + "/" + file, header=None)[:61000].astype('int')
                              for file in train_files_names], axis=0)
# test_ = np.concatenate([pd.read_csv(path + "/" + file, header=None)[:61000].astype('int')
#                               for file in test_file_names], axis=0)

# %%
std_dev = []
with open(r"C:\Users\mata2\Desktop\master\Axis-projection-RNN\odstupanja\0k Y\Y_std_dev.txt", 'r') as lines:
    for line in lines:
        std_dev.append(float(line.strip('\n')))

# %%
sr_vrednost = []
with open(r"C:\Users\mata2\Desktop\master\Axis-projection-RNN\odstupanja\0k Y\Y_sr_vrednost.txt", 'r') as lines:
    for line in lines:
        sr_vrednost.append(float(line.strip('\n')))

# %% [markdown]
# Adekvatno rasporedjivanje podataka kako bi se izbeglo fiktivno stanje

# %%
for j in range(len(train_files_names)):
    exec(f"koord_trening_{j} = []")
    exec(f"razlika_trening_{j} = []")

    for i in range(61000):
        exec(f"koord_trening_{j}.append(train_[j*61000+i])")
        exec(f"razlika_trening_{j}.append(y_command[i] - train_[j*61000+i])")
    exec(f'koord_trening_{j} = np.asarray(koord_trening_{j})') 
    exec(f'razlika_trening_{j} = np.asarray(razlika_trening_{j})')

# %%
for j in range(len(train_files_names)):
    exec(f"razlika_trening_{j} = []")
    for i in range(61000):
        exec(f"razlika_trening_{j}.append(y_command[i] - train_[j*61000+i])")
    exec(f'razlika_trening_{j} = np.asarray(razlika_trening_{j})')

# %%
def create_timeseries_split(data, time_steps):

    # Get the number of samples in the data
    num_samples = len(data) - time_steps

    # Create empty arrays to store features and target values
    x_train = np.zeros((num_samples, time_steps, 1))
    y_train = np.zeros((num_samples, 1))

    # Loop through the data and create features and target values
    for i in range(num_samples):
        # Extract a slice of data for the current feature
        x_train[i] = data[i:i+time_steps, :]

        # The target value is the next value after the feature
        y_train[i] = data[i+time_steps, 0]

    return x_train, y_train

# %%
min_kord = [float('inf') for x in range(61000)]
max_kord = [float('-inf') for x in range(61000)]

for i in range(61000):    
    for j in range(len(train_files_names)):
        exec(f'current_file = razlika_trening_{j}')
        if current_file[i][0] < min_kord[i]:
            min_kord[i] = current_file[i][0]
        if current_file[i][0] > max_kord[i]:
            max_kord[i] = current_file[i][0]

# %% [markdown]
# # TESTIRANJE ARHITEKTURE i LR/BATCH

# %% [markdown]
# radjeno u vise iteracija sa razlicitim vrednostima zbog vremenske kompleksnosti

# %%
gru_unit = [8,16]
unit1 = [8,16]
unit2 = [8,16]
batch_size = [128,256]
time_steps_list = [8,10]

# %%
best_skor = float('-inf')
best_gru = None
best_unit1 = None
best_unit2 = None
best_batch = None
best_step = None
loop = 0
for step in time_steps_list:

    #delimo podatke na osnovu velicine buffera
    input_shape = (step,1)

    for i in range(len(train_files_names)):
        exec(f'train_koord_X_{i}, _ = create_timeseries_split(koord_trening_{i}, step)')
        
    for i in range(len(train_files_names)):
        exec(f'_, train_y_{i} = create_timeseries_split(razlika_trening_{i}, step)')

    train_X = np.asarray(train_koord_X_0)
    for i in range(1,len(train_files_names)):
        exec(f'train_X = np.append(train_X, train_koord_X_{i}, axis=0)')

    train_y = np.asarray(train_y_0)
    for i in range(1,len(train_files_names)):
        exec(f'train_y = np.append(train_y, train_y_{i}, axis=0)')  

    #uzimamo percent_val sa kraja train_X skupa     
    val_x = train_X[-int(len(train_X)*percent_val)-1:-1]
    val_y = train_y[-int(len(train_X)*percent_val)-1:-1]

    train_X = train_X[:len(train_X)-val_x.shape[0]]
    train_y = train_y[:len(train_y)-val_x.shape[0]]
    
    for batch in batch_size:        
        for gru in gru_unit:
            for uni1 in unit1:
                for uni2 in unit2:

                    keras.utils.set_random_seed(7)
                    optimizerMSE = keras.optimizers.Adam(learning_rate=0.0001)

                    model = Sequential()
                    model.add(GRU(units = gru, input_shape = input_shape, activation = keras.layers.LeakyReLU()))
                    model.add(Dense(units = uni1, activation=keras.layers.LeakyReLU()))
                    model.add(Dense(units = uni2, activation=keras.layers.LeakyReLU()))
                    model.add(Dense(units = 1, activation=keras.layers.LeakyReLU(), bias_initializer='zeros', kernel_initializer='normal'))
                    model.compile(loss='mean_squared_error', optimizer = optimizerMSE)

                    model.fit(train_X, train_y, epochs = 10, batch_size = batch, verbose = 2, shuffle = False)
                    test_predict_MSE = model.predict(val_x)
                    
                    #zato sto smo uzeli 20% od kraja, ne pocinje indeks od samog pocetka rada masine
                    #radimo evaluaciju na mean 3 sigma testu
                    i =(61000-step) - val_x.shape[0]%(61000-step) -1
                    mean_3std = 0
                    for j in range(len(test_predict_MSE)):
                        if i%61000 == 0:
                            i = step
                        if sr_vrednost[i] - 3*std_dev[i] <= test_predict_MSE[j] <= sr_vrednost[i] + 3*std_dev[i]:
                                mean_3std += 1
                        i += 1
                    
                    loop += 1


                    if mean_3std > best_skor:
                        best_skor = mean_3std
                        best_gru = gru
                        best_unit1 = uni1
                        best_unit2 = uni2
                        best_step = step
                        best_batch = batch

                        print('best_skor: ', best_skor,'best_gru: ', best_gru,'best_unit1: ', best_unit1,'best_unit2: ', best_unit2, 'best_batch', best_batch, 'best_step', best_step)
                    
                    print('loop: ', loop)
print('best_skor: ', best_skor)                    
print('best_gru: ', best_gru)
print('best_unit1: ', best_unit1)
print('best_unit2: ', best_unit2)
print('best_batch: ', best_batch)
print('best_step: ', best_step)
# Out:
# WARNING:tensorflow:From D:\Users\mata2\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/10
# WARNING:tensorflow:From D:\Users\mata2\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 9149/9149 - 31s - loss: 473.5802 - 31s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 31s - loss: 53.1784 - 31s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 36s - loss: 100.4205 - 36s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 36s - loss: 51.7865 - 36s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 36s - loss: 51.3491 - 36s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 36s - loss: 51.7690 - 36s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 35s - loss: 60.9303 - 35s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 34s - loss: 50.5704 - 34s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 37s - loss: 61.3538 - 37s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 37s - loss: 50.0866 - 37s/epoch - 4ms/step
# 9149/9149 [==============================] - 18s 2ms/step
# best_skor:  200212 best_gru:  8 best_unit1:  8 best_unit2:  8 best_batch 128 best_step 8
# loop:  1
# Epoch 1/10
# 9149/9149 - 39s - loss: 2780.0847 - 39s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 36s - loss: 57.4666 - 36s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 36s - loss: 55.7210 - 36s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 36s - loss: 53.6895 - 36s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 36s - loss: 53.2793 - 36s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 36s - loss: 52.5466 - 36s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 36s - loss: 51.5483 - 36s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 36s - loss: 51.6628 - 36s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 36s - loss: 50.5136 - 36s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 36s - loss: 49.7012 - 36s/epoch - 4ms/step
# 9149/9149 [==============================] - 18s 2ms/step
# best_skor:  206267 best_gru:  8 best_unit1:  8 best_unit2:  16 best_batch 128 best_step 8
# loop:  2
# Epoch 1/10
# 9149/9149 - 38s - loss: 11511.6299 - 38s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 32s - loss: 50.2683 - 32s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 35s - loss: 49.5834 - 35s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 37s - loss: 47.9680 - 37s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 37s - loss: 47.2866 - 37s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 37s - loss: 47.2008 - 37s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 37s - loss: 47.1346 - 37s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 37s - loss: 47.0976 - 37s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 36s - loss: 47.0540 - 36s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 37s - loss: 47.0242 - 37s/epoch - 4ms/step
# 9149/9149 [==============================] - 18s 2ms/step
# best_skor:  272838 best_gru:  8 best_unit1:  16 best_unit2:  8 best_batch 128 best_step 8
# loop:  3
# Epoch 1/10
# 9149/9149 - 40s - loss: 62.1274 - 40s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 36s - loss: 62.4877 - 36s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 36s - loss: 470.1625 - 36s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 35s - loss: 56.6816 - 35s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 35s - loss: 54.4809 - 35s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 35s - loss: 52.9986 - 35s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 37s - loss: 66.4172 - 37s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 37s - loss: 52.8485 - 37s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 37s - loss: 64.8595 - 37s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 36s - loss: 55.5572 - 36s/epoch - 4ms/step
# 9149/9149 [==============================] - 19s 2ms/step
# loop:  4
# Epoch 1/10
# 9149/9149 - 41s - loss: 434.7021 - 41s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 36s - loss: 79.4862 - 36s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 33s - loss: 66.0707 - 33s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 32s - loss: 52.1306 - 32s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 29s - loss: 50.3529 - 29s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 32s - loss: 63.2539 - 32s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 29s - loss: 48.6254 - 29s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 28s - loss: 47.9538 - 28s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 28s - loss: 47.7877 - 28s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 29s - loss: 50.0628 - 29s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 1ms/step
# loop:  5
# Epoch 1/10
# 9149/9149 - 33s - loss: 335.0943 - 33s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 29s - loss: 53.1547 - 29s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 29s - loss: 52.7286 - 29s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 29s - loss: 51.3500 - 29s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 29s - loss: 50.3071 - 29s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 29s - loss: 51.4662 - 29s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 30s - loss: 49.0097 - 30s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 29s - loss: 47.8557 - 29s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 29s - loss: 47.3161 - 29s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 29s - loss: 46.7321 - 29s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# loop:  6
# Epoch 1/10
# 9149/9149 - 32s - loss: 110.4358 - 32s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 29s - loss: 54.2980 - 29s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 29s - loss: 62.1327 - 29s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 29s - loss: 52.7852 - 29s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 29s - loss: 51.6309 - 29s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 29s - loss: 50.9146 - 29s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 29s - loss: 63.7109 - 29s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 28s - loss: 50.4664 - 28s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 29s - loss: 49.0509 - 29s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 29s - loss: 48.1635 - 29s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# loop:  7
# Epoch 1/10
# 9149/9149 - 32s - loss: 99.0454 - 32s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 29s - loss: 117.0324 - 29s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 28s - loss: 62.0605 - 28s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 28s - loss: 53.6973 - 28s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 28s - loss: 52.7029 - 28s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 28s - loss: 51.1564 - 28s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 28s - loss: 10808.9102 - 28s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 28s - loss: 321.9692 - 28s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 28s - loss: 71.1911 - 28s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 28s - loss: 100.2570 - 28s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 2ms/step
# loop:  8
# Epoch 1/10
# 4575/4575 - 17s - loss: 1125.7242 - 17s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 56.5565 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 444.4026 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 1402.7581 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 51.3565 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 172.8171 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 54.6355 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 55.1235 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 54.0765 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 54.4336 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# loop:  9
# Epoch 1/10
# 4575/4575 - 17s - loss: 6823.0527 - 17s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 57.2432 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 58.2158 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 59.7191 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 60.3597 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 59.4823 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 59.5299 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 57.9986 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 56.7134 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 57.8165 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# loop:  10
# Epoch 1/10
# 4575/4575 - 17s - loss: 24887.3730 - 17s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 49.1754 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 51.8996 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 15s - loss: 52.1117 - 15s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 51.0058 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 49.0028 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 47.9792 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 47.5297 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 47.4370 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 47.4936 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# loop:  11
# Epoch 1/10
# 4575/4575 - 17s - loss: 60.8166 - 17s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 59.8095 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 62.4781 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 87.5149 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 59.7986 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 61.2371 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 61.7898 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 60.9610 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 59.6698 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 59.0810 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# loop:  12
# Epoch 1/10
# 4575/4575 - 18s - loss: 981.7443 - 18s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 16s - loss: 55.7971 - 16s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 16s - loss: 55.2934 - 16s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 486.3817 - 16s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 16s - loss: 53.0958 - 16s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 16s - loss: 53.8797 - 16s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 16s - loss: 54.4994 - 16s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 16s - loss: 54.2806 - 16s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 16s - loss: 114.9927 - 16s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 16s - loss: 77.9855 - 16s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# loop:  13
# Epoch 1/10
# 4575/4575 - 19s - loss: 1344.3911 - 19s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 16s - loss: 58.1674 - 16s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 16s - loss: 57.8589 - 16s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 68.3771 - 16s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 16s - loss: 56.1652 - 16s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 16s - loss: 55.0140 - 16s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 16s - loss: 54.8478 - 16s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 16s - loss: 58.7541 - 16s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 16s - loss: 53.6245 - 16s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 16s - loss: 57.4208 - 16s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 1ms/step
# loop:  14
# Epoch 1/10
# 4575/4575 - 18s - loss: 339.4182 - 18s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 16s - loss: 327.8889 - 16s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 16s - loss: 140.3016 - 16s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 58.1211 - 16s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 16s - loss: 57.8129 - 16s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 16s - loss: 56.0138 - 16s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 16s - loss: 54.2267 - 16s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 16s - loss: 53.4910 - 16s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 16s - loss: 52.6555 - 16s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 16s - loss: 52.0495 - 16s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# best_skor:  273740 best_gru:  16 best_unit1:  16 best_unit2:  8 best_batch 256 best_step 8
# loop:  15
# Epoch 1/10
# 4575/4575 - 18s - loss: 398.6785 - 18s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 16s - loss: 57.0518 - 16s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 16s - loss: 106.4030 - 16s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 67.4622 - 16s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 16s - loss: 51.2416 - 16s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 16s - loss: 53.9945 - 16s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 16s - loss: 53.1042 - 16s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 16s - loss: 51.1921 - 16s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 16s - loss: 53.8043 - 16s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 16s - loss: 52.8539 - 16s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# loop:  16
# Epoch 1/10
# 9149/9149 - 32s - loss: 473.8473 - 32s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 29s - loss: 64.0410 - 29s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 29s - loss: 50.7001 - 29s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 29s - loss: 50.5116 - 29s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 29s - loss: 50.2349 - 29s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 29s - loss: 116.7293 - 29s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 29s - loss: 75.2988 - 29s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 29s - loss: 57.2816 - 29s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 29s - loss: 57.2262 - 29s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 29s - loss: 57.1154 - 29s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 1ms/step
# loop:  17
# Epoch 1/10
# 9149/9149 - 33s - loss: 2782.2471 - 33s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 31s - loss: 58.5274 - 31s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 31s - loss: 57.9391 - 31s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 31s - loss: 57.9012 - 31s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 29s - loss: 55.9835 - 29s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 29s - loss: 53.8792 - 29s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 29s - loss: 53.6148 - 29s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 29s - loss: 53.8872 - 29s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 29s - loss: 50.9591 - 29s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 29s - loss: 50.0534 - 29s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 1ms/step
# loop:  18
# Epoch 1/10
# 9149/9149 - 31s - loss: 11514.8896 - 31s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 29s - loss: 51.6762 - 29s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 29s - loss: 50.2033 - 29s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 29s - loss: 48.3234 - 29s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 29s - loss: 48.2235 - 29s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 31s - loss: 47.4278 - 31s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 32s - loss: 47.1317 - 32s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 31s - loss: 47.4667 - 31s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 31s - loss: 46.9957 - 31s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 30s - loss: 47.1195 - 30s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 1ms/step
# loop:  19
# Epoch 1/10
# 9149/9149 - 33s - loss: 64.2593 - 33s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 30s - loss: 60.6981 - 30s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 29s - loss: 60.0239 - 29s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 29s - loss: 103.8796 - 29s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 29s - loss: 55.4707 - 29s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 29s - loss: 55.4817 - 29s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 29s - loss: 53.7737 - 29s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 29s - loss: 53.2061 - 29s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 29s - loss: 52.0915 - 29s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 29s - loss: 59.0437 - 29s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 1ms/step
# loop:  20
# Epoch 1/10
# 9149/9149 - 35s - loss: 434.0645 - 35s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 32s - loss: 55.6016 - 32s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 32s - loss: 51.3128 - 32s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 32s - loss: 89.5776 - 32s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 33s - loss: 50.4138 - 33s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 34s - loss: 49.6189 - 34s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 37s - loss: 49.1950 - 37s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 33s - loss: 48.5775 - 33s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 31s - loss: 47.7427 - 31s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 33s - loss: 46.6863 - 33s/epoch - 4ms/step
# 9149/9149 [==============================] - 14s 2ms/step
# loop:  21
# Epoch 1/10
# 9149/9149 - 39s - loss: 329.1961 - 39s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 36s - loss: 54.9811 - 36s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 35s - loss: 53.6285 - 35s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 35s - loss: 52.9357 - 35s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 35s - loss: 55.8310 - 35s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 35s - loss: 50.5048 - 35s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 35s - loss: 475.2255 - 35s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 35s - loss: 55.3834 - 35s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 33s - loss: 49.2786 - 33s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 34s - loss: 56.8745 - 34s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# loop:  22
# Epoch 1/10
# 9149/9149 - 41s - loss: 105.3632 - 41s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 35s - loss: 55.5592 - 35s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 34s - loss: 55.2156 - 34s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 34s - loss: 54.2659 - 34s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 34s - loss: 52.4357 - 34s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 34s - loss: 52.1722 - 34s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 34s - loss: 52.6558 - 34s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 35s - loss: 50.9066 - 35s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 36s - loss: 50.0225 - 36s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 36s - loss: 49.0329 - 36s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# loop:  23
# Epoch 1/10
# 9149/9149 - 38s - loss: 93.8845 - 38s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 36s - loss: 58.9107 - 36s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 35s - loss: 59.5316 - 35s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 36s - loss: 56.3312 - 36s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 36s - loss: 50.8578 - 36s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 36s - loss: 50.1461 - 36s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 36s - loss: 49.8899 - 36s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 35s - loss: 49.2143 - 35s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 36s - loss: 48.5529 - 36s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 36s - loss: 49.0709 - 36s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  274206 best_gru:  16 best_unit1:  16 best_unit2:  16 best_batch 128 best_step 10
# loop:  24
# Epoch 1/10
# 4575/4575 - 20s - loss: 1125.8276 - 20s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 18s - loss: 56.5021 - 18s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 18s - loss: 1593.5201 - 18s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 18s - loss: 71.6312 - 18s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 18s - loss: 51.8305 - 18s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 18s - loss: 128.3417 - 18s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 18s - loss: 68.6258 - 18s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 18s - loss: 64.9335 - 18s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 18s - loss: 66.1640 - 18s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 18s - loss: 65.5872 - 18s/epoch - 4ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# loop:  25
# Epoch 1/10
# 4575/4575 - 22s - loss: 6822.9082 - 22s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 18s - loss: 57.2558 - 18s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 18s - loss: 59.1977 - 18s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 18s - loss: 57.3334 - 18s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 18s - loss: 57.2555 - 18s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 18s - loss: 58.4203 - 18s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 18s - loss: 56.0078 - 18s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 19s - loss: 611.5049 - 19s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 18s - loss: 47.6203 - 18s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 18s - loss: 53.2982 - 18s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  274563 best_gru:  8 best_unit1:  8 best_unit2:  16 best_batch 256 best_step 10
# loop:  26
# Epoch 1/10
# 4575/4575 - 21s - loss: 24890.5645 - 21s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 18s - loss: 49.1492 - 18s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 18s - loss: 52.2700 - 18s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 18s - loss: 51.7184 - 18s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 18s - loss: 51.3374 - 18s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 18s - loss: 50.1339 - 18s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 18s - loss: 51.4015 - 18s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 18s - loss: 49.1443 - 18s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 18s - loss: 48.4400 - 18s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 18s - loss: 47.4151 - 18s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# loop:  27
# Epoch 1/10
# 4575/4575 - 20s - loss: 61.4254 - 20s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 18s - loss: 100.6250 - 18s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 18s - loss: 164.1509 - 18s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 18s - loss: 55.5923 - 18s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 18s - loss: 56.0461 - 18s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 18s - loss: 55.3519 - 18s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 18s - loss: 59.4545 - 18s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 18s - loss: 57.0475 - 18s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 18s - loss: 948.6985 - 18s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 21s - loss: 51.0099 - 21s/epoch - 5ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# loop:  28
# Epoch 1/10
# 4575/4575 - 25s - loss: 1156.6743 - 25s/epoch - 6ms/step
# Epoch 2/10
# 4575/4575 - 22s - loss: 72.1383 - 22s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 21s - loss: 371.5795 - 21s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 21s - loss: 51.9465 - 21s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 21s - loss: 53.5737 - 21s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 21s - loss: 52.7244 - 21s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 21s - loss: 51.3388 - 21s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 21s - loss: 159.3572 - 21s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 21s - loss: 51.4172 - 21s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 21s - loss: 56.9769 - 21s/epoch - 5ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# loop:  29
# Epoch 1/10
# 4575/4575 - 23s - loss: 1307.9110 - 23s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 21s - loss: 56.2258 - 21s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 21s - loss: 66.7704 - 21s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 21s - loss: 60.6932 - 21s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 21s - loss: 74.0167 - 21s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 21s - loss: 54.2225 - 21s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 21s - loss: 52.3087 - 21s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 22s - loss: 52.9558 - 22s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 21s - loss: 54.0090 - 21s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 21s - loss: 51.1819 - 21s/epoch - 5ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# loop:  30
# Epoch 1/10
# 4575/4575 - 24s - loss: 509.7208 - 24s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 21s - loss: 1126.9734 - 21s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 21s - loss: 100.0693 - 21s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 21s - loss: 55.3635 - 21s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 21s - loss: 56.0820 - 21s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 21s - loss: 53.7914 - 21s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 21s - loss: 52.7492 - 21s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 20s - loss: 51.6394 - 20s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 20s - loss: 50.6610 - 20s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 20s - loss: 49.0038 - 20s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# loop:  31
# Epoch 1/10
# 4575/4575 - 23s - loss: 226.8479 - 23s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 21s - loss: 82.5161 - 21s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 21s - loss: 58.1811 - 21s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 21s - loss: 56.7281 - 21s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 21s - loss: 69.7813 - 21s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 21s - loss: 56.4809 - 21s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 21s - loss: 58.8613 - 21s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 21s - loss: 56.8791 - 21s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 21s - loss: 57.9719 - 21s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 21s - loss: 57.9627 - 21s/epoch - 5ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# loop:  32
# best_skor:  274563
# best_gru:  8
# best_unit1:  8
# best_unit2:  16
# best_batch:  256
# best_step:  10

# %% [raw]
# best_skor:  274563
# best_gru:  8
# best_unit1:  8
# best_unit2:  16
# best_batch:  256
# best_step:  10
