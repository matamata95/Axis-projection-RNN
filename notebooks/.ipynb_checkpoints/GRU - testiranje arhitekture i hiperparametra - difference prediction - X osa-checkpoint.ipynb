# %%
import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, SimpleRNN, RNN, LSTM, GRU, SpatialDropout1D, Dropout
# Out:
# WARNING:tensorflow:From D:\Users\mata2\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt
# %matplotlib tk

# %%
import os, os.path, sys

# %%
path = r"C:\Users\mata2\Desktop\master\podaci\0k\X"

# %%
dir = os.listdir(path)

# %% [markdown]
# Ucitavanje fajlova

# %%
file_names = []
for file in dir:
    file_names.append(file)

# %%
percent_train = 0.8

# %%
percent_val = 0.2

# %% [markdown]
# Konkatenacija podataka koji se posle koriste za adekvatnu raspodelu na skup za treniranje i validaciju

# %%
train_files_names = file_names[:int(percent_train*len(file_names))]
#test_file_names = file_names[int(percent_train*len(file_names))::]

# %% [markdown]
# Ucitavanje zadate trajektorije

# %%
x_command = np.asarray(pd.read_csv(r"C:\Users\mata2\Desktop\master\podaci\xCmd.txt",header=None).astype('int'))

# %%
train_ = np.concatenate([pd.read_csv(path + "/" + file, header=None)[:61000].astype('int')
                              for file in train_files_names], axis=0)
# test_ = np.concatenate([pd.read_csv(path + "/" + file, header=None)[:61000].astype('int')
#                               for file in test_file_names], axis=0)

# %% [markdown]
# Ucitavanje stadardnih devijacija i strednih vrednosti

# %%
std_dev = []
with open(r"C:\Users\mata2\Desktop\master\Axis-projection-RNN\odstupanja\0k\std_dev.txt", 'r') as lines:
    for line in lines:
        std_dev.append(float(line.strip('\n')))

# %%
sr_vrednost = []
with open(r"C:\Users\mata2\Desktop\master\Axis-projection-RNN\odstupanja\0k\sr_vrednost.txt", 'r') as lines:
    for line in lines:
        sr_vrednost.append(float(line.strip('\n')))

# %% [markdown]
# Raspodela podataka kako bi se izbegla fiktivna stanja

# %%
for j in range(len(train_files_names)):
    exec(f"razlika_trening_{j} = []")
    for i in range(61000):
        exec(f"razlika_trening_{j}.append(x_command[i] - train_[j*61000+i])")
    exec(f'razlika_trening_{j} = np.asarray(razlika_trening_{j})')

# %%
def create_timeseries_split(data, time_steps):

  # Get the number of samples in the data
  num_samples = len(data) - time_steps

  # Create empty arrays to store features and target values
  x_train = np.zeros((num_samples, time_steps, 1))
  y_train = np.zeros((num_samples, 1))

  # Loop through the data and create features and target values
  for i in range(num_samples):
    # Extract a slice of data for the current feature
    x_train[i] = data[i:i+time_steps, :]

    # The target value is the next value after the feature
    y_train[i] = data[i+time_steps, 0]

  return x_train, y_train

# %%
min_kord = [float('inf') for x in range(61000)]
max_kord = [float('-inf') for x in range(61000)]

for i in range(61000):    
    for j in range(len(train_files_names)):
        exec(f'current_file = razlika_trening_{j}')
        if current_file[i][0] < min_kord[i]:
            min_kord[i] = current_file[i][0]
        if current_file[i][0] > max_kord[i]:
            max_kord[i] = current_file[i][0]

# %% [raw]
# time_steps = 10
# input_shape = (time_steps,1)

# %% [raw]
# for i in range(len(train_files_names)):
#     exec(f'train_X_{i}, train_y_{i} = create_timeseries_split(razlika_trening_{i}, time_steps)')
#
# train_X = np.asarray(train_X_0)
# for i in range(1,len(train_files_names)):
#     exec(f'train_X = np.append(train_X, train_X_{i}, axis=0)')
#
# train_y = np.asarray(train_y_0)
# for i in range(1,len(train_files_names)):
#     exec(f'train_y = np.append(train_y, train_y_{i}, axis=0)')

# %% [raw]
# val_x = train_X[-int(len(train_X)*percent_val)-1:-1]
# val_y = train_y[-int(len(train_X)*percent_val)-1:-1]

# %% [raw]
# train_X = train_X[:len(train_X)-val_x.shape[0]]
# train_y = train_y[:len(train_y)-val_x.shape[0]]

# %% [markdown]
# # TESTIRANJE ARHITEKTURE i LR/BATCH

# %% [markdown]
# radjeno u vise iteracija sa razlicitim vrednostima zbog vremenske kompleksnosti

# %%
gru_unit = [8,16]
unit1 = [8,16]
unit2 = [8,16]
batch_size = [128,256]
time_steps_list = [8,10]

# %%
best_skor = float('-inf')
best_gru = None
best_unit1 = None
best_unit2 = None
best_batch = None
best_step = None
for step in time_steps_list:
    
    #delimo podatke na osnovu velicine buffera
    input_shape = (step,1)

    for i in range(len(train_files_names)):
        exec(f'train_X_{i}, train_y_{i} = create_timeseries_split(razlika_trening_{i}, step)')

    train_X = np.asarray(train_X_0)
    for i in range(1,len(train_files_names)):
        exec(f'train_X = np.append(train_X, train_X_{i}, axis=0)')

    train_y = np.asarray(train_y_0)
    for i in range(1,len(train_files_names)):
        exec(f'train_y = np.append(train_y, train_y_{i}, axis=0)')  
    
    #uzimamo percent_val sa kraja train_X skupa 
    val_x = train_X[-int(len(train_X)*percent_val)-1:-1]
    val_y = train_y[-int(len(train_X)*percent_val)-1:-1]

    train_X = train_X[:len(train_X)-val_x.shape[0]]
    train_y = train_y[:len(train_y)-val_x.shape[0]]
    
    for batch in batch_size:        
        for gru in gru_unit:
            for uni1 in unit1:
                for uni2 in unit2:

                    keras.utils.set_random_seed(7)
                    optimizerMSE = keras.optimizers.Adam(learning_rate=0.0001)

                    model = Sequential()
                    model.add(GRU(units = gru, input_shape = input_shape, activation = keras.layers.LeakyReLU()))
                    model.add(Dense(units = uni1, activation=keras.layers.LeakyReLU()))
                    model.add(Dense(units = uni2, activation=keras.layers.LeakyReLU()))
                    model.add(Dense(units = 1, activation=keras.layers.LeakyReLU(), bias_initializer='zeros', kernel_initializer='normal'))
                    model.compile(loss='mean_squared_error', optimizer = optimizerMSE)

                    model.fit(train_X, train_y, epochs = 10, batch_size = batch, verbose = 2, shuffle = False)
                    test_predict_MSE = model.predict(val_x)

                    
                    
                    #zato sto smo uzeli 20% od kraja, ne pocinje indeks od samog pocetka rada masine
                    #radimo evaluaciju na mean 3 sigma testu
                    i =(61000-step) - val_x.shape[0]%(61000-step) -1
                    mean_3std = 0
                    for j in range(len(test_predict_MSE)):
                        if i%61000 == 0:
                            i = step
                        if sr_vrednost[i] - 3*std_dev[i] <= test_predict_MSE[j] <= sr_vrednost[i] + 3*std_dev[i]:
                                mean_3std += 1
                        i += 1

                    
                    
                    if mean_3std > best_skor:
                        best_skor = mean_3std
                        best_gru = gru
                        best_unit1 = uni1
                        best_unit2 = uni2
                        best_step = step
                        best_batch = batch

                        print('best_skor: ', best_skor,'best_gru: ', best_gru,'best_unit1: ', best_unit1,'best_unit2: ', best_unit2, 'best_batch', best_batch, 'best_step', best_step)
print('best_skor: ', best_skor)                    
print('best_gru: ', best_gru)
print('best_unit1: ', best_unit1)
print('best_unit2: ', best_unit2)
print('best_batch: ', best_batch)
print('best_step: ', best_step)
# Out:
# Epoch 1/10
# 9149/9149 - 40s - loss: 13.4045 - 40s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 39s - loss: 3.2870 - 39s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 38s - loss: 2.6907 - 38s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 38s - loss: 2.5524 - 38s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 38s - loss: 2.4731 - 38s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 38s - loss: 2.4179 - 38s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 38s - loss: 2.3775 - 38s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 39s - loss: 2.3436 - 39s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 42s - loss: 2.3171 - 42s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 41s - loss: 2.2922 - 41s/epoch - 4ms/step
# 9149/9149 [==============================] - 25s 3ms/step
# best_skor:  286871 best_gru:  8 best_unit1:  8 best_unit2:  8 best_batch 128 best_step 8
# Epoch 1/10
# 9149/9149 - 44s - loss: 13.8161 - 44s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 41s - loss: 3.4678 - 41s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 43s - loss: 2.7881 - 43s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 42s - loss: 2.5990 - 42s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 40s - loss: 2.5204 - 40s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 41s - loss: 2.4655 - 41s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 41s - loss: 2.4209 - 41s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 42s - loss: 2.3816 - 42s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 42s - loss: 2.3495 - 42s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 41s - loss: 2.3213 - 41s/epoch - 4ms/step
# 9149/9149 [==============================] - 23s 2ms/step
# Epoch 1/10
# 9149/9149 - 47s - loss: 13.9641 - 47s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 43s - loss: 3.3720 - 43s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 41s - loss: 2.7371 - 41s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 42s - loss: 2.5431 - 42s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 43s - loss: 2.4375 - 43s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 42s - loss: 2.3653 - 42s/epoch - 5ms/step
# Epoch 7/10
# 9149/9149 - 41s - loss: 2.3208 - 41s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 42s - loss: 2.2910 - 42s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 41s - loss: 2.2668 - 41s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 41s - loss: 2.2416 - 41s/epoch - 5ms/step
# 9149/9149 [==============================] - 24s 3ms/step
# Epoch 1/10
# 9149/9149 - 45s - loss: 12.1926 - 45s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 42s - loss: 3.1073 - 42s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 35s - loss: 2.6977 - 35s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 36s - loss: 2.5097 - 36s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 34s - loss: 2.3721 - 34s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 34s - loss: 2.2902 - 34s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 34s - loss: 2.2519 - 34s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 38s - loss: 2.2283 - 38s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 35s - loss: 2.2103 - 35s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 37s - loss: 2.1948 - 37s/epoch - 4ms/step
# 9149/9149 [==============================] - 20s 2ms/step
# Epoch 1/10
# 9149/9149 - 38s - loss: 11.2772 - 38s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 35s - loss: 2.9894 - 35s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 35s - loss: 2.5345 - 35s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 35s - loss: 2.3829 - 35s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 35s - loss: 2.3079 - 35s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 35s - loss: 2.2574 - 35s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 35s - loss: 2.2171 - 35s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 35s - loss: 2.1777 - 35s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 35s - loss: 2.1516 - 35s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 35s - loss: 2.1308 - 35s/epoch - 4ms/step
# 9149/9149 [==============================] - 19s 2ms/step
# Epoch 1/10
# 9149/9149 - 38s - loss: 11.4658 - 38s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 35s - loss: 2.8495 - 35s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 35s - loss: 2.3406 - 35s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 34s - loss: 2.2301 - 34s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 34s - loss: 2.1712 - 34s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 34s - loss: 2.1312 - 34s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 34s - loss: 2.1016 - 34s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 34s - loss: 2.0777 - 34s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 34s - loss: 2.0574 - 34s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 34s - loss: 2.0409 - 34s/epoch - 4ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 9149/9149 - 36s - loss: 10.3590 - 36s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 35s - loss: 2.7223 - 35s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 35s - loss: 2.3898 - 35s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 35s - loss: 2.2856 - 35s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 35s - loss: 2.2231 - 35s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 35s - loss: 2.1788 - 35s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 35s - loss: 2.1444 - 35s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 35s - loss: 2.1143 - 35s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 35s - loss: 2.0862 - 35s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 35s - loss: 2.0627 - 35s/epoch - 4ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 9149/9149 - 38s - loss: 9.4315 - 38s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 36s - loss: 2.6438 - 36s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 36s - loss: 2.4180 - 36s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 35s - loss: 2.3051 - 35s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 35s - loss: 2.2266 - 35s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 37s - loss: 2.1744 - 37s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 37s - loss: 2.1344 - 37s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 38s - loss: 2.1071 - 38s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 51s - loss: 2.0846 - 51s/epoch - 6ms/step
# Epoch 10/10
# 9149/9149 - 38s - loss: 2.0677 - 38s/epoch - 4ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 26s - loss: 18.5479 - 26s/epoch - 6ms/step
# Epoch 2/10
# 4575/4575 - 23s - loss: 4.2869 - 23s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 22s - loss: 3.0850 - 22s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 18s - loss: 2.7581 - 18s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 17s - loss: 2.6415 - 17s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 17s - loss: 2.5461 - 17s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 18s - loss: 2.4746 - 18s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 17s - loss: 2.4264 - 17s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 18s - loss: 2.3933 - 18s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 18s - loss: 2.3707 - 18s/epoch - 4ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 22s - loss: 19.1173 - 22s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 20s - loss: 4.3593 - 20s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 20s - loss: 3.1776 - 20s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 19s - loss: 2.7599 - 19s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 19s - loss: 2.6303 - 19s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 22s - loss: 2.5545 - 22s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 20s - loss: 2.4970 - 20s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 19s - loss: 2.4559 - 19s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 19s - loss: 2.4234 - 19s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 20s - loss: 2.3969 - 20s/epoch - 4ms/step
# 9149/9149 [==============================] - 18s 2ms/step
# Epoch 1/10
# 4575/4575 - 23s - loss: 19.2519 - 23s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 20s - loss: 5.1184 - 20s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 20s - loss: 3.1304 - 20s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 19s - loss: 2.8447 - 19s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 19s - loss: 2.6686 - 19s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 19s - loss: 2.5645 - 19s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 18s - loss: 2.4931 - 18s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 19s - loss: 2.4421 - 19s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 21s - loss: 2.4031 - 21s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 20s - loss: 2.3737 - 20s/epoch - 4ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 22s - loss: 16.7913 - 22s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 20s - loss: 3.6280 - 20s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 20s - loss: 2.8752 - 20s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 18s - loss: 2.6989 - 18s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 18s - loss: 2.5768 - 18s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 18s - loss: 2.4666 - 18s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 18s - loss: 2.3922 - 18s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 18s - loss: 2.3454 - 18s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 18s - loss: 2.3149 - 18s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 17s - loss: 2.2906 - 17s/epoch - 4ms/step
# 9149/9149 [==============================] - 14s 2ms/step
# Epoch 1/10
# 4575/4575 - 25s - loss: 15.2875 - 25s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 22s - loss: 4.5621 - 22s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 22s - loss: 3.1398 - 22s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 22s - loss: 2.6051 - 22s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 22s - loss: 2.3956 - 22s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 23s - loss: 2.3197 - 23s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 27s - loss: 2.2723 - 27s/epoch - 6ms/step
# Epoch 8/10
# 4575/4575 - 24s - loss: 2.2366 - 24s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 23s - loss: 2.2087 - 23s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 21s - loss: 2.1811 - 21s/epoch - 5ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 27s - loss: 15.4635 - 27s/epoch - 6ms/step
# Epoch 2/10
# 4575/4575 - 23s - loss: 3.9796 - 23s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 22s - loss: 2.6936 - 22s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 22s - loss: 2.3786 - 22s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 21s - loss: 2.3012 - 21s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 22s - loss: 2.2539 - 22s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 21s - loss: 2.2186 - 21s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 23s - loss: 2.1900 - 23s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 23s - loss: 2.1653 - 23s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 21s - loss: 2.1425 - 21s/epoch - 5ms/step
# 9149/9149 [==============================] - 19s 2ms/step
# best_skor:  286919 best_gru:  16 best_unit1:  8 best_unit2:  16 best_batch 256 best_step 8
# Epoch 1/10
# 4575/4575 - 25s - loss: 14.0045 - 25s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 21s - loss: 3.4218 - 21s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 21s - loss: 2.6030 - 21s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 21s - loss: 2.4240 - 21s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 21s - loss: 2.3369 - 21s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 21s - loss: 2.2845 - 21s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 21s - loss: 2.2447 - 21s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 21s - loss: 2.2117 - 21s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 20s - loss: 2.1823 - 20s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 19s - loss: 2.1578 - 19s/epoch - 4ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 4575/4575 - 24s - loss: 13.0939 - 24s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 24s - loss: 3.0317 - 24s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 26s - loss: 2.5628 - 26s/epoch - 6ms/step
# Epoch 4/10
# 4575/4575 - 25s - loss: 2.4414 - 25s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 25s - loss: 2.3681 - 25s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 25s - loss: 2.3129 - 25s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 25s - loss: 2.2597 - 25s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 24s - loss: 2.2104 - 24s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 22s - loss: 2.1773 - 22s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 23s - loss: 2.1524 - 23s/epoch - 5ms/step
# 9149/9149 [==============================] - 20s 2ms/step
# Epoch 1/10
# 9149/9149 - 48s - loss: 13.4509 - 48s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 40s - loss: 3.4806 - 40s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 37s - loss: 2.7566 - 37s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 43s - loss: 2.5452 - 43s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 42s - loss: 2.4499 - 42s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 45s - loss: 2.3988 - 45s/epoch - 5ms/step
# Epoch 7/10
# 9149/9149 - 43s - loss: 2.3584 - 43s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 45s - loss: 2.3301 - 45s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 43s - loss: 2.3095 - 43s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 41s - loss: 2.2932 - 41s/epoch - 5ms/step
# 9149/9149 [==============================] - 25s 3ms/step
# Epoch 1/10
# 9149/9149 - 47s - loss: 13.9486 - 47s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 42s - loss: 3.8087 - 42s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 42s - loss: 2.8849 - 42s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 43s - loss: 2.6562 - 43s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 42s - loss: 2.5781 - 42s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 43s - loss: 2.5227 - 43s/epoch - 5ms/step
# Epoch 7/10
# 9149/9149 - 42s - loss: 2.4709 - 42s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 43s - loss: 2.4291 - 43s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 43s - loss: 2.3962 - 43s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 42s - loss: 2.3700 - 42s/epoch - 5ms/step
# 9149/9149 [==============================] - 21s 2ms/step
# Epoch 1/10
# 9149/9149 - 46s - loss: 13.9632 - 46s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 42s - loss: 3.4210 - 42s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 43s - loss: 2.6529 - 43s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 42s - loss: 2.4821 - 42s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 49s - loss: 2.4003 - 49s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 45s - loss: 2.3490 - 45s/epoch - 5ms/step
# Epoch 7/10
# 9149/9149 - 42s - loss: 2.3140 - 42s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 48s - loss: 2.2866 - 48s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 40s - loss: 2.2611 - 40s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 44s - loss: 2.2386 - 44s/epoch - 5ms/step
# 9149/9149 [==============================] - 25s 3ms/step
# Epoch 1/10
# 9149/9149 - 47s - loss: 12.1176 - 47s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 49s - loss: 3.1311 - 49s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 43s - loss: 2.6658 - 43s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 43s - loss: 2.4696 - 43s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 44s - loss: 2.3716 - 44s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 43s - loss: 2.3237 - 43s/epoch - 5ms/step
# Epoch 7/10
# 9149/9149 - 43s - loss: 2.2880 - 43s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 43s - loss: 2.2581 - 43s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 36s - loss: 2.2344 - 36s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 40s - loss: 2.2137 - 40s/epoch - 4ms/step
# 9149/9149 [==============================] - 19s 2ms/step
# Epoch 1/10
# 9149/9149 - 47s - loss: 11.5926 - 47s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 43s - loss: 3.1953 - 43s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 48s - loss: 2.5765 - 48s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 49s - loss: 2.4068 - 49s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 47s - loss: 2.3263 - 47s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 46s - loss: 2.2718 - 46s/epoch - 5ms/step
# Epoch 7/10
# 9149/9149 - 48s - loss: 2.2321 - 48s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 48s - loss: 2.1980 - 48s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 42s - loss: 2.1695 - 42s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 48s - loss: 2.1462 - 48s/epoch - 5ms/step
# 9149/9149 [==============================] - 21s 2ms/step
# Epoch 1/10
# 9149/9149 - 53s - loss: 11.3957 - 53s/epoch - 6ms/step
# Epoch 2/10
# 9149/9149 - 49s - loss: 3.1088 - 49s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 44s - loss: 2.5010 - 44s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 42s - loss: 2.3487 - 42s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 43s - loss: 2.2708 - 43s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 42s - loss: 2.2243 - 42s/epoch - 5ms/step
# Epoch 7/10
# 9149/9149 - 43s - loss: 2.1872 - 43s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 45s - loss: 2.1562 - 45s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 41s - loss: 2.1325 - 41s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 42s - loss: 2.1128 - 42s/epoch - 5ms/step
# 9149/9149 [==============================] - 22s 2ms/step
# Epoch 1/10
# 9149/9149 - 47s - loss: 10.4387 - 47s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 42s - loss: 2.9261 - 42s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 42s - loss: 2.4915 - 42s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 43s - loss: 2.3510 - 43s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 42s - loss: 2.2813 - 42s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 44s - loss: 2.2341 - 44s/epoch - 5ms/step
# Epoch 7/10
# 9149/9149 - 45s - loss: 2.1982 - 45s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 42s - loss: 2.1669 - 42s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 43s - loss: 2.1378 - 43s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 44s - loss: 2.1161 - 44s/epoch - 5ms/step
# 9149/9149 [==============================] - 20s 2ms/step
# Epoch 1/10
# 9149/9149 - 49s - loss: 9.3409 - 49s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 44s - loss: 2.7190 - 44s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 47s - loss: 2.4895 - 47s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 46s - loss: 2.3723 - 46s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 44s - loss: 2.2862 - 44s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 45s - loss: 2.2165 - 45s/epoch - 5ms/step
# Epoch 7/10
# 9149/9149 - 56s - loss: 2.1647 - 56s/epoch - 6ms/step
# Epoch 8/10
# 9149/9149 - 54s - loss: 2.1268 - 54s/epoch - 6ms/step
# Epoch 9/10
# 9149/9149 - 44s - loss: 2.0993 - 44s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 46s - loss: 2.0773 - 46s/epoch - 5ms/step
# 9149/9149 [==============================] - 23s 2ms/step
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Cell In[153], line 37
#      34 optimizerMSE = keras.optimizers.Adam(learning_rate=0.0001)
#      36 model = Sequential()
# ---> 37 model.add(GRU(units = gru, input_shape = input_shape, activation = keras.layers.LeakyReLU()))
#      38 model.add(Dense(units = uni1, activation=keras.layers.LeakyReLU()))
#      39 model.add(Dense(units = uni2, activation=keras.layers.LeakyReLU()))
#
# File D:\Users\mata2\anaconda3\Lib\site-packages\tensorflow\python\trackable\base.py:204, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     202 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203 try:
# --> 204   result = method(self, *args, **kwargs)
#     205 finally:
#     206   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File D:\Users\mata2\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File D:\Users\mata2\anaconda3\Lib\site-packages\tensorflow\core\function\capture\capture_container.py:141, in FunctionCaptures.capture_by_value(self, graph, tensor, name)
#     138     return graph_const
#     140   # Large EagerTensors and resources are captured with Placeholder ops
# --> 141   return self._create_placeholder_helper(graph, tensor, name)
#     143 if tensor.graph is not graph:
#     144   graph._validate_in_scope(tensor)  # pylint: disable=protected-access
#
# File D:\Users\mata2\anaconda3\Lib\site-packages\tensorflow\core\function\capture\capture_container.py:285, in FunctionCaptures._create_placeholder_helper(self, graph, tensor, name)
#     279   composite_device_name = None
#     280 placeholder_ctx = trace_type.InternalPlaceholderContext(
#     281     graph,
#     282     with_none_control_dependencies=True,
#     283     composite_device_name=composite_device_name,
#     284 )
# --> 285 placeholder = spec.placeholder_value(placeholder_ctx)
#     286 self.add_or_replace(
#     287     key=id(tensor), external=tensor, internal=placeholder, is_by_ref=False
#     288 )
#     289 graph.inputs.append(placeholder)
#
# File D:\Users\mata2\anaconda3\Lib\site-packages\google\protobuf\internal\python_message.py:801, in _AddStaticMethods.<locals>.FromString(s)
#     799 def FromString(s):
#     800   message = cls()
# --> 801   message.MergeFromString(s)
#     802   return message
#
# File D:\Users\mata2\anaconda3\Lib\site-packages\google\protobuf\internal\python_message.py:1128, in _AddMergeFromStringMethod.<locals>.MergeFromString(self, serialized)
#    1126 length = len(serialized)
#    1127 try:
# -> 1128   if self._InternalParse(serialized, 0, length) != length:
#    1129     # The only reason _InternalParse would return early is if it
#    1130     # encountered an end-group tag.
#    1131     raise message_mod.DecodeError('Unexpected end-group tag.')
#    1132 except (IndexError, TypeError):
#    1133   # Now ord(buf[p:p+1]) == ord('') gets TypeError.
#
# File D:\Users\mata2\anaconda3\Lib\site-packages\google\protobuf\internal\python_message.py:1195, in _AddMergeFromStringMethod.<locals>.InternalParse(self, buffer, pos, end)
#    1193   pos = new_pos
#    1194 else:
# -> 1195   pos = field_decoder(buffer, new_pos, end, self, field_dict)
#    1196   if field_desc:
#    1197     self._UpdateOneofState(field_desc)
#
# File D:\Users\mata2\anaconda3\Lib\site-packages\google\protobuf\internal\decoder.py:584, in StringDecoder.<locals>.DecodeField(buffer, pos, end, message, field_dict)
#     583 def DecodeField(buffer, pos, end, message, field_dict):
# --> 584   (size, pos) = local_DecodeVarint(buffer, pos)
#     585   new_pos = pos + size
#     586   if new_pos > end:
#
# SystemError: Exception encountered when calling layer 'gru_cell' (type GRUCell).
#
# error return without exception set
#
# Call arguments received by layer 'gru_cell' (type GRUCell):
#   • inputs=tf.Tensor(shape=(None, 1), dtype=float32)
#   • states=('tf.Tensor(shape=(None, 8), dtype=float32)',)
#   • training=None

# %% [markdown]
# Zbog greske pri samom kraju testiranja arhitekture (falilo je ~8 modela), nastavljeno je u sledecoj petlji

# %%
gru_unit = [8,16]
unit1 = [8,16]
unit2 = [16]
batch_size = [128,256]
time_steps_list = [10]

# %%
best_skor = float('-inf')
best_gru = None
best_unit1 = None
best_unit2 = None
best_batch = None
best_step = None
for step in time_steps_list:
    
    input_shape = (step,1)

    for i in range(len(train_files_names)):
        exec(f'train_X_{i}, train_y_{i} = create_timeseries_split(razlika_trening_{i}, step)')

    train_X = np.asarray(train_X_0)
    for i in range(1,len(train_files_names)):
        exec(f'train_X = np.append(train_X, train_X_{i}, axis=0)')

    train_y = np.asarray(train_y_0)
    for i in range(1,len(train_files_names)):
        exec(f'train_y = np.append(train_y, train_y_{i}, axis=0)')  
    
    val_x = train_X[-int(len(train_X)*percent_val)-1:-1]
    val_y = train_y[-int(len(train_X)*percent_val)-1:-1]

    train_X = train_X[:len(train_X)-val_x.shape[0]]
    train_y = train_y[:len(train_y)-val_x.shape[0]]
    
    for batch in batch_size:        
        for gru in gru_unit:
            for uni1 in unit1:
                for uni2 in unit2:

                    keras.utils.set_random_seed(7)
                    optimizerMSE = keras.optimizers.Adam(learning_rate=0.0001)

                    model = Sequential()
                    model.add(GRU(units = gru, input_shape = input_shape, activation = keras.layers.LeakyReLU()))
                    model.add(Dense(units = uni1, activation=keras.layers.LeakyReLU()))
                    model.add(Dense(units = uni2, activation=keras.layers.LeakyReLU()))
                    model.add(Dense(units = 1, activation=keras.layers.LeakyReLU(), bias_initializer='zeros', kernel_initializer='normal'))
                    model.compile(loss='mean_squared_error', optimizer = optimizerMSE)

                    model.fit(train_X, train_y, epochs = 10, batch_size = batch, verbose = 2, shuffle = False)
                    test_predict_MSE = model.predict(val_x)

                    
                    
                    #zato sto smo uzeli 20% od kraja, ne pocinje indeks od samog pocetka rada masine
                    i =(61000-step) - val_x.shape[0]%(61000-step) -1
                    mean_3std = 0
                    for j in range(len(test_predict_MSE)):
                        if i%61000 == 0:
                            i = step
                        if sr_vrednost[i] - 3*std_dev[i] <= test_predict_MSE[j] <= sr_vrednost[i] + 3*std_dev[i]:
                                mean_3std += 1
                        i += 1


                    if mean_3std > best_skor:
                        best_skor = mean_3std
                        best_gru = gru
                        best_unit1 = uni1
                        best_unit2 = uni2
                        best_step = step
                        best_batch = batch

                        print('best_skor: ', best_skor,'best_gru: ', best_gru,'best_unit1: ', best_unit1,'best_unit2: ', best_unit2, 'best_batch', best_batch, 'best_step', best_step)
print('best_skor: ', best_skor)                    
print('best_gru: ', best_gru)
print('best_unit1: ', best_unit1)
print('best_unit2: ', best_unit2)
print('best_batch: ', best_batch)
print('best_step: ', best_step)
# Out:
# Epoch 1/10
# 9149/9149 - 44s - loss: 13.9486 - 44s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 43s - loss: 3.8087 - 43s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 44s - loss: 2.8849 - 44s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 41s - loss: 2.6562 - 41s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 39s - loss: 2.5781 - 39s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 43s - loss: 2.5227 - 43s/epoch - 5ms/step
# Epoch 7/10
# 9149/9149 - 43s - loss: 2.4709 - 43s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 40s - loss: 2.4291 - 40s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 41s - loss: 2.3962 - 41s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 43s - loss: 2.3700 - 43s/epoch - 5ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# best_skor:  286255 best_gru:  8 best_unit1:  8 best_unit2:  16 best_batch 128 best_step 10
# Epoch 1/10
# 9149/9149 - 47s - loss: 12.1176 - 47s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 42s - loss: 3.1311 - 42s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 43s - loss: 2.6658 - 43s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 43s - loss: 2.4696 - 43s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 45s - loss: 2.3716 - 45s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 41s - loss: 2.3237 - 41s/epoch - 5ms/step
# Epoch 7/10
# 9149/9149 - 39s - loss: 2.2880 - 39s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 44s - loss: 2.2581 - 44s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 43s - loss: 2.2344 - 43s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 41s - loss: 2.2137 - 41s/epoch - 4ms/step
# 9149/9149 [==============================] - 21s 2ms/step
# Epoch 1/10
# 9149/9149 - 58s - loss: 11.3957 - 58s/epoch - 6ms/step
# Epoch 2/10
# 9149/9149 - 45s - loss: 3.1088 - 45s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 48s - loss: 2.5010 - 48s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 45s - loss: 2.3487 - 45s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 44s - loss: 2.2708 - 44s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 45s - loss: 2.2243 - 45s/epoch - 5ms/step
# Epoch 7/10
# 9149/9149 - 44s - loss: 2.1872 - 44s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 44s - loss: 2.1562 - 44s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 44s - loss: 2.1325 - 44s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 45s - loss: 2.1128 - 45s/epoch - 5ms/step
# 9149/9149 [==============================] - 22s 2ms/step
# Epoch 1/10
# 9149/9149 - 47s - loss: 9.3409 - 47s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 47s - loss: 2.7190 - 47s/epoch - 5ms/step
# Epoch 3/10
# 9149/9149 - 45s - loss: 2.4895 - 45s/epoch - 5ms/step
# Epoch 4/10
# 9149/9149 - 49s - loss: 2.3723 - 49s/epoch - 5ms/step
# Epoch 5/10
# 9149/9149 - 41s - loss: 2.2862 - 41s/epoch - 5ms/step
# Epoch 6/10
# 9149/9149 - 41s - loss: 2.2165 - 41s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 43s - loss: 2.1647 - 43s/epoch - 5ms/step
# Epoch 8/10
# 9149/9149 - 44s - loss: 2.1268 - 44s/epoch - 5ms/step
# Epoch 9/10
# 9149/9149 - 43s - loss: 2.0993 - 43s/epoch - 5ms/step
# Epoch 10/10
# 9149/9149 - 41s - loss: 2.0773 - 41s/epoch - 4ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 4575/4575 - 25s - loss: 19.3654 - 25s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 21s - loss: 4.7754 - 21s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 22s - loss: 3.3429 - 22s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 22s - loss: 2.7922 - 22s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 20s - loss: 2.6166 - 20s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 21s - loss: 2.5494 - 21s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 20s - loss: 2.5039 - 20s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 20s - loss: 2.4661 - 20s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 21s - loss: 2.4330 - 21s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 23s - loss: 2.4049 - 23s/epoch - 5ms/step
# 9149/9149 [==============================] - 18s 2ms/step
# Epoch 1/10
# 4575/4575 - 25s - loss: 16.8213 - 25s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 22s - loss: 3.8313 - 22s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 21s - loss: 3.0248 - 21s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 24s - loss: 2.8031 - 24s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 24s - loss: 2.6707 - 24s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 20s - loss: 2.5566 - 20s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 22s - loss: 2.4633 - 22s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 21s - loss: 2.3985 - 21s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 26s - loss: 2.3527 - 26s/epoch - 6ms/step
# Epoch 10/10
# 4575/4575 - 23s - loss: 2.3154 - 23s/epoch - 5ms/step
# 9149/9149 [==============================] - 18s 2ms/step
# Epoch 1/10
# 4575/4575 - 28s - loss: 15.3990 - 28s/epoch - 6ms/step
# Epoch 2/10
# 4575/4575 - 27s - loss: 4.3247 - 27s/epoch - 6ms/step
# Epoch 3/10
# 4575/4575 - 28s - loss: 2.7648 - 28s/epoch - 6ms/step
# Epoch 4/10
# 4575/4575 - 27s - loss: 2.4106 - 27s/epoch - 6ms/step
# Epoch 5/10
# 4575/4575 - 27s - loss: 2.2951 - 27s/epoch - 6ms/step
# Epoch 6/10
# 4575/4575 - 25s - loss: 2.2327 - 25s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 29s - loss: 2.1946 - 29s/epoch - 6ms/step
# Epoch 8/10
# 4575/4575 - 27s - loss: 2.1674 - 27s/epoch - 6ms/step
# Epoch 9/10
# 4575/4575 - 28s - loss: 2.1459 - 28s/epoch - 6ms/step
# Epoch 10/10
# 4575/4575 - 27s - loss: 2.1275 - 27s/epoch - 6ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 4575/4575 - 30s - loss: 12.9155 - 30s/epoch - 7ms/step
# Epoch 2/10
# 4575/4575 - 28s - loss: 3.1353 - 28s/epoch - 6ms/step
# Epoch 3/10
# 4575/4575 - 29s - loss: 2.6001 - 29s/epoch - 6ms/step
# Epoch 4/10
# 4575/4575 - 26s - loss: 2.4765 - 26s/epoch - 6ms/step
# Epoch 5/10
# 4575/4575 - 25s - loss: 2.3992 - 25s/epoch - 6ms/step
# Epoch 6/10
# 4575/4575 - 25s - loss: 2.3387 - 25s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 31s - loss: 2.2912 - 31s/epoch - 7ms/step
# Epoch 8/10
# 4575/4575 - 24s - loss: 2.2542 - 24s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 25s - loss: 2.2223 - 25s/epoch - 6ms/step
# Epoch 10/10
# 4575/4575 - 24s - loss: 2.1945 - 24s/epoch - 5ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# best_skor:  286255
# best_gru:  8
# best_unit1:  8
# best_unit2:  16
# best_batch:  128
# best_step:  10

# %% [raw]
# best_skor:  231076
# best_gru:  8
# best_unit1:  8
# best_unit2:  16
# best_batch:  128
# best_step:  10
#
# best_skor:  286919 best_gru:  16; best_unit1:  8; best_unit2:  16; best_batch: 256; best_step: 8    - pre errora (odradio je ~24 fali 8)
#
# best_skor:  286255 (posle errora)
# best_gru:  8
# best_unit1:  8
# best_unit2:  16
# best_batch:  128
# best_step:  10
