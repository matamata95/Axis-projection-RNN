# %%
import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input,LeakyReLU, Flatten, MaxPooling1D, Conv1D, MaxPool1D, GlobalMaxPool1D, Dense, AveragePooling1D, GlobalAveragePooling1D
# Out:
# WARNING:tensorflow:From D:\Users\mata2\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt
# %matplotlib tk

# %%
import os, os.path, sys

# %%
path = r"C:\Users\mata2\Desktop\master\podaci\0k\X"

# %%
dir = os.listdir(path)

# %% [markdown]
# Ucitavanje fajlova

# %%
file_names = []
for file in dir:
    file_names.append(file)

# %%
percent_train = 0.8

# %%
percent_val = 0.2

# %% [markdown]
# Konkatenacija podataka koji se posle koriste za adekvatnu raspodelu na skup za treniranje i validaciju

# %%
train_files_names = file_names[:int(percent_train*len(file_names))]
#test_file_names = file_names[int(percent_train*len(file_names))::]

# %% [markdown]
# Ucitavanje zadate trajektorije

# %%
x_command = np.asarray(pd.read_csv(r"C:\Users\mata2\Desktop\master\podaci\xCmd.txt",header=None).astype('int'))

# %%
train_ = np.concatenate([pd.read_csv(path + "/" + file, header=None)[:61000].astype('int')
                              for file in train_files_names], axis=0)
# test_ = np.concatenate([pd.read_csv(path + "/" + file, header=None)[:61000].astype('int')
#                               for file in test_file_names], axis=0)

# %% [markdown]
# Ucitavanje stadardnih devijacija i strednih vrednosti

# %%
std_dev = []
with open(r"C:\Users\mata2\Desktop\master\Axis-projection-RNN\odstupanja\0k\std_dev.txt", 'r') as lines:
    for line in lines:
        std_dev.append(float(line.strip('\n')))

# %%
sr_vrednost = []
with open(r"C:\Users\mata2\Desktop\master\Axis-projection-RNN\odstupanja\0k\sr_vrednost.txt", 'r') as lines:
    for line in lines:
        sr_vrednost.append(float(line.strip('\n')))

# %% [markdown]
# Raspodela podataka kako bi se izbegla fiktivna stanja

# %%
for j in range(len(train_files_names)):
    exec(f"razlika_trening_{j} = []")
    for i in range(len(x_command)):
        exec(f"razlika_trening_{j}.append(x_command[i] - train_[j*len(x_command)+i])")
    exec(f'razlika_trening_{j} = np.asarray(razlika_trening_{j})')

# %%
def create_timeseries_split(data, time_steps):

    # Get the number of samples in the data
    num_samples = len(data) - time_steps

    # Create empty arrays to store features and target values
    x_train = np.zeros((num_samples, time_steps, 1))
    y_train = np.zeros((num_samples, 1))

    # Loop through the data and create features and target values
    for i in range(num_samples):
        # Extract a slice of data for the current feature
        x_train[i] = data[i:i+time_steps, :]

        # The target value is the next value after the feature
        y_train[i] = data[i+time_steps, 0]

    return x_train, y_train

# %%
time_steps = 8
input_shape = (time_steps,1)

# %%
for i in range(len(train_files_names)):
    exec(f'train_X_{i}, train_y_{i} = create_timeseries_split(razlika_trening_{i}, time_steps)')
    
train_X = np.asarray(train_X_0)
for i in range(1,len(train_files_names)):
    exec(f'train_X = np.append(train_X, train_X_{i}, axis=0)')

train_y = np.asarray(train_y_0)
for i in range(1,len(train_files_names)):
    exec(f'train_y = np.append(train_y, train_y_{i}, axis=0)')

# %%
val_x = train_X[-int(len(train_X)*percent_val)-1:-1]
val_y = train_y[-int(len(train_X)*percent_val)-1:-1]

# %%
train_X = train_X[:len(train_X)-val_x.shape[0]]
train_y = train_y[:len(train_y)-val_x.shape[0]]

# %% [markdown]
# # TESTIRANJE ARHITEKTURE i LR/BATCH

# %% [raw]
# keras.utils.set_random_seed(7)
# optimizerMSE = keras.optimizers.Adam(learning_rate=0.0001)
#
# modelMSE = Sequential()
# modelMSE.add(Input(shape=(time_steps, 1)))
# modelMSE.add(Conv1D(filters=32, kernel_size=2,padding='same', activation=LeakyReLU()))
# #modelMSE.add(Conv1D(filters=32, kernel_size=2, activation=LeakyReLU()))
# modelMSE.add(MaxPooling1D(pool_size=3))
# modelMSE.add(Conv1D(filters=64, kernel_size=2,padding='same', activation=LeakyReLU()))
# #modelMSE.add(Conv1D(filters=64, kernel_size=2, activation=LeakyReLU()))
# modelMSE.add(GlobalAveragePooling1D())
# modelMSE.add(Flatten())
# modelMSE.add(Dense(128, activation=LeakyReLU()))
# modelMSE.add(Dense(units = 1, activation=LeakyReLU()))
# modelMSE.compile(loss='mean_squared_error', optimizer = optimizerMSE)

# %% [raw]
# historyMSE = modelMSE.fit(train_X, train_y, epochs=10, batch_size = 256, shuffle=False, verbose = 2)

# %% [raw]
# modelMSE.summary()

# %% [raw]
# test_predict_MSE = modelMSE.predict(val_x)

# %% [raw]
# i =(len(x_command)-time_steps) - val_x.shape[0]%(len(x_command)-time_steps) -1
# mean_3std = 0
# for j in range(len(test_predict_MSE)):
#     if i%len(x_command) == 0:
#         i = time_steps
#     if sr_vrednost[i] - 3*std_dev[i] <= test_predict_MSE[j] <= sr_vrednost[i] + 3*std_dev[i]:
#             mean_3std += 1
#     i += 1
# mean_3std/len(test_predict_MSE)

# %% [raw]
# 0.9884274203189632

# %% [markdown]
# radjeno u vise iteracija sa razlicitim vrednostima zbog vremenske kompleksnosti

# %%
filter_size = [16,32,64]
kernel_size_1 = [3,4]
kernel_size_2 = [3,4]
pooling_size = [3,4]
batch_size = [128,256]
#pool_type = [MaxPooling1D(pool_size = 3),MaxPooling1D(pool_size = 4), AveragePooling1D(pool_size = 3),AveragePooling1D(pool_size = 4)]
#global_pool_type = [GlobalAveragePooling1D(), GlobalMaxPool1D()]
time_steps_list = [8,10]

# %%
best_skor = float('-inf')
best_filter = None
best_kernel_1 = None
best_kernel_2 = None
best_pool = None
best_batch = None
#best_pool_type = None
#best_global_pool_type = None
best_step = None
for step in time_steps_list:
    
    #delimo podatke na osnovu velicine buffera
    input_shape = (step,1)

    for i in range(len(train_files_names)):
        exec(f'train_X_{i}, train_y_{i} = create_timeseries_split(razlika_trening_{i}, step)')

    train_X = np.asarray(train_X_0)
    for i in range(1,len(train_files_names)):
        exec(f'train_X = np.append(train_X, train_X_{i}, axis=0)')

    train_y = np.asarray(train_y_0)
    for i in range(1,len(train_files_names)):
        exec(f'train_y = np.append(train_y, train_y_{i}, axis=0)')  
    
    #uzimamo percent_val sa kraja train_X skupa 
    val_x = train_X[-int(len(train_X)*percent_val)-1:-1]
    val_y = train_y[-int(len(train_X)*percent_val)-1:-1]

    train_X = train_X[:len(train_X)-val_x.shape[0]]
    train_y = train_y[:len(train_y)-val_x.shape[0]]
    
    for batch in batch_size:        
        for filt in filter_size:
            for kernel_1 in kernel_size_1:
                for kernel_2 in kernel_size_2:
                    for pool in pooling_size:
                        keras.utils.set_random_seed(7)
                        optimizerMSE = keras.optimizers.Adam(learning_rate=0.0001)

                        modelMSE = Sequential()
                        modelMSE.add(Input(shape=input_shape))
                        modelMSE.add(Conv1D(filters=filt, kernel_size=kernel_1,padding='same', activation=LeakyReLU()))
                        #modelMSE.add(Conv1D(filters=32, kernel_size=2, activation=LeakyReLU()))
                        modelMSE.add(MaxPooling1D(pool_size=pool))
                        modelMSE.add(Conv1D(filters=filt, kernel_size=kernel_2,padding='same', activation=LeakyReLU()))
                        #modelMSE.add(Conv1D(filters=64, kernel_size=2, activation=LeakyReLU()))
                        modelMSE.add(GlobalAveragePooling1D())
                        modelMSE.add(Flatten())
                        modelMSE.add(Dense(128, activation=LeakyReLU()))
                        modelMSE.add(Dense(units = 1, activation=LeakyReLU()))
                        modelMSE.compile(loss='mean_squared_error', optimizer = optimizerMSE)

                        modelMSE.fit(train_X, train_y, epochs = 10, batch_size = batch, verbose = 2, shuffle = False)
                        test_predict_MSE = modelMSE.predict(val_x)



                        #zato sto smo uzeli 20% od kraja, ne pocinje indeks od samog pocetka rada masine
                        #radimo evaluaciju na mean 3 sigma testu
                        i =(len(x_command)-time_steps) - val_x.shape[0]%(len(x_command)-time_steps) -1
                        mean_3std = 0
                        for j in range(len(test_predict_MSE)):
                            if i%len(x_command) == 0:
                                i = step
                            if sr_vrednost[i] - 3*std_dev[i] <= test_predict_MSE[j] <= sr_vrednost[i] + 3*std_dev[i]:
                                    mean_3std += 1
                            i += 1



                        if mean_3std > best_skor:
                            best_skor = mean_3std
                            best_filter = filt
                            best_kernel_1 = kernel_1
                            best_kernel_2 = kernel_2
                            best_pool = pool
                            best_batch = batch
                            #best_pool_type = ptype
                            #best_global_pool_type = gptype
                            best_step = step

                            print('best_skor: ', best_skor)
                            print('best_filter: ', best_filter)
                            print('best_kernel_1: ', best_kernel_1)
                            print('best_kernel_2: ', best_kernel_2)
                            print('best_batch', best_batch)
                            print('best_step', best_step)
                            print('best_pool', best_pool)
                            #print('best_pool_type', best_pool_type)
                            #print('best_global_pool_type',best_global_pool_type)
                                    
print('best_skor: ', best_skor)
print('best_filter: ', best_filter)
print('best_kernel_1: ', best_kernel_1)
print('best_kernel_2: ', best_kernel_2)
print('best_batch', best_batch)
print('best_step', best_step)
print('best_pool', best_pool)
#print('best_pool_type', best_pool_type)
#print('best_global_pool_type',best_global_pool_type)
# Out:
# Epoch 1/10
# 9149/9149 - 24s - loss: 12.7065 - 24s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 23s - loss: 8.5592 - 23s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 23s - loss: 7.6903 - 23s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 23s - loss: 7.2565 - 23s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 23s - loss: 6.9664 - 23s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 23s - loss: 6.7475 - 23s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 23s - loss: 6.5673 - 23s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 23s - loss: 6.4109 - 23s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 23s - loss: 6.2799 - 23s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 23s - loss: 6.1725 - 23s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  289013
# best_filter:  16
# best_kernel_1:  3
# best_kernel_2:  3
# best_batch 128
# best_step 8
# best_pool 3
# Epoch 1/10
# 9149/9149 - 25s - loss: 9.2969 - 25s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 23s - loss: 4.2920 - 23s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 24s - loss: 3.2638 - 24s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 24s - loss: 2.8803 - 24s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 23s - loss: 2.7281 - 23s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 23s - loss: 2.6426 - 23s/epoch - 2ms/step
# Epoch 7/10
# 9149/9149 - 23s - loss: 2.5833 - 23s/epoch - 2ms/step
# Epoch 8/10
# 9149/9149 - 23s - loss: 2.5348 - 23s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 23s - loss: 2.4898 - 23s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 23s - loss: 2.4500 - 23s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 9149/9149 - 24s - loss: 12.7538 - 24s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 23s - loss: 8.5461 - 23s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 23s - loss: 7.6960 - 23s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 23s - loss: 7.2652 - 23s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 23s - loss: 6.9677 - 23s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 23s - loss: 6.7390 - 23s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 27s - loss: 6.5482 - 27s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 27s - loss: 6.3896 - 27s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 26s - loss: 6.2567 - 26s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 27s - loss: 6.1511 - 27s/epoch - 3ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# best_skor:  289050
# best_filter:  16
# best_kernel_1:  3
# best_kernel_2:  4
# best_batch 128
# best_step 8
# best_pool 3
# Epoch 1/10
# 9149/9149 - 24s - loss: 9.3134 - 24s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 23s - loss: 4.2433 - 23s/epoch - 2ms/step
# Epoch 3/10
# 9149/9149 - 23s - loss: 3.2211 - 23s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 23s - loss: 2.8623 - 23s/epoch - 2ms/step
# Epoch 5/10
# 9149/9149 - 23s - loss: 2.7217 - 23s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 23s - loss: 2.6455 - 23s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 23s - loss: 2.5937 - 23s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 23s - loss: 2.5516 - 23s/epoch - 2ms/step
# Epoch 9/10
# 9149/9149 - 23s - loss: 2.5152 - 23s/epoch - 2ms/step
# Epoch 10/10
# 9149/9149 - 23s - loss: 2.4827 - 23s/epoch - 2ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 9149/9149 - 24s - loss: 8.0797 - 24s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 23s - loss: 3.7269 - 23s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 24s - loss: 3.1601 - 24s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 23s - loss: 2.8287 - 23s/epoch - 2ms/step
# Epoch 5/10
# 9149/9149 - 23s - loss: 2.6273 - 23s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 23s - loss: 2.4973 - 23s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 23s - loss: 2.4093 - 23s/epoch - 2ms/step
# Epoch 8/10
# 9149/9149 - 23s - loss: 2.3476 - 23s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 25s - loss: 2.3044 - 25s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 24s - loss: 2.2703 - 24s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 9149/9149 - 25s - loss: 8.3802 - 25s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 25s - loss: 4.0727 - 25s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 23s - loss: 3.3940 - 23s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 23s - loss: 3.0482 - 23s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 26s - loss: 2.8381 - 26s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 24s - loss: 2.6965 - 24s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 23s - loss: 2.5994 - 23s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 23s - loss: 2.5269 - 23s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 23s - loss: 2.4687 - 23s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 23s - loss: 2.4200 - 23s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 9149/9149 - 24s - loss: 8.1455 - 24s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 23s - loss: 3.7561 - 23s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 23s - loss: 3.1876 - 23s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 24s - loss: 2.8642 - 24s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 23s - loss: 2.6598 - 23s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 23s - loss: 2.5292 - 23s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 23s - loss: 2.4428 - 23s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 23s - loss: 2.3809 - 23s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 23s - loss: 2.3352 - 23s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 23s - loss: 2.2991 - 23s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 9149/9149 - 24s - loss: 8.3950 - 24s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 24s - loss: 3.9893 - 24s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 23s - loss: 3.2948 - 23s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 23s - loss: 3.0063 - 23s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 23s - loss: 2.8331 - 23s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 24s - loss: 2.7143 - 24s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 24s - loss: 2.6172 - 24s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 23s - loss: 2.5388 - 23s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 24s - loss: 2.4753 - 24s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 23s - loss: 2.4220 - 23s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 9149/9149 - 29s - loss: 10.9632 - 29s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 26s - loss: 7.9005 - 26s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 26s - loss: 7.2259 - 26s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 26s - loss: 6.8228 - 26s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 26s - loss: 6.5426 - 26s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 26s - loss: 6.3327 - 26s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 27s - loss: 6.1783 - 27s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 27s - loss: 6.0631 - 27s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 32s - loss: 5.9807 - 32s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 28s - loss: 5.9116 - 28s/epoch - 3ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 9149/9149 - 29s - loss: 7.3413 - 29s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 29s - loss: 3.3767 - 29s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 29s - loss: 2.9358 - 29s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 28s - loss: 2.7605 - 28s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 30s - loss: 2.6466 - 30s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 28s - loss: 2.5692 - 28s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 27s - loss: 2.5073 - 27s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 27s - loss: 2.4544 - 27s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 27s - loss: 2.4158 - 27s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 27s - loss: 2.3805 - 27s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 9149/9149 - 29s - loss: 10.9193 - 29s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 27s - loss: 7.9147 - 27s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 27s - loss: 7.2405 - 27s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 27s - loss: 6.8454 - 27s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 27s - loss: 6.5618 - 27s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 28s - loss: 6.3464 - 28s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 27s - loss: 6.1798 - 27s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 27s - loss: 6.0562 - 27s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 27s - loss: 5.9654 - 27s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 27s - loss: 5.8915 - 27s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 9149/9149 - 28s - loss: 7.3317 - 28s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 26s - loss: 3.3826 - 26s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 26s - loss: 2.9216 - 26s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 26s - loss: 2.7532 - 26s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 26s - loss: 2.6427 - 26s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 26s - loss: 2.5620 - 26s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 27s - loss: 2.4997 - 27s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 26s - loss: 2.4548 - 26s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 26s - loss: 2.4142 - 26s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 27s - loss: 2.3719 - 27s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 9149/9149 - 28s - loss: 7.5573 - 28s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 27s - loss: 3.3873 - 27s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 26s - loss: 2.7432 - 26s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 26s - loss: 2.5047 - 26s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 26s - loss: 2.3887 - 26s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 26s - loss: 2.3172 - 26s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 26s - loss: 2.2653 - 26s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 26s - loss: 2.2265 - 26s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 26s - loss: 2.1961 - 26s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 26s - loss: 2.1685 - 26s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 9149/9149 - 28s - loss: 7.1618 - 28s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 26s - loss: 3.3208 - 26s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 26s - loss: 2.7651 - 26s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 26s - loss: 2.5852 - 26s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 26s - loss: 2.4836 - 26s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 26s - loss: 2.4126 - 26s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 26s - loss: 2.3632 - 26s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 26s - loss: 2.3258 - 26s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 26s - loss: 2.2933 - 26s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 26s - loss: 2.2635 - 26s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 9149/9149 - 27s - loss: 7.5524 - 27s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 26s - loss: 3.3961 - 26s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 26s - loss: 2.7624 - 26s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 26s - loss: 2.5181 - 26s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 26s - loss: 2.3959 - 26s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 26s - loss: 2.3202 - 26s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 26s - loss: 2.2680 - 26s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 26s - loss: 2.2286 - 26s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 26s - loss: 2.1969 - 26s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 26s - loss: 2.1688 - 26s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 9149/9149 - 28s - loss: 7.1727 - 28s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 26s - loss: 3.3100 - 26s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 26s - loss: 2.7541 - 26s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 26s - loss: 2.5849 - 26s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 26s - loss: 2.4787 - 26s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 26s - loss: 2.4048 - 26s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 26s - loss: 2.3558 - 26s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 26s - loss: 2.3155 - 26s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 26s - loss: 2.2798 - 26s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 26s - loss: 2.2533 - 26s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 9149/9149 - 31s - loss: 9.9928 - 31s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 30s - loss: 7.5756 - 30s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 30s - loss: 6.9206 - 30s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 30s - loss: 6.5036 - 30s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 30s - loss: 6.2306 - 30s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 30s - loss: 6.0557 - 30s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 31s - loss: 5.9270 - 31s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 30s - loss: 5.8378 - 30s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 30s - loss: 5.7585 - 30s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 30s - loss: 5.6974 - 30s/epoch - 3ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# best_skor:  289068
# best_filter:  64
# best_kernel_1:  3
# best_kernel_2:  3
# best_batch 128
# best_step 8
# best_pool 3
# Epoch 1/10
# 9149/9149 - 32s - loss: 6.2713 - 32s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 31s - loss: 3.1780 - 31s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 31s - loss: 2.8556 - 31s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 31s - loss: 2.6798 - 31s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 31s - loss: 2.5754 - 31s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 31s - loss: 2.4959 - 31s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 31s - loss: 2.4290 - 31s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 31s - loss: 2.3821 - 31s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 31s - loss: 2.3392 - 31s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 31s - loss: 2.3019 - 31s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 9149/9149 - 32s - loss: 9.9962 - 32s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 31s - loss: 7.5759 - 31s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 31s - loss: 6.9002 - 31s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 30s - loss: 6.4781 - 30s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 30s - loss: 6.2164 - 30s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 30s - loss: 6.0549 - 30s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 31s - loss: 5.9339 - 31s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 30s - loss: 5.8390 - 30s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 30s - loss: 5.7625 - 30s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 30s - loss: 5.7029 - 30s/epoch - 3ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# best_skor:  289096
# best_filter:  64
# best_kernel_1:  3
# best_kernel_2:  4
# best_batch 128
# best_step 8
# best_pool 3
# Epoch 1/10
# 9149/9149 - 32s - loss: 6.2471 - 32s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 30s - loss: 3.2028 - 30s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 30s - loss: 2.8888 - 30s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 31s - loss: 2.7171 - 31s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 30s - loss: 2.6011 - 30s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 30s - loss: 2.5205 - 30s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 30s - loss: 2.4502 - 30s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 30s - loss: 2.3983 - 30s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 30s - loss: 2.3481 - 30s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 30s - loss: 2.3145 - 30s/epoch - 3ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 9149/9149 - 31s - loss: 5.8123 - 31s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 30s - loss: 2.9658 - 30s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 30s - loss: 2.5968 - 30s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 30s - loss: 2.4093 - 30s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 30s - loss: 2.3125 - 30s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 30s - loss: 2.2596 - 30s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 30s - loss: 2.2118 - 30s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 30s - loss: 2.1765 - 30s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 30s - loss: 2.1485 - 30s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 30s - loss: 2.1192 - 30s/epoch - 3ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 9149/9149 - 31s - loss: 6.2239 - 31s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 30s - loss: 3.0632 - 30s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 30s - loss: 2.7321 - 30s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 30s - loss: 2.5729 - 30s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 30s - loss: 2.4408 - 30s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 30s - loss: 2.3586 - 30s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 30s - loss: 2.2961 - 30s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 30s - loss: 2.2463 - 30s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 30s - loss: 2.2081 - 30s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 30s - loss: 2.1743 - 30s/epoch - 3ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 9149/9149 - 32s - loss: 5.7843 - 32s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 31s - loss: 2.9737 - 31s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 31s - loss: 2.5797 - 31s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 31s - loss: 2.4067 - 31s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 30s - loss: 2.3171 - 30s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 30s - loss: 2.2565 - 30s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 31s - loss: 2.2216 - 31s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 31s - loss: 2.1838 - 31s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 31s - loss: 2.1498 - 31s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 30s - loss: 2.1168 - 30s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 9149/9149 - 31s - loss: 6.1984 - 31s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 30s - loss: 3.0266 - 30s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 30s - loss: 2.7411 - 30s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 32s - loss: 2.5817 - 32s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 34s - loss: 2.4619 - 34s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 31s - loss: 2.3585 - 31s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 30s - loss: 2.3105 - 30s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 30s - loss: 2.2633 - 30s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 30s - loss: 2.2217 - 30s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 30s - loss: 2.1887 - 30s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 14.4159 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 9.2968 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 8.1625 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 7.6175 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 7.2809 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 7.0511 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 6.8745 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 6.7219 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 6.5854 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 6.4618 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 11.4699 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 5.2271 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 3.9003 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 3.2457 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 2.9182 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 2.7649 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 2.6836 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.6258 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 2.5769 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.5375 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 14.4968 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 9.3150 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 8.1673 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 7.6275 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 7.2921 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 7.0548 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 6.8805 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 6.7312 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 6.5997 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 6.4787 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 11.5261 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 5.1959 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 3.8618 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 3.2023 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 2.8991 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 2.7569 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 2.6771 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.6214 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 2.5797 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.5440 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 10.0888 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 4.2610 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 3.4973 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 3.1362 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 2.8770 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 2.6946 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 2.5660 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.4732 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 2.4041 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.3538 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 10.4705 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 4.5735 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 3.8336 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 3.3845 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 3.1079 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 2.9188 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 2.7862 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.6846 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 2.6082 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.5469 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 10.1813 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 4.3101 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 3.5441 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 3.1862 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 2.9327 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 2.7474 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 2.6126 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.5186 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 2.4494 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.3958 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 10.4941 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 4.5769 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 3.8064 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 3.3590 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 3.1026 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 2.9308 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 2.8011 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.7012 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 2.6190 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.5496 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 12.2126 - 16s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 8.3619 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 7.6098 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 7.1373 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 6.8075 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 6.5712 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 6.3907 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 6.2501 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 6.1319 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 6.0354 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# best_skor:  289178
# best_filter:  32
# best_kernel_1:  3
# best_kernel_2:  3
# best_batch 256
# best_step 8
# best_pool 3
# Epoch 1/10
# 4575/4575 - 15s - loss: 8.9439 - 15s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 3.9442 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 3.0864 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 2.8564 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 2.7270 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 2.6311 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 2.5570 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 2.5004 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 2.4572 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.4204 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 12.1848 - 16s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 8.3768 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 7.6395 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 15s - loss: 7.1975 - 15s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 6.9032 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 6.6725 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 6.4791 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 6.3224 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 6.1878 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 6.0767 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 8.9558 - 16s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 3.9725 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 3.0915 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 15s - loss: 2.8578 - 15s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 2.7319 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 2.6394 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 2.5674 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 2.5121 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 18s - loss: 2.4678 - 18s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 16s - loss: 2.4291 - 16s/epoch - 3ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 4575/4575 - 18s - loss: 9.2242 - 18s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 17s - loss: 3.9893 - 17s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 16s - loss: 3.0680 - 16s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 17s - loss: 2.6921 - 17s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 19s - loss: 2.5005 - 19s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 17s - loss: 2.3936 - 17s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 2.3247 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 16s - loss: 2.2727 - 16s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 2.2332 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 2.1991 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 4575/4575 - 17s - loss: 8.7259 - 17s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 17s - loss: 3.8931 - 17s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 18s - loss: 2.9870 - 18s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 17s - loss: 2.6851 - 17s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 17s - loss: 2.5416 - 17s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 16s - loss: 2.4510 - 16s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 18s - loss: 2.3932 - 18s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 19s - loss: 2.3474 - 19s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 19s - loss: 2.3110 - 19s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 16s - loss: 2.2791 - 16s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 9.2457 - 16s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 16s - loss: 3.9909 - 16s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 17s - loss: 3.0625 - 17s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 2.6917 - 16s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 2.5077 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 16s - loss: 2.4070 - 16s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 2.3352 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 18s - loss: 2.2806 - 18s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 19s - loss: 2.2385 - 19s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 20s - loss: 2.2063 - 20s/epoch - 4ms/step
# 9149/9149 [==============================] - 18s 2ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 8.6795 - 16s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 3.8971 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 16s - loss: 2.9764 - 16s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 2.6821 - 16s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 2.5511 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 17s - loss: 2.4692 - 17s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 2.4135 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 2.3727 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 2.3391 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 16s - loss: 2.3109 - 16s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 21s - loss: 10.9230 - 21s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 22s - loss: 7.9569 - 22s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 25s - loss: 7.2627 - 25s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 22s - loss: 6.8033 - 22s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 21s - loss: 6.4710 - 21s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 21s - loss: 6.2362 - 21s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 22s - loss: 6.0670 - 22s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 20s - loss: 5.9430 - 20s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 20s - loss: 5.8460 - 20s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 20s - loss: 5.7788 - 20s/epoch - 4ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 4575/4575 - 23s - loss: 7.6362 - 23s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 20s - loss: 3.3065 - 20s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 20s - loss: 2.8581 - 20s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 22s - loss: 2.6988 - 22s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 22s - loss: 2.5942 - 22s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 22s - loss: 2.5267 - 22s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 22s - loss: 2.4690 - 22s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 23s - loss: 2.4252 - 23s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 22s - loss: 2.3833 - 22s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 21s - loss: 2.3548 - 21s/epoch - 5ms/step
# 9149/9149 [==============================] - 18s 2ms/step
# Epoch 1/10
# 4575/4575 - 21s - loss: 10.9076 - 21s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 22s - loss: 7.9552 - 22s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 20s - loss: 7.2540 - 20s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 22s - loss: 6.8017 - 22s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 21s - loss: 6.4632 - 21s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 22s - loss: 6.2231 - 22s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 36s - loss: 6.0461 - 36s/epoch - 8ms/step
# Epoch 8/10
# 4575/4575 - 29s - loss: 5.9305 - 29s/epoch - 6ms/step
# Epoch 9/10
# 4575/4575 - 29s - loss: 5.8469 - 29s/epoch - 6ms/step
# Epoch 10/10
# 4575/4575 - 28s - loss: 5.7758 - 28s/epoch - 6ms/step
# 9149/9149 [==============================] - 26s 3ms/step
# Epoch 1/10
# 4575/4575 - 31s - loss: 7.5938 - 31s/epoch - 7ms/step
# Epoch 2/10
# 4575/4575 - 28s - loss: 3.3028 - 28s/epoch - 6ms/step
# Epoch 3/10
# 4575/4575 - 28s - loss: 2.8631 - 28s/epoch - 6ms/step
# Epoch 4/10
# 4575/4575 - 28s - loss: 2.7016 - 28s/epoch - 6ms/step
# Epoch 5/10
# 4575/4575 - 22s - loss: 2.5996 - 22s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 20s - loss: 2.5363 - 20s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 20s - loss: 2.4759 - 20s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 20s - loss: 2.4387 - 20s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 20s - loss: 2.3960 - 20s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 21s - loss: 2.3749 - 21s/epoch - 5ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 4575/4575 - 20s - loss: 7.1846 - 20s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 19s - loss: 3.1500 - 19s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 19s - loss: 2.6682 - 19s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 19s - loss: 2.4618 - 19s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 19s - loss: 2.3518 - 19s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 19s - loss: 2.2941 - 19s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 19s - loss: 2.2524 - 19s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 19s - loss: 2.2138 - 19s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 19s - loss: 2.1819 - 19s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 20s - loss: 2.1570 - 20s/epoch - 4ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 4575/4575 - 20s - loss: 7.5933 - 20s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 20s - loss: 3.2237 - 20s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 19s - loss: 2.7426 - 19s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 19s - loss: 2.5681 - 19s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 19s - loss: 2.4768 - 19s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 19s - loss: 2.4020 - 19s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 19s - loss: 2.3351 - 19s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 19s - loss: 2.2944 - 19s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 19s - loss: 2.2580 - 19s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 19s - loss: 2.2288 - 19s/epoch - 4ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 20s - loss: 7.1445 - 20s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 19s - loss: 3.1553 - 19s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 19s - loss: 2.6779 - 19s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 19s - loss: 2.4673 - 19s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 19s - loss: 2.3612 - 19s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 20s - loss: 2.3026 - 20s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 20s - loss: 2.2530 - 20s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 19s - loss: 2.2135 - 19s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 20s - loss: 2.1855 - 20s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 20s - loss: 2.1590 - 20s/epoch - 4ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 21s - loss: 7.5754 - 21s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 19s - loss: 3.2198 - 19s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 19s - loss: 2.7471 - 19s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 20s - loss: 2.5795 - 20s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 20s - loss: 2.4829 - 20s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 20s - loss: 2.4162 - 20s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 20s - loss: 2.3554 - 20s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 20s - loss: 2.3151 - 20s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 20s - loss: 2.2745 - 20s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 20s - loss: 2.2428 - 20s/epoch - 4ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 9149/9149 - 25s - loss: 10.8079 - 25s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 23s - loss: 4.5075 - 23s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 23s - loss: 3.4220 - 23s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 23s - loss: 3.0163 - 23s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 23s - loss: 2.8102 - 23s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 23s - loss: 2.6797 - 23s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 23s - loss: 2.5877 - 23s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 23s - loss: 2.5230 - 23s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 24s - loss: 2.4729 - 24s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 23s - loss: 2.4299 - 23s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  291481
# best_filter:  16
# best_kernel_1:  3
# best_kernel_2:  3
# best_batch 128
# best_step 10
# best_pool 3
# Epoch 1/10
# 9149/9149 - 25s - loss: 12.5254 - 25s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 31s - loss: 9.1192 - 31s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 38s - loss: 8.1822 - 38s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 27s - loss: 7.7916 - 27s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 24s - loss: 7.4604 - 24s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 23s - loss: 7.1482 - 23s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 24s - loss: 6.9435 - 24s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 24s - loss: 6.8082 - 24s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 24s - loss: 6.7046 - 24s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 24s - loss: 6.6160 - 24s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 9149/9149 - 24s - loss: 8.7164 - 24s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 23s - loss: 3.9926 - 23s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 23s - loss: 3.3119 - 23s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 24s - loss: 2.8893 - 24s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 24s - loss: 2.7077 - 24s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 23s - loss: 2.6055 - 23s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 23s - loss: 2.5331 - 23s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 23s - loss: 2.4751 - 23s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 23s - loss: 2.4248 - 23s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 23s - loss: 2.3821 - 23s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  291690
# best_filter:  16
# best_kernel_1:  3
# best_kernel_2:  4
# best_batch 128
# best_step 10
# best_pool 3
# Epoch 1/10
# 9149/9149 - 25s - loss: 12.5518 - 25s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 23s - loss: 9.0957 - 23s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 23s - loss: 8.1760 - 23s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 23s - loss: 7.7923 - 23s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 23s - loss: 7.4717 - 23s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 23s - loss: 7.1628 - 23s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 23s - loss: 6.9556 - 23s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 23s - loss: 6.8250 - 23s/epoch - 2ms/step
# Epoch 9/10
# 9149/9149 - 23s - loss: 6.7241 - 23s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 24s - loss: 6.6388 - 24s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 9149/9149 - 25s - loss: 9.0934 - 25s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 24s - loss: 4.5292 - 24s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 24s - loss: 3.6877 - 24s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 24s - loss: 3.2463 - 24s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 24s - loss: 2.9994 - 24s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 23s - loss: 2.8266 - 23s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 24s - loss: 2.6988 - 24s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 24s - loss: 2.5993 - 24s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 23s - loss: 2.5194 - 23s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 24s - loss: 2.4543 - 24s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  291693
# best_filter:  16
# best_kernel_1:  4
# best_kernel_2:  3
# best_batch 128
# best_step 10
# best_pool 3
# Epoch 1/10
# 9149/9149 - 25s - loss: 9.1463 - 25s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 24s - loss: 4.5360 - 24s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 23s - loss: 3.9174 - 23s/epoch - 2ms/step
# Epoch 4/10
# 9149/9149 - 23s - loss: 3.4975 - 23s/epoch - 2ms/step
# Epoch 5/10
# 9149/9149 - 23s - loss: 3.1918 - 23s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 23s - loss: 2.9880 - 23s/epoch - 2ms/step
# Epoch 7/10
# 9149/9149 - 24s - loss: 2.8481 - 24s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 24s - loss: 2.7479 - 24s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 24s - loss: 2.6719 - 24s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 22s - loss: 2.6127 - 22s/epoch - 2ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 9149/9149 - 24s - loss: 7.5003 - 24s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 23s - loss: 3.9248 - 23s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 23s - loss: 3.3688 - 23s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 24s - loss: 3.0304 - 24s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 23s - loss: 2.8115 - 23s/epoch - 2ms/step
# Epoch 6/10
# 9149/9149 - 23s - loss: 2.6595 - 23s/epoch - 2ms/step
# Epoch 7/10
# 9149/9149 - 24s - loss: 2.5466 - 24s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 24s - loss: 2.4578 - 24s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 23s - loss: 2.3901 - 23s/epoch - 2ms/step
# Epoch 10/10
# 9149/9149 - 23s - loss: 2.3359 - 23s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 9149/9149 - 24s - loss: 9.1797 - 24s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 23s - loss: 4.5445 - 23s/epoch - 2ms/step
# Epoch 3/10
# 9149/9149 - 23s - loss: 3.9130 - 23s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 23s - loss: 3.4784 - 23s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 23s - loss: 3.1569 - 23s/epoch - 2ms/step
# Epoch 6/10
# 9149/9149 - 23s - loss: 2.9528 - 23s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 23s - loss: 2.8250 - 23s/epoch - 2ms/step
# Epoch 8/10
# 9149/9149 - 23s - loss: 2.7275 - 23s/epoch - 2ms/step
# Epoch 9/10
# 9149/9149 - 23s - loss: 2.6542 - 23s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 23s - loss: 2.5957 - 23s/epoch - 2ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 9149/9149 - 27s - loss: 7.8938 - 27s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 26s - loss: 3.8990 - 26s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 26s - loss: 3.3144 - 26s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 26s - loss: 2.9582 - 26s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 26s - loss: 2.7564 - 26s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 26s - loss: 2.6248 - 26s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 26s - loss: 2.5389 - 26s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 26s - loss: 2.4781 - 26s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 26s - loss: 2.4274 - 26s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 26s - loss: 2.3885 - 26s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 9149/9149 - 26s - loss: 11.1591 - 26s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 25s - loss: 8.1910 - 25s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 25s - loss: 7.4257 - 25s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 25s - loss: 6.9958 - 25s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 25s - loss: 6.7152 - 25s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 25s - loss: 6.5103 - 25s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 25s - loss: 6.3508 - 25s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 26s - loss: 6.2210 - 26s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 27s - loss: 6.1158 - 27s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 25s - loss: 6.0228 - 25s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 9149/9149 - 28s - loss: 6.8727 - 28s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 27s - loss: 3.5186 - 27s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 26s - loss: 2.9277 - 26s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 26s - loss: 2.6555 - 26s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 26s - loss: 2.5117 - 26s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 26s - loss: 2.4208 - 26s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 27s - loss: 2.3520 - 27s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 27s - loss: 2.3042 - 27s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 27s - loss: 2.2638 - 27s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 26s - loss: 2.2301 - 26s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# best_skor:  291763
# best_filter:  32
# best_kernel_1:  3
# best_kernel_2:  4
# best_batch 128
# best_step 10
# best_pool 3
# Epoch 1/10
# 9149/9149 - 27s - loss: 11.1350 - 27s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 26s - loss: 8.1532 - 26s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 26s - loss: 7.3510 - 26s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 26s - loss: 6.9119 - 26s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 26s - loss: 6.6309 - 26s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 26s - loss: 6.4323 - 26s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 26s - loss: 6.2819 - 26s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 26s - loss: 6.1617 - 26s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 26s - loss: 6.0621 - 26s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 26s - loss: 5.9796 - 26s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 9149/9149 - 27s - loss: 7.4591 - 27s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 26s - loss: 3.6284 - 26s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 26s - loss: 3.1207 - 26s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 26s - loss: 2.8654 - 26s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 26s - loss: 2.6898 - 26s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 26s - loss: 2.5674 - 26s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 26s - loss: 2.4733 - 26s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 26s - loss: 2.3981 - 26s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 26s - loss: 2.3428 - 26s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 26s - loss: 2.2938 - 26s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 9149/9149 - 27s - loss: 8.3215 - 27s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 26s - loss: 4.2226 - 26s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 25s - loss: 3.3535 - 25s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 26s - loss: 3.0066 - 26s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 25s - loss: 2.8203 - 25s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 26s - loss: 2.7124 - 26s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 26s - loss: 2.6232 - 26s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 26s - loss: 2.5444 - 26s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 26s - loss: 2.4871 - 26s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 26s - loss: 2.4371 - 26s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 9149/9149 - 28s - loss: 6.6071 - 28s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 27s - loss: 3.3246 - 27s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 27s - loss: 2.8560 - 27s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 26s - loss: 2.6351 - 26s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 27s - loss: 2.4956 - 27s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 26s - loss: 2.3985 - 26s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 27s - loss: 2.3300 - 27s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 26s - loss: 2.2775 - 26s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 27s - loss: 2.2335 - 27s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 26s - loss: 2.1954 - 26s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# best_skor:  291803
# best_filter:  32
# best_kernel_1:  4
# best_kernel_2:  4
# best_batch 128
# best_step 10
# best_pool 3
# Epoch 1/10
# 9149/9149 - 27s - loss: 8.3584 - 27s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 26s - loss: 4.3598 - 26s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 27s - loss: 3.4598 - 27s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 26s - loss: 3.0629 - 26s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 26s - loss: 2.8539 - 26s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 26s - loss: 2.7272 - 26s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 26s - loss: 2.6394 - 26s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 26s - loss: 2.5710 - 26s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 26s - loss: 2.5141 - 26s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 26s - loss: 2.4688 - 26s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 9149/9149 - 33s - loss: 6.9319 - 33s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 32s - loss: 3.7699 - 32s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 32s - loss: 3.2096 - 32s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 32s - loss: 2.8669 - 32s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 32s - loss: 2.6644 - 32s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 32s - loss: 2.5432 - 32s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 32s - loss: 2.4441 - 32s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 32s - loss: 2.3908 - 32s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 32s - loss: 2.3394 - 32s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 32s - loss: 2.2906 - 32s/epoch - 4ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 9149/9149 - 33s - loss: 10.2436 - 33s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 30s - loss: 7.7959 - 30s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 30s - loss: 7.1072 - 30s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 30s - loss: 6.7101 - 30s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 30s - loss: 6.4388 - 30s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 30s - loss: 6.2657 - 30s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 30s - loss: 6.1318 - 30s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 30s - loss: 6.0180 - 30s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 30s - loss: 5.9071 - 30s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 30s - loss: 5.8130 - 30s/epoch - 3ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 9149/9149 - 34s - loss: 5.9935 - 34s/epoch - 4ms/step
# ...
# Epoch 10/10
# 4575/4575 - 13s - loss: 6.8534 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 11.0948 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 4.6028 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 3.7720 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 3.2111 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 2.9277 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 2.7814 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 2.6870 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.6155 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 2.5553 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.5025 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 13.8084 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 9.9389 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 8.6425 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 8.1347 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 7.8544 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 7.6190 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 7.3876 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 7.1575 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 6.9856 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 6.8680 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 11.1814 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 5.0829 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 4.2039 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 3.6189 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 3.2677 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 3.0448 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 2.8864 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.7641 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 2.6638 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.5796 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 15s - loss: 11.0981 - 15s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 5.2175 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 4.2406 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 3.8286 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 3.5086 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 3.2613 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 3.0806 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.9477 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 2.8426 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.7580 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 9.2860 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 4.3131 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 3.7337 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 3.3617 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 3.0930 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 2.8968 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 2.7565 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.6449 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 2.5555 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.4810 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 11.1811 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 5.2218 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 4.2439 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 3.8175 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 3.4935 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 3.2447 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 3.0579 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.9160 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 2.8131 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.7319 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 9.7647 - 16s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 4.3418 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 3.6183 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 3.2223 - 16s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 2.9435 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 2.7635 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 2.6481 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 2.5688 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 2.5091 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 2.4611 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 12.3400 - 16s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 8.7570 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 7.8326 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 15s - loss: 7.3393 - 15s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 7.0017 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 6.7485 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 6.5574 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 6.3990 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 6.2729 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 6.1654 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 17s - loss: 8.4854 - 17s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 3.9010 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 3.2531 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 15s - loss: 2.8642 - 15s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 16s - loss: 2.6469 - 16s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 2.5285 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 2.4449 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 2.3828 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 16s - loss: 2.3309 - 16s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 2.2872 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 12.3300 - 16s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 8.7188 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 7.8075 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 15s - loss: 7.2844 - 15s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 6.9375 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 6.7003 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 6.5192 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 6.3708 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 6.2444 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 6.1418 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 9.2641 - 16s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 4.0516 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 3.3586 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 15s - loss: 3.0434 - 15s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 2.8508 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 2.7071 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 2.5982 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 2.5155 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 2.4517 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 2.4003 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 9.9949 - 16s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 5.0188 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 3.8784 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 15s - loss: 3.3019 - 15s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 3.0292 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 2.8659 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 2.7543 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 2.6731 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 2.6043 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 2.5449 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 8.1067 - 16s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 16s - loss: 3.6934 - 16s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 16s - loss: 3.0741 - 16s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 15s - loss: 2.7844 - 15s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 2.6075 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 16s - loss: 2.4866 - 16s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 16s - loss: 2.4012 - 16s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 2.3426 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 2.2952 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 16s - loss: 2.2570 - 16s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 9.9803 - 16s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 5.0639 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 4.0448 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 15s - loss: 3.4458 - 15s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 3.1072 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 2.9063 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 2.7790 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 2.6816 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 2.6088 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 2.5517 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 22s - loss: 8.3567 - 22s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 21s - loss: 4.0990 - 21s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 21s - loss: 3.4923 - 21s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 21s - loss: 3.0903 - 21s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 21s - loss: 2.8361 - 21s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 21s - loss: 2.6847 - 21s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 21s - loss: 2.5690 - 21s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 21s - loss: 2.4875 - 21s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 21s - loss: 2.4230 - 21s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 21s - loss: 2.3694 - 21s/epoch - 5ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 4575/4575 - 21s - loss: 11.1825 - 21s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 20s - loss: 8.2285 - 20s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 20s - loss: 7.4715 - 20s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 20s - loss: 7.0111 - 20s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 20s - loss: 6.6995 - 20s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 20s - loss: 6.4717 - 20s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 20s - loss: 6.3126 - 20s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 21s - loss: 6.1758 - 21s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 20s - loss: 6.0689 - 20s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 20s - loss: 5.9767 - 20s/epoch - 4ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 4575/4575 - 22s - loss: 7.1036 - 22s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 21s - loss: 3.5875 - 21s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 21s - loss: 2.9950 - 21s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 22s - loss: 2.6623 - 22s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 22s - loss: 2.5196 - 22s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 22s - loss: 2.4040 - 22s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 21s - loss: 2.3371 - 21s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 21s - loss: 2.2743 - 21s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 22s - loss: 2.2343 - 22s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 21s - loss: 2.2047 - 21s/epoch - 5ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 4575/4575 - 21s - loss: 11.1452 - 21s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 20s - loss: 8.1919 - 20s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 20s - loss: 7.4338 - 20s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 20s - loss: 6.9778 - 20s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 20s - loss: 6.6785 - 20s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 20s - loss: 6.4559 - 20s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 20s - loss: 6.2976 - 20s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 20s - loss: 6.1618 - 20s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 20s - loss: 6.0596 - 20s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 20s - loss: 5.9689 - 20s/epoch - 4ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 4575/4575 - 22s - loss: 7.8973 - 22s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 21s - loss: 3.7005 - 21s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 21s - loss: 3.1428 - 21s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 21s - loss: 2.8581 - 21s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 21s - loss: 2.6764 - 21s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 21s - loss: 2.5883 - 21s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 21s - loss: 2.4724 - 21s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 21s - loss: 2.4110 - 21s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 21s - loss: 2.3579 - 21s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 21s - loss: 2.2994 - 21s/epoch - 5ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# best_skor:  291827
# best_filter:  64
# best_kernel_1:  4
# best_kernel_2:  3
# best_batch 256
# best_step 10
# best_pool 3
# Epoch 1/10
# 4575/4575 - 21s - loss: 7.9706 - 21s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 20s - loss: 4.0156 - 20s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 20s - loss: 3.2478 - 20s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 20s - loss: 2.8906 - 20s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 20s - loss: 2.7035 - 20s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 20s - loss: 2.5701 - 20s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 20s - loss: 2.5049 - 20s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 20s - loss: 2.4350 - 20s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 20s - loss: 2.3731 - 20s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 20s - loss: 2.3223 - 20s/epoch - 4ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 4575/4575 - 22s - loss: 6.8000 - 22s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 21s - loss: 3.4323 - 21s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 22s - loss: 2.9125 - 22s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 22s - loss: 2.6678 - 22s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 22s - loss: 2.5094 - 22s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 22s - loss: 2.4079 - 22s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 22s - loss: 2.3301 - 22s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 22s - loss: 2.2589 - 22s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 22s - loss: 2.2029 - 22s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 22s - loss: 2.1574 - 22s/epoch - 5ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 4575/4575 - 21s - loss: 7.9438 - 21s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 20s - loss: 4.0138 - 20s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 20s - loss: 3.2437 - 20s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 20s - loss: 2.9118 - 20s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 20s - loss: 2.7227 - 20s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 20s - loss: 2.6110 - 20s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 20s - loss: 2.5268 - 20s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 20s - loss: 2.4574 - 20s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 20s - loss: 2.3967 - 20s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 20s - loss: 2.3517 - 20s/epoch - 4ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# best_skor:  291827
# best_filter:  64
# best_kernel_1:  4
# best_kernel_2:  3
# best_batch 256
# best_step 10
# best_pool 3

# %% [raw]
# best_skor:  291827
# best_filter:  64
# best_kernel_1:  4
# best_kernel_2:  3
# best_batch 256
# best_step 10
# best_pool 3

# %% [markdown]
# ## Trazenje jednostavnije arhitekture

# %%
filter_size_1 = [8,16]
filter_size_2 = [8,16]
kernel_size_1 = [3,4]
kernel_size_2 = [3,4]
pooling_size = [3,4]
time_steps_list = [8,10]

# %%
best_skor = float('-inf')
best_filter = None
best_filter_2 = None
best_kernel_1 = None
best_kernel_2 = None
best_pool = None
best_batch = None
#best_pool_type = None
#best_global_pool_type = None
best_step = None
for step in time_steps_list:
    
    #delimo podatke na osnovu velicine buffera
    input_shape = (step,1)

    for i in range(len(train_files_names)):
        exec(f'train_X_{i}, train_y_{i} = create_timeseries_split(razlika_trening_{i}, step)')

    train_X = np.asarray(train_X_0)
    for i in range(1,len(train_files_names)):
        exec(f'train_X = np.append(train_X, train_X_{i}, axis=0)')

    train_y = np.asarray(train_y_0)
    for i in range(1,len(train_files_names)):
        exec(f'train_y = np.append(train_y, train_y_{i}, axis=0)')  
    
    #uzimamo percent_val sa kraja train_X skupa 
    val_x = train_X[-int(len(train_X)*percent_val)-1:-1]
    val_y = train_y[-int(len(train_X)*percent_val)-1:-1]

    train_X = train_X[:len(train_X)-val_x.shape[0]]
    train_y = train_y[:len(train_y)-val_x.shape[0]]
         
    for filt in filter_size_1:
        for filt_2 in filter_size_2:
            for kernel_1 in kernel_size_1:
                for kernel_2 in kernel_size_2:
                    for pool in pooling_size:
                        keras.utils.set_random_seed(7)
                        optimizerMSE = keras.optimizers.Adam(learning_rate=0.0001)

                        modelMSE = Sequential()
                        modelMSE.add(Input(shape=input_shape))
                        modelMSE.add(Conv1D(filters=filt, kernel_size=kernel_1,padding='same', activation=LeakyReLU()))
                        #modelMSE.add(Conv1D(filters=32, kernel_size=2, activation=LeakyReLU()))
                        modelMSE.add(MaxPooling1D(pool_size=pool))
                        modelMSE.add(Conv1D(filters=filt_2, kernel_size=kernel_2,padding='same', activation=LeakyReLU()))
                        #modelMSE.add(Conv1D(filters=64, kernel_size=2, activation=LeakyReLU()))
                        modelMSE.add(GlobalAveragePooling1D())
                        modelMSE.add(Flatten())
                        modelMSE.add(Dense(128, activation=LeakyReLU()))
                        modelMSE.add(Dense(units = 1, activation=LeakyReLU()))
                        modelMSE.compile(loss='mean_squared_error', optimizer = optimizerMSE)

                        modelMSE.fit(train_X, train_y, epochs = 10, batch_size = 256, verbose = 2, shuffle = False)
                        test_predict_MSE = modelMSE.predict(val_x)



                        #zato sto smo uzeli 20% od kraja, ne pocinje indeks od samog pocetka rada masine
                        #radimo evaluaciju na mean 3 sigma testu
                        i =(len(x_command)-time_steps) - val_x.shape[0]%(len(x_command)-time_steps) -1
                        mean_3std = 0
                        for j in range(len(test_predict_MSE)):
                            if i%len(x_command) == 0:
                                i = step
                            if sr_vrednost[i] - 3*std_dev[i] <= test_predict_MSE[j] <= sr_vrednost[i] + 3*std_dev[i]:
                                    mean_3std += 1
                            i += 1



                        if mean_3std > best_skor:
                            best_skor = mean_3std
                            best_filter = filt
                            best_filter_2 = filt_2
                            best_kernel_1 = kernel_1
                            best_kernel_2 = kernel_2
                            best_pool = pool
                            #best_batch = batch
                            #best_pool_type = ptype
                            #best_global_pool_type = gptype
                            best_step = step

                            print('best_skor: ', best_skor)
                            print('best_filter: ', best_filter)
                            print('best_filter_2', best_filter_2)
                            print('best_kernel_1: ', best_kernel_1)
                            print('best_kernel_2: ', best_kernel_2)
                            #print('best_batch', best_batch)
                            print('best_step', best_step)
                            print('best_pool', best_pool)
                            #print('best_pool_type', best_pool_type)
                            #print('best_global_pool_type',best_global_pool_type)

print('best_skor: ', best_skor)
print('best_filter: ', best_filter)
print('best_filter_2', best_filter_2)
print('best_kernel_1: ', best_kernel_1)
print('best_kernel_2: ', best_kernel_2)
#print('best_batch', best_batch)
print('best_step', best_step)
print('best_pool', best_pool)
#print('best_pool_type', best_pool_type)
#print('best_global_pool_type',best_global_pool_type)
# Out:
# Epoch 1/10
# 4575/4575 - 13s - loss: 15.2717 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 11s - loss: 10.8702 - 11s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 11s - loss: 9.3954 - 11s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 11s - loss: 8.7825 - 11s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 11s - loss: 8.4047 - 11s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 11s - loss: 8.1291 - 11s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 7.9154 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 7.7396 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 12s - loss: 7.5897 - 12s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 7.4569 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  289640
# best_filter:  8
# best_filter_2 8
# best_kernel_1:  3
# best_kernel_2:  3
# best_step 8
# best_pool 3
# Epoch 1/10
# 4575/4575 - 16s - loss: 12.5667 - 16s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 7.3155 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 5.4274 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 4.6184 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 4.1312 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 3.8129 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 3.5946 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 3.4415 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 3.3258 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 3.2337 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 2ms/step
# Epoch 1/10
# 4575/4575 - 15s - loss: 15.4850 - 15s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 10.9271 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 9.3375 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 8.7032 - 16s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 20s - loss: 8.3341 - 20s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 21s - loss: 8.0764 - 21s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 20s - loss: 7.8783 - 20s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 19s - loss: 7.7160 - 19s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 7.5797 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 7.4610 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# best_skor:  289693
# best_filter:  8
# best_filter_2 8
# best_kernel_1:  3
# best_kernel_2:  4
# best_step 8
# best_pool 3
# Epoch 1/10
# 4575/4575 - 18s - loss: 12.8091 - 18s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 7.3629 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 5.3911 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 4.5526 - 16s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 16s - loss: 4.0696 - 16s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 3.7631 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 3.5537 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 3.4001 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 19s - loss: 3.2793 - 19s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 19s - loss: 3.1774 - 19s/epoch - 4ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 23s - loss: 12.9351 - 23s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 6.2362 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 16s - loss: 4.6446 - 16s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 3.9119 - 16s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 16s - loss: 3.5482 - 16s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 16s - loss: 3.3237 - 16s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 16s - loss: 3.1695 - 16s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 3.0543 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 2.9600 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 2.8771 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 19s 2ms/step
# Epoch 1/10
# 4575/4575 - 26s - loss: 12.2274 - 26s/epoch - 6ms/step
# Epoch 2/10
# 4575/4575 - 16s - loss: 6.0676 - 16s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 16s - loss: 4.6221 - 16s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 4.1174 - 16s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 16s - loss: 3.7857 - 16s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 16s - loss: 3.5628 - 16s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 16s - loss: 3.4189 - 16s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 16s - loss: 3.3179 - 16s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 17s - loss: 3.2375 - 17s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 17s - loss: 3.1680 - 17s/epoch - 4ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 4575/4575 - 18s - loss: 13.0856 - 18s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 16s - loss: 6.2800 - 16s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 4.6797 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 3.9295 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 3.5655 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 3.3589 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 3.2157 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 17s - loss: 3.0979 - 17s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 17s - loss: 2.9963 - 17s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 17s - loss: 2.9066 - 17s/epoch - 4ms/step
# 9149/9149 [==============================] - 12s 1ms/step
# Epoch 1/10
# 4575/4575 - 21s - loss: 12.4318 - 21s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 19s - loss: 6.1062 - 19s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 4.5609 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 4.0506 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 11s - loss: 3.7590 - 11s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 11s - loss: 3.5783 - 11s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 3.4472 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 3.3460 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 3.2653 - 11s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 12s - loss: 3.1997 - 12s/epoch - 3ms/step
# 9149/9149 [==============================] - 12s 1ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 15.4269 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 10.1456 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 9.1277 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 8.4517 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 7.9496 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 7.5565 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 7.2987 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 7.1202 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 12s - loss: 6.9803 - 12s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 12s - loss: 6.8664 - 12s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 22s - loss: 12.7984 - 22s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 6.3657 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.8448 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 4.2412 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.8518 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 3.5920 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 3.4080 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 3.2781 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 3.1846 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.1092 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 15.4388 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 10.0801 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 9.0909 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 8.4208 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 7.9228 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 7.5355 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 7.2594 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 7.0793 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 6.9432 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 6.8336 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.7741 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 6.3102 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.8599 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 4.2313 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.8200 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.5410 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.3548 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.2253 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 3.1311 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 11s - loss: 3.0538 - 11s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 12s - loss: 12.2506 - 12s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.4542 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.3808 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.7024 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.2597 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 3.0012 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.8502 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.7463 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.6652 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.6008 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 11.9778 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.1715 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.9377 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.5410 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.3628 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 3.2569 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 3.1827 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 3.1246 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 3.0755 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.0330 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.2790 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.4198 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.3659 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 3.6761 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.2196 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.9653 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.8257 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.7282 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.6532 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.5963 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.0007 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.1989 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.9517 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.5367 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.3644 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 3.2647 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 3.1948 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 3.1386 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 3.0890 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.0420 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 12s - loss: 15.1911 - 12s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 9.8246 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 8.6080 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 8.0359 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 7.6968 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 7.3926 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 7.1503 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 6.9617 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 6.8001 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 6.6645 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 12s - loss: 12.3963 - 12s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.4111 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.0155 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.3345 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.0610 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.9058 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.8053 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.7365 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.6856 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.6422 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 15.2568 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 9.7580 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 8.6187 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 8.0880 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 7.7815 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 7.5364 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 7.3193 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 7.1087 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 6.9247 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 6.7723 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.4677 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.3833 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.0446 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.3846 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.0833 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.9096 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.7913 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.7077 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.6488 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.6029 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 12s - loss: 12.6536 - 12s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.2123 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.9948 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.4740 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 11s - loss: 3.1773 - 11s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.9685 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.8127 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.6988 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.6131 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.5450 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.4599 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 4.8965 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.8141 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.3380 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.0642 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.8820 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.7604 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.6758 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.6156 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.5695 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.6329 - 11s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.1676 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.9765 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.4828 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.1908 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.9721 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.8071 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.6813 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 2.5849 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.5086 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.4355 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 11s - loss: 4.8655 - 11s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.8341 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.3569 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.1079 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 2.9393 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.8157 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.7269 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.6599 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.6072 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 14.4159 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 9.2971 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 8.1628 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 7.6178 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 7.2812 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 7.0516 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 6.8753 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 6.7238 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 6.5887 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 6.4669 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 11.4699 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.2271 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.9004 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.2459 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 2.9179 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 2.7618 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 2.6729 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.6121 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 2.5674 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.5293 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 14.4968 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 9.3151 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 8.1670 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 11s - loss: 7.6250 - 11s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 7.2902 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 7.0549 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 6.8813 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 6.7313 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 6.5980 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 12s - loss: 6.4777 - 12s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 11.5260 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 5.1956 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 11s - loss: 3.8621 - 11s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 3.2029 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 2.8995 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 2.7572 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 2.6774 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.6217 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 2.5800 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.5441 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 10.0888 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 11s - loss: 4.2609 - 11s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 3.4973 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 3.1362 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 2.8766 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 2.6944 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 2.5660 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 2.4734 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 12s - loss: 2.4042 - 12s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.3539 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 10.4705 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 4.5735 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 3.8336 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 3.3844 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 3.1078 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 2.9186 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 2.7862 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.6846 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 2.6081 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.5467 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 12s 1ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 10.1814 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 4.3099 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 3.5435 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 3.1854 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 2.9315 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 2.7465 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 2.6120 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 2.5184 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 12s - loss: 2.4487 - 12s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 12s - loss: 2.3954 - 12s/epoch - 3ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 10.4941 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 4.5769 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 3.8066 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 3.3590 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 3.1024 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 2.9306 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 2.8007 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.7005 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 12s - loss: 2.6183 - 12s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 12s - loss: 2.5488 - 12s/epoch - 3ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 13.7563 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 9.0385 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 5.7744 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 4.6695 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 4.2435 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 3.9592 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 3.7451 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 3.5948 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 3.4882 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.4005 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# best_skor:  291375
# best_filter:  8
# best_filter_2 8
# best_kernel_1:  3
# best_kernel_2:  3
# best_step 10
# best_pool 3
# Epoch 1/10
# 4575/4575 - 13s - loss: 14.3629 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 11.6837 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 10.4525 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 9.3585 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 8.7439 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 8.3689 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 8.0953 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 7.8866 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 7.7276 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 7.5936 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 13.4070 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 6.8789 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 4.7701 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 4.1704 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 3.8955 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 3.7005 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 3.5406 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 3.4053 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 3.2888 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.1861 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 12s 1ms/step
# best_skor:  291396
# best_filter:  8
# best_filter_2 8
# best_kernel_1:  3
# best_kernel_2:  4
# best_step 10
# best_pool 3
# Epoch 1/10
# 4575/4575 - 13s - loss: 14.5144 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 11.6956 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 10.3600 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 9.2743 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 8.6851 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 8.3130 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 8.0563 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 7.8726 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 7.7313 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 7.6170 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 12s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 13.2833 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 6.9508 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 5.1519 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 4.5954 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 4.2807 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 4.0210 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 3.8016 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 3.6189 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 3.4713 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.3511 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 12s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 13.5449 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 7.7179 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 5.6928 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 5.0798 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 4.7260 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 4.5088 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 4.3449 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 4.2004 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 4.0632 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.9316 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 12s 1ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 12.6697 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 5.7539 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 4.4351 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 3.9981 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 3.7005 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 3.4733 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 3.3016 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 3.1785 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 3.0864 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.0123 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 13.6877 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 7.6742 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 5.6574 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 5.0679 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 4.7239 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 4.5077 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 11s - loss: 4.3468 - 11s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 4.2053 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 4.0722 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.9446 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 14.1953 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 7.9517 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 5.5297 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 4.8454 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 4.4799 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 4.2278 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 4.0265 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 3.8620 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 3.7244 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 11s - loss: 3.6059 - 11s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 14.7941 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 11.3539 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 9.8275 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 8.8689 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 8.3844 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 8.0831 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 7.8573 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 7.6774 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 7.5289 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 11s - loss: 7.4031 - 11s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 12.8298 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 6.0676 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 4.7142 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 4.2380 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 3.9239 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 3.6984 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 11s - loss: 3.5278 - 11s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 3.3991 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 3.3022 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 11s - loss: 3.2265 - 11s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# best_skor:  291406
# best_filter:  8
# best_filter_2 16
# best_kernel_1:  3
# best_kernel_2:  4
# best_step 10
# best_pool 3
# Epoch 1/10
# 4575/4575 - 14s - loss: 14.8113 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 11s - loss: 11.3759 - 11s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 11s - loss: 10.0102 - 11s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 9.0207 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 8.4828 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 11s - loss: 8.1213 - 11s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 7.8710 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 7.6829 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 7.5249 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 7.3851 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 13.3616 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 11s - loss: 6.4333 - 11s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 4.9749 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 4.4118 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 4.0904 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 3.8342 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 3.6323 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 3.4791 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 12s - loss: 3.3596 - 12s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 11s - loss: 3.2590 - 11s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 13.3040 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 6.5343 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 5.0576 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 4.4888 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 4.0991 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 3.8182 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 3.6170 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 3.4610 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 3.3320 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.2250 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# best_skor:  291497
# best_filter:  8
# best_filter_2 16
# best_kernel_1:  4
# best_kernel_2:  3
# best_step 10
# best_pool 4
# Epoch 1/10
# 4575/4575 - 14s - loss: 11.7866 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 5.2302 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 4.2934 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 3.8475 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 3.5200 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 3.2681 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 3.0976 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 2.9774 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 2.8815 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.8017 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 14s 2ms/step
# Epoch 1/10
# 4575/4575 - 15s - loss: 13.3457 - 15s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 6.6008 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 5.0855 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 4.4798 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 4.0703 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 3.7778 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 3.5462 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 3.3720 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 3.2315 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 12s - loss: 3.1243 - 12s/epoch - 3ms/step
# 9149/9149 [==============================] - 12s 1ms/step
# best_skor:  291566
# best_filter:  8
# best_filter_2 16
# best_kernel_1:  4
# best_kernel_2:  4
# best_step 10
# best_pool 4
# Epoch 1/10
# 4575/4575 - 27s - loss: 14.0058 - 27s/epoch - 6ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 7.3077 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 4.8048 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 4.1801 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 3.8529 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 3.5364 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 3.2918 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 3.1255 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 3.0050 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.9173 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 1ms/step
# Epoch 1/10
# 4575/4575 - 17s - loss: 14.7606 - 17s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 10.5761 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 8.9992 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 15s - loss: 8.2216 - 15s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 7.8227 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 7.5412 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 7.3332 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 7.1692 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 7.0288 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 6.9084 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 15s - loss: 13.1242 - 15s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 5.3014 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 4.1573 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 3.6730 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 3.2724 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 2.9757 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 2.8120 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 2.7169 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 2.6515 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.6022 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  291576
# best_filter:  16
# best_filter_2 8
# best_kernel_1:  3
# best_kernel_2:  4
# best_step 10
# best_pool 3
# Epoch 1/10
# 4575/4575 - 14s - loss: 14.8178 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 10.5660 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 9.0129 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 8.2624 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 7.8709 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 7.5815 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 7.3623 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 7.1931 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 7.0499 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 6.9281 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 15s - loss: 13.0089 - 15s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 5.6201 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 4.1643 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 3.5597 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 3.2176 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 2.9902 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 2.8370 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 2.7306 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 2.6512 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.5881 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 18s - loss: 13.3287 - 18s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 6.1984 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 4.6530 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 4.0780 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 3.6873 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 3.4131 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 3.2218 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 3.0872 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 2.9804 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.8902 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  291603
# best_filter:  16
# best_filter_2 8
# best_kernel_1:  4
# best_kernel_2:  3
# best_step 10
# best_pool 4
# Epoch 1/10
# 4575/4575 - 15s - loss: 11.8467 - 15s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 4.7276 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 3.8421 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 15s - loss: 3.4190 - 15s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 3.1202 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 2.8689 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 2.6920 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 2.5669 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 2.4829 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.4234 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 13.3196 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 6.2037 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 4.6414 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 4.0866 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 3.6975 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 3.4160 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 3.2178 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 3.0725 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 2.9560 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.8635 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  291655
# best_filter:  16
# best_filter_2 8
# best_kernel_1:  4
# best_kernel_2:  4
# best_step 10
# best_pool 4
# Epoch 1/10
# 4575/4575 - 15s - loss: 12.9658 - 15s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 6.1031 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 4.0454 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 3.4114 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 3.0985 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 2.9169 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 2.7938 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 2.6999 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 2.6289 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.5727 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  291680
# best_filter:  16
# best_filter_2 16
# best_kernel_1:  3
# best_kernel_2:  3
# best_step 10
# best_pool 3
# Epoch 1/10
# 4575/4575 - 14s - loss: 13.7498 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 9.9620 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 8.6574 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 8.1397 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 7.8522 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 7.6032 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 7.3463 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 7.1206 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 6.9641 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 6.8513 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 11.0948 - 16s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 4.6027 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 3.7717 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 3.2104 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 2.9269 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 2.7842 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 2.6890 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 2.6169 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 2.5562 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.5021 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 2ms/step
# Epoch 1/10
# 4575/4575 - 15s - loss: 13.8084 - 15s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 9.9391 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 8.6420 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 8.1346 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 7.8541 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 7.6186 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 7.3874 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 7.1576 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 6.9854 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 6.8679 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 11.1814 - 16s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 5.0829 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 4.2044 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 3.6197 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 3.2681 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 3.0449 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 2.8868 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 2.7644 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 2.6640 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.5797 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 1ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 11.0981 - 16s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 5.2174 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 4.2405 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 3.8286 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 3.5084 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 3.2611 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 3.0804 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 2.9475 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 2.8424 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.7577 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 9.2861 - 16s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 4.3131 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 3.7339 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 15s - loss: 3.3623 - 15s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 3.0936 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 2.8975 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 2.7572 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 2.6454 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 2.5562 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.4820 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 1ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 11.1812 - 16s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 5.2217 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 4.2440 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 3.8175 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 3.4936 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 3.2447 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 3.0582 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 2.9164 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 2.8136 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 2.7319 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# best_skor:  291680
# best_filter:  16
# best_filter_2 16
# best_kernel_1:  3
# best_kernel_2:  3
# best_step 10
# best_pool 3

# %% [raw]
# best_skor:  291680
# best_filter:  16
# best_filter_2 16
# best_kernel_1:  3
# best_kernel_2:  3
# best_step 10
# best_pool 3
