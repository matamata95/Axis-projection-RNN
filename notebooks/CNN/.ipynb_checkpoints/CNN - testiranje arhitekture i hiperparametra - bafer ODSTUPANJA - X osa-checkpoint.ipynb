# %%
import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input,LeakyReLU, Flatten, MaxPooling1D, Conv1D, MaxPool1D, GlobalMaxPool1D, Dense, AveragePooling1D, GlobalAveragePooling1D
# Out:
# WARNING:tensorflow:From D:\Users\mata2\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt
# %matplotlib tk

# %%
import os, os.path, sys

# %%
path = r"C:\Users\mata2\Desktop\master\podaci\0k\X"

# %%
dir = os.listdir(path)

# %% [markdown]
# Ucitavanje fajlova

# %%
file_names = []
for file in dir:
    file_names.append(file)

# %%
percent_train = 0.8

# %%
percent_val = 0.2

# %% [markdown]
# Konkatenacija podataka koji se posle koriste za adekvatnu raspodelu na skup za treniranje i validaciju

# %%
train_files_names = file_names[:int(percent_train*len(file_names))]
#test_file_names = file_names[int(percent_train*len(file_names))::]

# %% [markdown]
# Ucitavanje zadate trajektorije

# %%
x_command = np.asarray(pd.read_csv(r"C:\Users\mata2\Desktop\master\podaci\xCmd.txt",header=None).astype('int'))

# %%
train_ = np.concatenate([pd.read_csv(path + "/" + file, header=None)[:61000].astype('int')
                              for file in train_files_names], axis=0)
# test_ = np.concatenate([pd.read_csv(path + "/" + file, header=None)[:61000].astype('int')
#                               for file in test_file_names], axis=0)

# %% [markdown]
# Ucitavanje stadardnih devijacija i strednih vrednosti

# %%
std_dev = []
with open(r"C:\Users\mata2\Desktop\master\Axis-projection-RNN\odstupanja\0k\std_dev.txt", 'r') as lines:
    for line in lines:
        std_dev.append(float(line.strip('\n')))

# %%
sr_vrednost = []
with open(r"C:\Users\mata2\Desktop\master\Axis-projection-RNN\odstupanja\0k\sr_vrednost.txt", 'r') as lines:
    for line in lines:
        sr_vrednost.append(float(line.strip('\n')))

# %% [markdown]
# Raspodela podataka kako bi se izbegla fiktivna stanja

# %%
for j in range(len(train_files_names)):
    exec(f"razlika_trening_{j} = []")
    for i in range(len(x_command)):
        exec(f"razlika_trening_{j}.append(x_command[i] - train_[j*len(x_command)+i])")
    exec(f'razlika_trening_{j} = np.asarray(razlika_trening_{j})')

# %%
def create_timeseries_split(data, time_steps):

    # Get the number of samples in the data
    num_samples = len(data) - time_steps

    # Create empty arrays to store features and target values
    x_train = np.zeros((num_samples, time_steps, 1))
    y_train = np.zeros((num_samples, 1))

    # Loop through the data and create features and target values
    for i in range(num_samples):
        # Extract a slice of data for the current feature
        x_train[i] = data[i:i+time_steps, :]

        # The target value is the next value after the feature
        y_train[i] = data[i+time_steps, 0]

    return x_train, y_train

# %%
time_steps = 10
input_shape = (time_steps,1)

# %%
for i in range(len(train_files_names)):
    exec(f'train_X_{i}, train_y_{i} = create_timeseries_split(razlika_trening_{i}, time_steps)')
    
train_X = np.asarray(train_X_0)
for i in range(1,len(train_files_names)):
    exec(f'train_X = np.append(train_X, train_X_{i}, axis=0)')

train_y = np.asarray(train_y_0)
for i in range(1,len(train_files_names)):
    exec(f'train_y = np.append(train_y, train_y_{i}, axis=0)')

# %%
val_x = train_X[-int(len(train_X)*percent_val)-1:-1]
val_y = train_y[-int(len(train_X)*percent_val)-1:-1]

# %%
train_X = train_X[:len(train_X)-val_x.shape[0]]
train_y = train_y[:len(train_y)-val_x.shape[0]]

# %% [markdown]
# # TESTIRANJE ARHITEKTURE i LR/BATCH

# %%
keras.utils.set_random_seed(7)
optimizerMSE = keras.optimizers.Adam(learning_rate=0.0001)

modelMSE = Sequential()
modelMSE.add(Input(shape=(time_steps, 1)))
modelMSE.add(Conv1D(filters=16, kernel_size=3,padding='same', activation=LeakyReLU()))
#modelMSE.add(Conv1D(filters=32, kernel_size=2, activation=LeakyReLU()))
modelMSE.add(MaxPooling1D(pool_size=4))
#modelMSE.add(Conv1D(filters=16, kernel_size=3,padding='same', activation=LeakyReLU()))
#modelMSE.add(Conv1D(filters=64, kernel_size=2, activation=LeakyReLU()))
#modelMSE.add(GlobalAveragePooling1D())
modelMSE.add(Flatten())
modelMSE.add(Dense(16, activation=LeakyReLU()))
modelMSE.add(Dense(units = 1, activation=LeakyReLU()))
modelMSE.compile(loss='mean_squared_error', optimizer = optimizerMSE)

# %%
historyMSE = modelMSE.fit(train_X, train_y, epochs=10, batch_size = 256, shuffle=False, verbose = 2)
# Out:
# Epoch 1/10
# 4575/4575 - 11s - loss: 10.1714 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 5.4622 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.2103 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 3.5674 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.2536 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.0755 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 2.9574 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 2.8676 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 2.7955 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.7340 - 9s/epoch - 2ms/step

# %%
modelMSE.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 10, 16)            64
#
#  max_pooling1d_1 (MaxPoolin  (None, 3, 16)             0
#  g1D)
#
#  flatten_1 (Flatten)         (None, 48)                0
#
#  dense_2 (Dense)             (None, 32)                1568
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1665 (6.50 KB)
# Trainable params: 1665 (6.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
test_predict_MSE = modelMSE.predict(val_x)
# Out:
# 9149/9149 [==============================] - 10s 1ms/step

# %%
i =(len(x_command)-time_steps) - val_x.shape[0]%(len(x_command)-time_steps) -1
mean_3std = 0
for j in range(len(test_predict_MSE)):
    if i%len(x_command) == 0:
        i = time_steps
    if sr_vrednost[i] - 3*std_dev[i] <= test_predict_MSE[j] <= sr_vrednost[i] + 3*std_dev[i]:
            mean_3std += 1
    i += 1
mean_3std/len(test_predict_MSE)
# Out:
# 0.976591107831885

# %% [raw]
# 0.9759728370771165

# %% [markdown]
# radjeno u vise iteracija sa razlicitim vrednostima zbog vremenske kompleksnosti

# %% [raw]
# modelMSE = Sequential()
# modelMSE.add(Input(shape=input_shape))
# modelMSE.add(Conv1D(filters=filt, kernel_size=kernel_1,padding='same', activation=LeakyReLU()))
# modelMSE.add(MaxPooling1D(pool_size=pool))
# modelMSE.add(Flatten())
# modelMSE.add(Dense(out, activation=LeakyReLU()))
# modelMSE.add(Dense(units = 1, activation=LeakyReLU()))
# modelMSE.compile(loss='mean_squared_error', optimizer = optimizerMSE)

# %%
filter_size = [16,32]
kernel_size_1 = [3,4]
kernel_size_2 = [3,4]
pooling_size = [3,4]
output_dens = [16,32]
batch_size = [256]
time_steps_list = [8,10]

# %%
best_skor = float('-inf')
best_filter = None
best_kernel_1 = None
best_kernel_2 = None
best_pool = None
best_batch = None
best_out = None
#best_pool_type = None
#best_global_pool_type = None
best_step = None
for step in time_steps_list:
    
    #delimo podatke na osnovu velicine buffera
    input_shape = (step,1)

    for i in range(len(train_files_names)):
        exec(f'train_X_{i}, train_y_{i} = create_timeseries_split(razlika_trening_{i}, step)')

    train_X = np.asarray(train_X_0)
    for i in range(1,len(train_files_names)):
        exec(f'train_X = np.append(train_X, train_X_{i}, axis=0)')

    train_y = np.asarray(train_y_0)
    for i in range(1,len(train_files_names)):
        exec(f'train_y = np.append(train_y, train_y_{i}, axis=0)')  
    
    #uzimamo percent_val sa kraja train_X skupa 
    val_x = train_X[-int(len(train_X)*percent_val)-1:-1]
    val_y = train_y[-int(len(train_X)*percent_val)-1:-1]

    train_X = train_X[:len(train_X)-val_x.shape[0]]
    train_y = train_y[:len(train_y)-val_x.shape[0]]
    
    for batch in batch_size:        
        for filt in filter_size:
            for kernel_1 in kernel_size_1:
                for kernel_2 in kernel_size_2:
                    for pool in pooling_size:
                        for out in output_dens:
                            keras.utils.set_random_seed(7)
                            optimizerMSE = keras.optimizers.Adam(learning_rate=0.0001)

                            modelMSE = Sequential()
                            modelMSE.add(Input(shape=input_shape))
                            modelMSE.add(Conv1D(filters=filt, kernel_size=kernel_1,padding='same', activation=LeakyReLU()))
                            #modelMSE.add(Conv1D(filters=32, kernel_size=2, activation=LeakyReLU()))
                            modelMSE.add(MaxPooling1D(pool_size=pool))
                            #modelMSE.add(Conv1D(filters=filt, kernel_size=kernel_2,padding='same', activation=LeakyReLU()))
                            #modelMSE.add(Conv1D(filters=64, kernel_size=2, activation=LeakyReLU()))
                            modelMSE.add(Flatten())
                            modelMSE.add(Dense(out, activation=LeakyReLU()))
                            modelMSE.add(Dense(units = 1, activation=LeakyReLU()))
                            modelMSE.compile(loss='mean_squared_error', optimizer = optimizerMSE)

                            modelMSE.fit(train_X, train_y, epochs = 10, batch_size = batch, verbose = 2, shuffle = False)
                            test_predict_MSE = modelMSE.predict(val_x)



                            #zato sto smo uzeli 20% od kraja, ne pocinje indeks od samog pocetka rada masine
                            #radimo evaluaciju na mean 3 sigma testu
                            i =(len(x_command)-step) - val_x.shape[0]%(len(x_command)-step) -1
                            mean_3std = 0
                            for j in range(len(test_predict_MSE)):
                                if i%len(x_command) == 0:
                                    i = step
                                if sr_vrednost[i] - 3*std_dev[i] <= test_predict_MSE[j] <= sr_vrednost[i] + 3*std_dev[i]:
                                        mean_3std += 1
                                i += 1



                            if mean_3std > best_skor:
                                best_skor = mean_3std
                                best_filter = filt
                                best_kernel_1 = kernel_1
                                best_kernel_2 = kernel_2
                                best_pool = pool
                                best_batch = batch
                                best_out = out
                                best_step = step
                                
                                
                                print('best_skor: ', best_skor)
                                print('best_filter: ', best_filter)
                                print('best_kernel_1: ', best_kernel_1)
                                print('best_kernel_2: ', best_kernel_2)
                                print('best_out: ', best_out )
                                print('best_batch', best_batch)
                                print('best_step', best_step)
                                print('best_pool', best_pool)
                                    
print('best_skor: ', best_skor)
print('best_filter: ', best_filter)
print('best_kernel_1: ', best_kernel_1)
print('best_kernel_2: ', best_kernel_2)
print('best_out: ', best_out )
print('best_batch', best_batch)
print('best_step', best_step)
print('best_pool', best_pool)
# Out:
# WARNING:tensorflow:From D:\Users\mata2\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\Users\mata2\anaconda3\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Epoch 1/10
# WARNING:tensorflow:From D:\Users\mata2\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 4575/4575 - 10s - loss: 14.7684 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 8s - loss: 10.4062 - 8s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 8s - loss: 9.4744 - 8s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 8s - loss: 8.9162 - 8s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 8s - loss: 8.5441 - 8s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 8s - loss: 8.2498 - 8s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 8s - loss: 8.0307 - 8s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 8s - loss: 7.8579 - 8s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 8s - loss: 7.7155 - 8s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 8s - loss: 7.5952 - 8s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# best_skor:  284242
# best_filter:  16
# best_kernel_1:  3
# best_kernel_2:  3
# best_out:  16
# best_batch 256
# best_step 8
# best_pool 3
# Epoch 1/10
# 4575/4575 - 10s - loss: 14.5834 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 8s - loss: 9.7455 - 8s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 8s - loss: 8.7313 - 8s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 8s - loss: 8.3074 - 8s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 8s - loss: 8.0064 - 8s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 8s - loss: 7.7729 - 8s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 8s - loss: 7.5754 - 8s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 8s - loss: 7.3987 - 8s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 8s - loss: 7.2362 - 8s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 8s - loss: 7.0918 - 8s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 13.0583 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 8s - loss: 6.9127 - 8s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 8s - loss: 5.7644 - 8s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 8s - loss: 5.1325 - 8s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 8s - loss: 4.5556 - 8s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 8s - loss: 4.0223 - 8s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.7081 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 8s - loss: 3.5406 - 8s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 8s - loss: 3.4331 - 8s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 8s - loss: 3.3520 - 8s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 11.5393 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 6.1936 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.9116 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 4.0786 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.6269 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.3816 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.2209 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.1018 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 3.0072 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.9267 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 14.7684 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 10.4062 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 9.4744 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 8.9162 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 8.5441 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 8.2498 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 8.0307 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 7.8579 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 7.7155 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 7.5952 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 14.5834 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 9.7455 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 8.7313 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 8.3074 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 8.0064 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 7.7729 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 7.5754 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 7.3987 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 7.2362 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 7.0918 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 13.0583 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 6.9127 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 5.7644 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 5.1325 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 4.5556 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 4.0223 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.7081 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.5406 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 3.4331 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 3.3520 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 11.5393 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 6.1936 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.9116 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 4.0786 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.6269 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.3816 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.2209 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.1018 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 3.0072 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.9267 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 12.1754 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 5.8709 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.6317 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 4.0637 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.7149 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.4903 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.3200 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.1773 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 3.0614 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.9683 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 12.4197 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 5.5903 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.4070 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 3.8592 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.5458 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.3240 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.1411 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 2.9920 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 2.8746 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.7859 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 12.4596 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 5.4429 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.5238 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 4.1381 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.8659 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.6538 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.4854 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.3565 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 3.2511 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 3.1645 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 11.3737 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 5.2885 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.4112 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 3.9459 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.6161 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.3898 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.2378 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.1253 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 3.0330 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.9550 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 12.1754 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 5.8709 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.6317 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 4.0637 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.7149 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.4903 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.3200 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.1773 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 3.0614 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.9683 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 12.4197 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 5.5903 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.4070 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 3.8592 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.5458 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.3240 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.1411 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 2.9920 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 2.8746 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.7859 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 12.4596 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 5.4429 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.5238 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 4.1381 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.8659 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.6538 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.4854 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.3565 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 3.2511 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 3.1645 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 11.3737 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 5.2885 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.4112 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 3.9459 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.6161 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.3898 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.2378 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.1253 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 3.0330 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.9550 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 13.6689 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 9.2547 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 8.4410 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 8.0078 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 7.7109 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 7.5005 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 7.3238 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 7.1903 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 7.0829 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 6.9906 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 14.3581 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 9.3688 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 8.6243 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 8.2055 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 7.8549 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 7.5739 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 7.3559 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 7.1896 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 7.0575 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 6.9426 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 11.7923 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 6.0067 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.6427 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 3.9231 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.5107 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.2745 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.1343 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.0365 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 2.9594 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.8949 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.2175 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.6180 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.0923 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.5448 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.3121 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 3.1714 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 3.0670 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.9828 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.9072 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.8381 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 13.6689 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 9.2547 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 8.4410 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 8.0078 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 7.7109 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 7.5005 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 7.3238 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 7.1903 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 7.0829 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 6.9906 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 14.3581 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 9.3688 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 8.6243 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 8.2055 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 7.8549 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 7.5739 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 7.3559 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 7.1896 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 7.0575 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 6.9426 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 11.7923 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 6.0067 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.6427 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.9231 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.5107 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 3.2745 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 3.1343 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 3.0365 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.9594 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.8949 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.2175 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.6180 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.0923 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.5448 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.3121 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 3.1714 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 3.0670 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.9828 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.9072 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.8381 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 11.3331 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.5391 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.0370 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.3584 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.0173 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.8061 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.6732 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.5834 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.5169 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.4616 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.1053 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.5543 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.0447 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.4107 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.1169 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.9166 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.7694 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.6575 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.5713 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.5036 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 10.8649 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.0016 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.1338 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 3.6292 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.2731 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.0438 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 2.8978 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 2.7932 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 2.7109 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.6455 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 11.3875 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 4.9958 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.9677 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.4289 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.1213 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.9437 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.8264 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.7408 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.6719 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.6128 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 11.3331 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 5.5391 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.0370 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 3.3584 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.0173 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 2.8061 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 2.6732 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 2.5834 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 2.5169 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.4616 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.1053 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.5543 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.0447 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.4107 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.1169 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.9166 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.7694 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.6575 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.5713 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.5036 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 10.8649 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 5.0016 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.1338 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 3.6292 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.2731 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.0438 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 2.8978 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 2.7932 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 2.7109 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.6455 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 11.3875 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 4.9958 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.9677 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.4289 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.1213 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.9437 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.8264 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.7408 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.6719 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.6128 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 11.8821 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 6.4830 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.9059 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 4.1961 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.7745 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.5011 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.2978 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.1487 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 3.0376 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.9512 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# best_skor:  286124
# best_filter:  16
# best_kernel_1:  3
# best_kernel_2:  3
# best_out:  16
# best_batch 256
# best_step 10
# best_pool 3
# Epoch 1/10
# 4575/4575 - 10s - loss: 10.1714 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 5.4622 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.2103 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 3.5674 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.2536 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.0755 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 2.9574 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 2.8676 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 2.7955 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.7340 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 14.2822 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 11.1589 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 10.2423 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 9.5063 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 9.0124 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 8.6932 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 8.4580 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 8.2858 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 8.1471 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 8.0218 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# best_skor:  288015
# best_filter:  16
# best_kernel_1:  3
# best_kernel_2:  3
# best_out:  16
# best_batch 256
# best_step 10
# best_pool 4
# Epoch 1/10
# 4575/4575 - 10s - loss: 14.2422 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 10.7384 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 9.5417 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 8.8822 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 8.4645 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 8.1975 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 8.0102 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 7.8572 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 7.7222 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 7.6009 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 11.8821 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 6.4830 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.9059 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 4.1961 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.7745 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.5011 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.2978 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.1487 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 3.0376 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.9512 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 10.1714 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 5.4622 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.2103 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 3.5674 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.2536 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.0755 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 2.9574 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 2.8676 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 2.7955 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.7340 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 14.2822 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 11.1589 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 10.2423 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 9.5063 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 9.0124 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 8.6932 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 8.4580 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 8.2858 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 8.1471 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 8.0218 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 14.2422 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 10.7384 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 9.5417 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 8.8822 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 8.4645 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 8.1975 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 8.0102 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 7.8572 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 7.7222 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 7.6009 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 12.0429 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 5.4295 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.4577 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 3.9634 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.6311 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.3879 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.2098 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.0727 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 2.9620 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.8642 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 9.7233 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 4.7855 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.1422 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.8089 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.5493 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 3.3318 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 3.1437 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 2.9787 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 2.8514 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.7490 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.9502 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 7.2553 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 5.6749 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 4.9729 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 4.5837 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 4.3220 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 4.0848 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.8664 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 3.6655 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 3.5132 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 13.2808 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 6.7997 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 5.4019 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 4.8541 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 4.5129 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 4.2352 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 3.9838 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 3.7436 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 3.5349 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.3607 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.0429 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.4295 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 11s - loss: 4.4577 - 11s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 3.9634 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.6311 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.3879 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 3.2098 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.0727 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 2.9620 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.8642 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 9.7233 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 4.7855 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 4.1422 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 3.8089 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 3.5493 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.3318 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.1437 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 2.9787 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 2.8514 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.7490 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 12s - loss: 12.9502 - 12s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 7.2553 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 5.6749 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 4.9729 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 4.5837 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 4.3220 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 4.0848 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.8664 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 3.6655 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 3.5132 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 10s - loss: 13.2808 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 6.7997 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 5.4019 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 4.8541 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 4.5129 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 4.2352 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.9838 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.7436 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 3.5349 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 3.3607 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 9.7333 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.0471 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.8769 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.3772 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.1075 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.9406 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.8345 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.7595 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.7017 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.6531 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 10.6713 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 4.8480 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.8717 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.4710 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.1485 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.9314 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.7873 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 11s - loss: 2.6825 - 11s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 12s - loss: 2.6021 - 12s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 12s - loss: 2.5410 - 12s/epoch - 3ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 13.7948 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 10.0261 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 8.9838 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 8.3850 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 8.0222 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 7.7731 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 7.5904 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 7.4501 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 7.3373 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 7.2420 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 14.1789 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 10.0590 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 9.0216 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 8.4029 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 8.0221 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 7.7556 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 7.5415 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 7.3657 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 7.2292 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 7.1121 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 9.7333 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.0471 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.8769 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.3772 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.1075 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.9406 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.8345 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.7595 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.7017 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.6531 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 10.6713 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 4.8480 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.8717 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.4710 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.1485 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.9314 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.7873 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.6825 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.6021 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.5410 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 13.7948 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 10.0261 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 8.9838 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 8.3850 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 8.0222 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 7.7731 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 7.5904 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 7.4501 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 7.3373 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 7.2420 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 14.1789 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 10.0590 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 9.0216 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 8.4029 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 8.0221 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 7.7556 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 7.5415 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 7.3657 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 7.2292 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 7.1121 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 9.1022 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 4.6847 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.8583 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.3945 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.0545 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.8121 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.6504 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.5452 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.4764 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.4271 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 9.3964 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 4.3934 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 11s - loss: 3.6852 - 11s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.3206 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.0401 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.8292 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.6816 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.5755 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.4951 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.4309 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.0520 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 6.5556 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 5.0578 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 4.4277 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 4.0385 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 3.7686 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 3.5609 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 3.3909 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 3.2527 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.1463 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.7534 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 6.6614 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.9185 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 4.2134 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.8120 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 3.5496 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 3.3498 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 3.1915 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 3.0606 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.9544 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 12s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 9.1022 - 11s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 4.6847 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.8583 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.3945 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 3.0545 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.8121 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.6504 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.5452 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.4764 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.4271 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 9.3964 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 11s - loss: 4.3934 - 11s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 11s - loss: 3.6852 - 11s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.3206 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 3.0401 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 11s - loss: 2.8292 - 11s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 11s - loss: 2.6816 - 11s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 11s - loss: 2.5755 - 11s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 2.4951 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 11s - loss: 2.4309 - 11s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.0520 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 6.5556 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 5.0578 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 4.4277 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 4.0385 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 3.7686 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 3.5609 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 3.3909 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 3.2527 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.1463 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.7534 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 6.6614 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.9185 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 4.2134 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.8120 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 3.5496 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 3.3498 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 3.1915 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 3.0606 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.9544 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# best_skor:  288015
# best_filter:  16
# best_kernel_1:  3
# best_kernel_2:  3
# best_out:  16
# best_batch 256
# best_step 10
# best_pool 4

# %% [raw]
# best_skor:  288015
# best_filter:  16
# best_kernel_1:  3
# best_kernel_2:  3
# best_out:  16
# best_batch 256
# best_step 10
# best_pool 4

# %%
time_steps = 10
input_shape = (time_steps,1)

# %%
for i in range(len(train_files_names)):
    exec(f'train_X_{i}, train_y_{i} = create_timeseries_split(razlika_trening_{i}, time_steps)')
    
train_X = np.asarray(train_X_0)
for i in range(1,len(train_files_names)):
    exec(f'train_X = np.append(train_X, train_X_{i}, axis=0)')

train_y = np.asarray(train_y_0)
for i in range(1,len(train_files_names)):
    exec(f'train_y = np.append(train_y, train_y_{i}, axis=0)')

# %%
val_x = train_X[-int(len(train_X)*percent_val)-1:-1]
val_y = train_y[-int(len(train_X)*percent_val)-1:-1]

# %%
train_X = train_X[:len(train_X)-val_x.shape[0]]
train_y = train_y[:len(train_y)-val_x.shape[0]]

# %%
filter_size = [16,32]
kernel_size_1 = [3,4]
kernel_size_2 = [3,4]
pooling_size = [3,4]
output_dens = [16,32]
#batch_size = [256]
#time_steps_list = [8,10]

# %% [raw]
# modelMSE = Sequential()
# modelMSE.add(Input(shape=input_shape))
# modelMSE.add(Conv1D(filters=filt, kernel_size=kernel_1,padding='same', activation=LeakyReLU()))
# modelMSE.add(MaxPooling1D(pool_size=pool))
# modelMSE.add(Conv1D(filters=filt, kernel_size=kernel_2,padding='same', activation=LeakyReLU()))
# modelMSE.add(Flatten())
# modelMSE.add(Dense(out, activation=LeakyReLU()))
# modelMSE.add(Dense(units = 1, activation=LeakyReLU()))

# %%
best_skor = float('-inf')
best_filter = None
best_kernel_1 = None
best_kernel_2 = None
best_pool = None
#best_batch = None
best_out = None
#best_pool_type = None
#best_global_pool_type = None
#best_step = None
loop = 0

for filt in filter_size:
    for kernel_1 in kernel_size_1:
        for kernel_2 in kernel_size_2:
            for pool in pooling_size:
                for out in output_dens:
                    keras.utils.set_random_seed(7)
                    optimizerMSE = keras.optimizers.Adam(learning_rate=0.0001)
                    loop += 1

                    modelMSE = Sequential()
                    modelMSE.add(Input(shape=input_shape))
                    modelMSE.add(Conv1D(filters=filt, kernel_size=kernel_1,padding='same', activation=LeakyReLU()))
                    #modelMSE.add(Conv1D(filters=32, kernel_size=2, activation=LeakyReLU()))
                    modelMSE.add(MaxPooling1D(pool_size=pool))
                    modelMSE.add(Conv1D(filters=filt, kernel_size=kernel_2,padding='same', activation=LeakyReLU()))
                    #modelMSE.add(MaxPooling1D(pool_size=pool))
                    modelMSE.add(Flatten())
                    modelMSE.add(Dense(out, activation=LeakyReLU()))
                    modelMSE.add(Dense(units = 1, activation=LeakyReLU()))
                    modelMSE.compile(loss='mean_squared_error', optimizer = optimizerMSE)

                    modelMSE.fit(train_X, train_y, epochs = 10, batch_size = 256, verbose = 2, shuffle = False)
                    test_predict_MSE = modelMSE.predict(val_x)



                    #zato sto smo uzeli 20% od kraja, ne pocinje indeks od samog pocetka rada masine
                    #radimo evaluaciju na mean 3 sigma testu
                    i =(len(x_command)-time_steps) - val_x.shape[0]%(len(x_command)-time_steps) -1
                    mean_3std = 0
                    for j in range(len(test_predict_MSE)):
                        if i%len(x_command) == 0:
                            i = time_steps
                        if sr_vrednost[i] - 3*std_dev[i] <= test_predict_MSE[j] <= sr_vrednost[i] + 3*std_dev[i]:
                                mean_3std += 1
                        i += 1



                    if mean_3std > best_skor:
                        best_skor = mean_3std
                        best_filter = filt
                        best_kernel_1 = kernel_1
                        best_kernel_2 = kernel_2
                        best_pool = pool
                        #best_batch = batch
                        best_out = out
                        #best_step = step


                        print('best_skor: ', best_skor)
                        print('best_filter: ', best_filter)
                        print('best_kernel_1: ', best_kernel_1)
                        print('best_kernel_2: ', best_kernel_2)
                        print('best_out: ', best_out )
                        #print('best_batch', best_batch)
                        #print('best_step', best_step)
                        print('best_pool', best_pool)

                    print('loop: ', loop)
                                    
print('best_skor: ', best_skor)
print('best_filter: ', best_filter)
print('best_kernel_1: ', best_kernel_1)
print('best_kernel_2: ', best_kernel_2)
print('best_out: ', best_out )
#print('best_batch', best_batch)
#print('best_step', best_step)
print('best_pool', best_pool)
# Out:
# Epoch 1/10
# 4575/4575 - 11s - loss: 10.2374 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 4.4149 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 3.3420 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 2.9106 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 2.6952 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 2.5729 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 2.4918 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 2.4324 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 2.3844 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.3449 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# best_skor:  285787
# best_filter:  16
# best_kernel_1:  3
# best_kernel_2:  3
# best_out:  16
# best_pool 3
# loop:  1
# Epoch 1/10
# 4575/4575 - 11s - loss: 10.1322 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 4.4814 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 3.4670 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 2.9626 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 2.7665 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.6493 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.5580 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.4812 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 2.4150 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.3603 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# loop:  2
# Epoch 1/10
# 4575/4575 - 11s - loss: 14.1759 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 10.2067 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 8.9331 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 8.2892 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 7.8413 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 7.4740 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 7.1859 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 6.9704 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 9s - loss: 6.8032 - 9s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 6.6710 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# best_skor:  286990
# best_filter:  16
# best_kernel_1:  3
# best_kernel_2:  3
# best_out:  16
# best_pool 4
# loop:  3
# Epoch 1/10
# 4575/4575 - 10s - loss: 13.6300 - 10s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 9.3961 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 9s - loss: 8.2657 - 9s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 7.8175 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 9s - loss: 7.5437 - 9s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 7.3268 - 9s/epoch - 2ms/step
# Epoch 7/10

# %% [markdown]
# ## Trazenje jednostavnije arhitekture

# %%
filter_size_1 = [8,16]
filter_size_2 = [8,16]
kernel_size_1 = [3,4]
kernel_size_2 = [3,4]
pooling_size = [3,4]
time_steps_list = [8,10]

# %%
best_skor = float('-inf')
best_filter = None
best_filter_2 = None
best_kernel_1 = None
best_kernel_2 = None
best_pool = None
best_batch = None
best_step = None
loop = 0
for step in time_steps_list:
    
    #delimo podatke na osnovu velicine buffera
    input_shape = (step,1)

    for i in range(len(train_files_names)):
        exec(f'train_X_{i}, train_y_{i} = create_timeseries_split(razlika_trening_{i}, step)')

    train_X = np.asarray(train_X_0)
    for i in range(1,len(train_files_names)):
        exec(f'train_X = np.append(train_X, train_X_{i}, axis=0)')

    train_y = np.asarray(train_y_0)
    for i in range(1,len(train_files_names)):
        exec(f'train_y = np.append(train_y, train_y_{i}, axis=0)')  
    
    #uzimamo percent_val sa kraja train_X skupa 
    val_x = train_X[-int(len(train_X)*percent_val)-1:-1]
    val_y = train_y[-int(len(train_X)*percent_val)-1:-1]

    train_X = train_X[:len(train_X)-val_x.shape[0]]
    train_y = train_y[:len(train_y)-val_x.shape[0]]
         
    for filt in filter_size_1:
        for filt_2 in filter_size_2:
            for kernel_1 in kernel_size_1:
                for kernel_2 in kernel_size_2:
                    for pool in pooling_size:
                        keras.utils.set_random_seed(7)
                        optimizerMSE = keras.optimizers.Adam(learning_rate=0.0001)

                        modelMSE = Sequential()
                        modelMSE.add(Input(shape=input_shape))
                        modelMSE.add(Conv1D(filters=filt, kernel_size=kernel_1,padding='same', activation=LeakyReLU()))
                        #modelMSE.add(Conv1D(filters=32, kernel_size=2, activation=LeakyReLU()))
                        modelMSE.add(MaxPooling1D(pool_size=pool))
                        modelMSE.add(Conv1D(filters=filt_2, kernel_size=kernel_2,padding='same', activation=LeakyReLU()))
                        #modelMSE.add(Conv1D(filters=64, kernel_size=2, activation=LeakyReLU()))
                        #modelMSE.add(GlobalAveragePooling1D())
                        modelMSE.add(Flatten())
                        modelMSE.add(Dense(128, activation=LeakyReLU()))
                        modelMSE.add(Dense(units = 1, activation=LeakyReLU()))
                        modelMSE.compile(loss='mean_squared_error', optimizer = optimizerMSE)

                        modelMSE.fit(train_X, train_y, epochs = 10, batch_size = 256, verbose = 2, shuffle = False)
                        test_predict_MSE = modelMSE.predict(val_x)



                        #zato sto smo uzeli 20% od kraja, ne pocinje indeks od samog pocetka rada masine
                        #radimo evaluaciju na mean 3 sigma testu
                        i =(len(x_command)-step) - val_x.shape[0]%(len(x_command)-step) -1
                        mean_3std = 0
                        for j in range(len(test_predict_MSE)):
                            if i%len(x_command) == 0:
                                i = step
                            if sr_vrednost[i] - 3*std_dev[i] <= test_predict_MSE[j] <= sr_vrednost[i] + 3*std_dev[i]:
                                    mean_3std += 1
                            i += 1



                        if mean_3std > best_skor:
                            best_skor = mean_3std
                            best_filter = filt
                            best_filter_2 = filt_2
                            best_kernel_1 = kernel_1
                            best_kernel_2 = kernel_2
                            best_pool = pool
                            #best_batch = batch
                            #best_pool_type = ptype
                            best_step = step

                            print('best_skor: ', best_skor)
                            print('best_filter: ', best_filter)
                            print('best_filter_2', best_filter_2)
                            print('best_kernel_1: ', best_kernel_1)
                            print('best_kernel_2: ', best_kernel_2)
                            #print('best_batch', best_batch)
                            print('best_step', best_step)
                            print('best_pool', best_pool)
                            #print('best_pool_type', best_pool_type)
                        loop += 1
                        print('loop: ', loop)

print('best_skor: ', best_skor)
print('best_filter: ', best_filter)
print('best_filter_2', best_filter_2)
print('best_kernel_1: ', best_kernel_1)
print('best_kernel_2: ', best_kernel_2)
#print('best_batch', best_batch)
print('best_step', best_step)
print('best_pool', best_pool)
#print('best_pool_type', best_pool_type)
# Out:
# Epoch 1/10
# 4575/4575 - 13s - loss: 15.2717 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 11s - loss: 10.8702 - 11s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 11s - loss: 9.3954 - 11s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 11s - loss: 8.7825 - 11s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 11s - loss: 8.4047 - 11s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 11s - loss: 8.1291 - 11s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 7.9154 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 7.7396 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 12s - loss: 7.5897 - 12s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 7.4569 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  289640
# best_filter:  8
# best_filter_2 8
# best_kernel_1:  3
# best_kernel_2:  3
# best_step 8
# best_pool 3
# Epoch 1/10
# 4575/4575 - 16s - loss: 12.5667 - 16s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 7.3155 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 5.4274 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 4.6184 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 4.1312 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 3.8129 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 3.5946 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 3.4415 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 3.3258 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 3.2337 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 2ms/step
# Epoch 1/10
# 4575/4575 - 15s - loss: 15.4850 - 15s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 10.9271 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 9.3375 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 8.7032 - 16s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 20s - loss: 8.3341 - 20s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 21s - loss: 8.0764 - 21s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 20s - loss: 7.8783 - 20s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 19s - loss: 7.7160 - 19s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 7.5797 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 7.4610 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# best_skor:  289693
# best_filter:  8
# best_filter_2 8
# best_kernel_1:  3
# best_kernel_2:  4
# best_step 8
# best_pool 3
# Epoch 1/10
# 4575/4575 - 18s - loss: 12.8091 - 18s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 7.3629 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 5.3911 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 4.5526 - 16s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 16s - loss: 4.0696 - 16s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 3.7631 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 3.5537 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 3.4001 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 19s - loss: 3.2793 - 19s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 19s - loss: 3.1774 - 19s/epoch - 4ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 23s - loss: 12.9351 - 23s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 6.2362 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 16s - loss: 4.6446 - 16s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 3.9119 - 16s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 16s - loss: 3.5482 - 16s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 16s - loss: 3.3237 - 16s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 16s - loss: 3.1695 - 16s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 3.0543 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 2.9600 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 2.8771 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 19s 2ms/step
# Epoch 1/10
# 4575/4575 - 26s - loss: 12.2274 - 26s/epoch - 6ms/step
# Epoch 2/10
# 4575/4575 - 16s - loss: 6.0676 - 16s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 16s - loss: 4.6221 - 16s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 4.1174 - 16s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 16s - loss: 3.7857 - 16s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 16s - loss: 3.5628 - 16s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 16s - loss: 3.4189 - 16s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 16s - loss: 3.3179 - 16s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 17s - loss: 3.2375 - 17s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 17s - loss: 3.1680 - 17s/epoch - 4ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 4575/4575 - 18s - loss: 13.0856 - 18s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 16s - loss: 6.2800 - 16s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 4.6797 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 3.9295 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 3.5655 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 3.3589 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 3.2157 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 17s - loss: 3.0979 - 17s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 17s - loss: 2.9963 - 17s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 17s - loss: 2.9066 - 17s/epoch - 4ms/step
# 9149/9149 [==============================] - 12s 1ms/step
# Epoch 1/10
# 4575/4575 - 21s - loss: 12.4318 - 21s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 19s - loss: 6.1062 - 19s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 4.5609 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 4.0506 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 11s - loss: 3.7590 - 11s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 11s - loss: 3.5783 - 11s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 3.4472 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 3.3460 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 3.2653 - 11s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 12s - loss: 3.1997 - 12s/epoch - 3ms/step
# 9149/9149 [==============================] - 12s 1ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 15.4269 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 10.1456 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 9.1277 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 8.4517 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 7.9496 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 7.5565 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 7.2987 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 7.1202 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 12s - loss: 6.9803 - 12s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 12s - loss: 6.8664 - 12s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 22s - loss: 12.7984 - 22s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 6.3657 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.8448 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 4.2412 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.8518 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 3.5920 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 3.4080 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 3.2781 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 3.1846 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.1092 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 15.4388 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 10.0801 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 9.0909 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 8.4208 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 7.9228 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 7.5355 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 7.2594 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 7.0793 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 6.9432 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 6.8336 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.7741 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 9s - loss: 6.3102 - 9s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.8599 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 4.2313 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.8200 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 3.5410 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 9s - loss: 3.3548 - 9s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 9s - loss: 3.2253 - 9s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 3.1311 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 11s - loss: 3.0538 - 11s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 12s - loss: 12.2506 - 12s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.4542 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.3808 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.7024 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.2597 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 3.0012 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.8502 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.7463 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.6652 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.6008 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 11.9778 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.1715 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.9377 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.5410 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.3628 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 3.2569 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 3.1827 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 3.1246 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 3.0755 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.0330 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.2790 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.4198 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.3659 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 9s - loss: 3.6761 - 9s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.2196 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.9653 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.8257 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.7282 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.6532 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.5963 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.0007 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.1989 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.9517 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.5367 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.3644 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 3.2647 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 3.1948 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 3.1386 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 3.0890 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.0420 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 12s - loss: 15.1911 - 12s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 9.8246 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 8.6080 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 8.0359 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 7.6968 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 7.3926 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 7.1503 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 6.9617 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 6.8001 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 6.6645 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 12s - loss: 12.3963 - 12s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.4111 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.0155 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.3345 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.0610 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.9058 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.8053 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.7365 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.6856 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.6422 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 15.2568 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 9.7580 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 8.6187 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 8.0880 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 7.7815 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 7.5364 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 7.3193 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 7.1087 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 6.9247 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 6.7723 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.4677 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.3833 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 4.0446 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.3846 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.0833 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.9096 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.7913 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.7077 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.6488 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.6029 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 12s - loss: 12.6536 - 12s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.2123 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.9948 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.4740 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 11s - loss: 3.1773 - 11s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.9685 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.8127 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.6988 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.6131 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.5450 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.4599 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 4.8965 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.8141 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.3380 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.0642 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.8820 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.7604 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.6758 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.6156 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.5695 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.6329 - 11s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.1676 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.9765 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.4828 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.1908 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 2.9721 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.8071 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.6813 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 2.5849 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 9s - loss: 2.5086 - 9s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 12.4355 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 11s - loss: 4.8655 - 11s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.8341 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.3569 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 3.1079 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 9s - loss: 2.9393 - 9s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 2.8157 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 2.7269 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 2.6599 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.6072 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 10s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 14.4159 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 9.2971 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 8.1628 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 7.6178 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 7.2812 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 10s - loss: 7.0516 - 10s/epoch - 2ms/step
# Epoch 7/10
# 4575/4575 - 10s - loss: 6.8753 - 10s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 10s - loss: 6.7238 - 10s/epoch - 2ms/step
# Epoch 9/10
# 4575/4575 - 10s - loss: 6.5887 - 10s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 6.4669 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 11s - loss: 11.4699 - 11s/epoch - 2ms/step
# Epoch 2/10
# 4575/4575 - 10s - loss: 5.2271 - 10s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 10s - loss: 3.9004 - 10s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 10s - loss: 3.2459 - 10s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 10s - loss: 2.9179 - 10s/epoch - 2ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 2.7618 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 2.6729 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.6121 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 2.5674 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.5293 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 14.4968 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 9.3151 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 8.1670 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 11s - loss: 7.6250 - 11s/epoch - 2ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 7.2902 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 7.0549 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 6.8813 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 6.7313 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 6.5980 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 12s - loss: 6.4777 - 12s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 11.5260 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 5.1956 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 11s - loss: 3.8621 - 11s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 3.2029 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 2.8995 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 2.7572 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 2.6774 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.6217 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 2.5800 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.5441 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 10.0888 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 11s - loss: 4.2609 - 11s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 3.4973 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 3.1362 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 2.8766 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 2.6944 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 2.5660 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 2.4734 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 12s - loss: 2.4042 - 12s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.3539 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 10.4705 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 4.5735 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 3.8336 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 3.3844 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 3.1078 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 2.9186 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 2.7862 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.6846 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 2.6081 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 13s - loss: 2.5467 - 13s/epoch - 3ms/step
# 9149/9149 [==============================] - 12s 1ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 10.1814 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 4.3099 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 3.5435 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 3.1854 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 2.9315 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 2.7465 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 2.6120 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 2.5184 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 12s - loss: 2.4487 - 12s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 12s - loss: 2.3954 - 12s/epoch - 3ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 10.4941 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 4.5769 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 3.8066 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 3.3590 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 3.1024 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 2.9306 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 2.8007 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 2.7005 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 12s - loss: 2.6183 - 12s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 12s - loss: 2.5488 - 12s/epoch - 3ms/step
# 9149/9149 [==============================] - 11s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 13.7563 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 9.0385 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 5.7744 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 4.6695 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 4.2435 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 3.9592 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 3.7451 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 3.5948 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 3.4882 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.4005 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# best_skor:  291375
# best_filter:  8
# best_filter_2 8
# best_kernel_1:  3
# best_kernel_2:  3
# best_step 10
# best_pool 3
# Epoch 1/10
# 4575/4575 - 13s - loss: 14.3629 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 11.6837 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 10.4525 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 9.3585 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 8.7439 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 8.3689 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 8.0953 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 7.8866 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 7.7276 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 7.5936 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 13.4070 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 6.8789 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 4.7701 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 4.1704 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 3.8955 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 13s - loss: 3.7005 - 13s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 3.5406 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 3.4053 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 3.2888 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.1861 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 12s 1ms/step
# best_skor:  291396
# best_filter:  8
# best_filter_2 8
# best_kernel_1:  3
# best_kernel_2:  4
# best_step 10
# best_pool 3
# Epoch 1/10
# 4575/4575 - 13s - loss: 14.5144 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 11.6956 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 10.3600 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 9.2743 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 8.6851 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 8.3130 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 8.0563 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 7.8726 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 7.7313 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 7.6170 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 12s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 13.2833 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 6.9508 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 5.1519 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 4.5954 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 4.2807 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 4.0210 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 3.8016 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 3.6189 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 3.4713 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.3511 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 12s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 13.5449 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 7.7179 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 5.6928 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 5.0798 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 4.7260 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 4.5088 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 4.3449 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 4.2004 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 4.0632 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.9316 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 12s 1ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 12.6697 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 5.7539 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 4.4351 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 3.9981 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 3.7005 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 3.4733 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 3.3016 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 3.1785 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 3.0864 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.0123 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 13.6877 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 7.6742 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 5.6574 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 5.0679 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 4.7239 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 4.5077 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 11s - loss: 4.3468 - 11s/epoch - 2ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 4.2053 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 4.0722 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.9446 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 14.1953 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 7.9517 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 5.5297 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 4.8454 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 4.4799 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 4.2278 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 4.0265 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 3.8620 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 3.7244 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 11s - loss: 3.6059 - 11s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 14.7941 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 11.3539 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 9.8275 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 8.8689 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 8.3844 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 8.0831 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 7.8573 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 13s - loss: 7.6774 - 13s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 7.5289 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 11s - loss: 7.4031 - 11s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 12.8298 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 6.0676 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 4.7142 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 4.2380 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 3.9239 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 3.6984 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 11s - loss: 3.5278 - 11s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 3.3991 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 3.3022 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 11s - loss: 3.2265 - 11s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# best_skor:  291406
# best_filter:  8
# best_filter_2 16
# best_kernel_1:  3
# best_kernel_2:  4
# best_step 10
# best_pool 3
# Epoch 1/10
# 4575/4575 - 14s - loss: 14.8113 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 11s - loss: 11.3759 - 11s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 11s - loss: 10.0102 - 11s/epoch - 2ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 9.0207 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 8.4828 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 11s - loss: 8.1213 - 11s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 7.8710 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 7.6829 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 7.5249 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 7.3851 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 13s - loss: 13.3616 - 13s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 11s - loss: 6.4333 - 11s/epoch - 2ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 4.9749 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 4.4118 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 13s - loss: 4.0904 - 13s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 3.8342 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 3.6323 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 3.4791 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 12s - loss: 3.3596 - 12s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 11s - loss: 3.2590 - 11s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 13.3040 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 6.5343 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 5.0576 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 12s - loss: 4.4888 - 12s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 4.0991 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 3.8182 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 12s - loss: 3.6170 - 12s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 3.4610 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 3.3320 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 3.2250 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# best_skor:  291497
# best_filter:  8
# best_filter_2 16
# best_kernel_1:  4
# best_kernel_2:  3
# best_step 10
# best_pool 4
# Epoch 1/10
# 4575/4575 - 14s - loss: 11.7866 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 12s - loss: 5.2302 - 12s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 12s - loss: 4.2934 - 12s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 13s - loss: 3.8475 - 13s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 12s - loss: 3.5200 - 12s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 12s - loss: 3.2681 - 12s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 13s - loss: 3.0976 - 13s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 12s - loss: 2.9774 - 12s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 11s - loss: 2.8815 - 11s/epoch - 2ms/step
# Epoch 10/10
# 4575/4575 - 10s - loss: 2.8017 - 10s/epoch - 2ms/step
# 9149/9149 [==============================] - 14s 2ms/step
# Epoch 1/10
# 4575/4575 - 15s - loss: 13.3457 - 15s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 13s - loss: 6.6008 - 13s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 13s - loss: 5.0855 - 13s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 4.4798 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 4.0703 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 3.7778 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 3.5462 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 3.3720 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 13s - loss: 3.2315 - 13s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 12s - loss: 3.1243 - 12s/epoch - 3ms/step
# 9149/9149 [==============================] - 12s 1ms/step
# best_skor:  291566
# best_filter:  8
# best_filter_2 16
# best_kernel_1:  4
# best_kernel_2:  4
# best_step 10
# best_pool 4
# Epoch 1/10
# 4575/4575 - 27s - loss: 14.0058 - 27s/epoch - 6ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 7.3077 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 4.8048 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 4.1801 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 3.8529 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 3.5364 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 3.2918 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 3.1255 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 3.0050 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.9173 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 1ms/step
# Epoch 1/10
# 4575/4575 - 17s - loss: 14.7606 - 17s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 10.5761 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 8.9992 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 15s - loss: 8.2216 - 15s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 7.8227 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 7.5412 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 7.3332 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 7.1692 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 7.0288 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 6.9084 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 15s - loss: 13.1242 - 15s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 5.3014 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 4.1573 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 3.6730 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 3.2724 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 2.9757 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 2.8120 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 2.7169 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 2.6515 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.6022 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  291576
# best_filter:  16
# best_filter_2 8
# best_kernel_1:  3
# best_kernel_2:  4
# best_step 10
# best_pool 3
# Epoch 1/10
# 4575/4575 - 14s - loss: 14.8178 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 10.5660 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 9.0129 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 8.2624 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 7.8709 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 7.5815 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 7.3623 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 7.1931 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 7.0499 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 6.9281 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 15s - loss: 13.0089 - 15s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 5.6201 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 4.1643 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 3.5597 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 3.2176 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 2.9902 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 2.8370 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 2.7306 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 2.6512 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.5881 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 18s - loss: 13.3287 - 18s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 6.1984 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 4.6530 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 4.0780 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 3.6873 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 3.4131 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 3.2218 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 3.0872 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 2.9804 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.8902 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  291603
# best_filter:  16
# best_filter_2 8
# best_kernel_1:  4
# best_kernel_2:  3
# best_step 10
# best_pool 4
# Epoch 1/10
# 4575/4575 - 15s - loss: 11.8467 - 15s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 4.7276 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 3.8421 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 15s - loss: 3.4190 - 15s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 3.1202 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 2.8689 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 2.6920 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 2.5669 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 2.4829 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.4234 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 14s - loss: 13.3196 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 6.2037 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 4.6414 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 4.0866 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 3.6975 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 3.4160 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 3.2178 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 3.0725 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 2.9560 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.8635 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  291655
# best_filter:  16
# best_filter_2 8
# best_kernel_1:  4
# best_kernel_2:  4
# best_step 10
# best_pool 4
# Epoch 1/10
# 4575/4575 - 15s - loss: 12.9658 - 15s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 6.1031 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 4.0454 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 3.4114 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 3.0985 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 2.9169 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 2.7938 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 2.6999 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 2.6289 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.5727 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  291680
# best_filter:  16
# best_filter_2 16
# best_kernel_1:  3
# best_kernel_2:  3
# best_step 10
# best_pool 3
# Epoch 1/10
# 4575/4575 - 14s - loss: 13.7498 - 14s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 9.9620 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 8.6574 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 8.1397 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 7.8522 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 7.6032 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 7.3463 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 7.1206 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 6.9641 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 6.8513 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 11.0948 - 16s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 4.6027 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 3.7717 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 3.2104 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 2.9269 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 2.7842 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 2.6890 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 2.6169 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 2.5562 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.5021 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 2ms/step
# Epoch 1/10
# 4575/4575 - 15s - loss: 13.8084 - 15s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 9.9391 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 8.6420 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 8.1346 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 7.8541 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 7.6186 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 7.3874 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 7.1576 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 6.9854 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 6.8679 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 11.1814 - 16s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 5.0829 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 4.2044 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 3.6197 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 3.2681 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 3.0449 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 14s - loss: 2.8868 - 14s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 2.7644 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 14s - loss: 2.6640 - 14s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.5797 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 1ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 11.0981 - 16s/epoch - 3ms/step
# Epoch 2/10
# 4575/4575 - 14s - loss: 5.2174 - 14s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 4.2405 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 3.8286 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 14s - loss: 3.5084 - 14s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 14s - loss: 3.2611 - 14s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 3.0804 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 2.9475 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 2.8424 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.7577 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 9.2861 - 16s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 4.3131 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 15s - loss: 3.7339 - 15s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 15s - loss: 3.3623 - 15s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 3.0936 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 2.8975 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 2.7572 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 15s - loss: 2.6454 - 15s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 2.5562 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 14s - loss: 2.4820 - 14s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 1ms/step
# Epoch 1/10
# 4575/4575 - 16s - loss: 11.1812 - 16s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 15s - loss: 5.2217 - 15s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 14s - loss: 4.2440 - 14s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 14s - loss: 3.8175 - 14s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 3.4936 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 3.2447 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 3.0582 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 14s - loss: 2.9164 - 14s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 2.8136 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 2.7319 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# best_skor:  291680
# best_filter:  16
# best_filter_2 16
# best_kernel_1:  3
# best_kernel_2:  3
# best_step 10
# best_pool 3

# %% [raw]
# best_skor:  291680
# best_filter:  16
# best_filter_2 16
# best_kernel_1:  3
# best_kernel_2:  3
# best_step 10
# best_pool 3
