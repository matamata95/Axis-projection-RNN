# %%
import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, SimpleRNN, RNN, LSTM, GRU, SpatialDropout1D, Dropout
# Out:
# WARNING:tensorflow:From D:\Users\mata2\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt
# %matplotlib tk

# %%
import os, os.path, sys

# %%
path = r"C:\Users\mata2\Desktop\master\podaci\0k\X"

# %%
dir = os.listdir(path)

# %% [markdown]
# Ucitavanje fajlova

# %%
file_names = []
for file in dir:
    file_names.append(file)

# %%
percent_train = 0.8

# %%
percent_val = 0.2

# %% [markdown]
# Konkatenacija podataka koji se posle koriste za adekvatnu raspodelu na skup za treniranje i validaciju

# %%
train_files_names = file_names[:int(percent_train*len(file_names))]
#test_file_names = file_names[int(percent_train*len(file_names))::]

# %% [markdown]
# Ucitavanje zadate trajektorije

# %%
x_command = np.asarray(pd.read_csv(r"C:\Users\mata2\Desktop\master\podaci\xCmd.txt",header=None).astype('int'))

# %%
train_ = np.concatenate([pd.read_csv(path + "/" + file, header=None)[:61000].astype('int')
                              for file in train_files_names], axis=0)
# test_ = np.concatenate([pd.read_csv(path + "/" + file, header=None)[:61000].astype('int')
#                               for file in test_file_names], axis=0)

# %% [markdown]
# Ucitavanje stadardnih devijacija i strednih vrednosti

# %%
std_dev = []
with open(r"C:\Users\mata2\Desktop\master\Axis-projection-RNN\odstupanja\0k\std_dev.txt", 'r') as lines:
    for line in lines:
        std_dev.append(float(line.strip('\n')))

# %%
sr_vrednost = []
with open(r"C:\Users\mata2\Desktop\master\Axis-projection-RNN\odstupanja\0k\sr_vrednost.txt", 'r') as lines:
    for line in lines:
        sr_vrednost.append(float(line.strip('\n')))

# %% [markdown]
# Raspodela podataka kako bi se izbegla fiktivna stanja

# %%
for j in range(len(train_files_names)):
    exec(f"koord_trening_{j} = []")
    exec(f"razlika_trening_{j} = []")

    for i in range(61000):
        exec(f"koord_trening_{j}.append(train_[j*61000+i])")
        exec(f"razlika_trening_{j}.append(x_command[i] - train_[j*61000+i])")
    exec(f'koord_trening_{j} = np.asarray(koord_trening_{j})') 
    exec(f'razlika_trening_{j} = np.asarray(razlika_trening_{j})')

# %%
def create_timeseries_split(data, time_steps):

  # Get the number of samples in the data
  num_samples = len(data) - time_steps

  # Create empty arrays to store features and target values
  x_train = np.zeros((num_samples, time_steps, 1))
  y_train = np.zeros((num_samples, 1))

  # Loop through the data and create features and target values
  for i in range(num_samples):
    # Extract a slice of data for the current feature
    x_train[i] = data[i:i+time_steps, :]

    # The target value is the next value after the feature
    y_train[i] = data[i+time_steps, 0]

  return x_train, y_train

# %%
min_kord = [float('inf') for x in range(61000)]
max_kord = [float('-inf') for x in range(61000)]

for i in range(61000):    
    for j in range(len(train_files_names)):
        exec(f'current_file = razlika_trening_{j}')
        if current_file[i][0] < min_kord[i]:
            min_kord[i] = current_file[i][0]
        if current_file[i][0] > max_kord[i]:
            max_kord[i] = current_file[i][0]

# %% [markdown]
# # TESTIRANJE ARHITEKTURE i LR/BATCH

# %% [markdown]
# radjeno u vise iteracija sa razlicitim vrednostima zbog vremenske kompleksnosti

# %%
gru_unit = [8,16]
unit1 = [8,16]
unit2 = [8,16]
batch_size = [128,256]
time_steps_list = [8,10]

# %%
best_skor = float('-inf')
best_gru = None
best_unit1 = None
best_unit2 = None
best_batch = None
best_step = None
for step in time_steps_list:
    
    #delimo podatke na osnovu velicine buffera
    input_shape = (step,1)

    for i in range(len(train_files_names)):
        exec(f'train_koord_X_{i}, _ = create_timeseries_split(koord_trening_{i}, step)')
        
    for i in range(len(train_files_names)):
        exec(f'_, train_y_{i} = create_timeseries_split(razlika_trening_{i}, step)')
    
    train_X = np.asarray(train_koord_X_0)
    for i in range(1,len(train_files_names)):
        exec(f'train_X = np.append(train_X, train_koord_X_{i}, axis=0)')

    train_y = np.asarray(train_y_0)
    for i in range(1,len(train_files_names)):
        exec(f'train_y = np.append(train_y, train_y_{i}, axis=0)')  
    
    #uzimamo percent_val sa kraja train_X skupa 
    val_x = train_X[-int(len(train_X)*percent_val)-1:-1]
    val_y = train_y[-int(len(train_X)*percent_val)-1:-1]

    train_X = train_X[:len(train_X)-val_x.shape[0]]
    train_y = train_y[:len(train_y)-val_x.shape[0]]
    
    for batch in batch_size:        
        for gru in gru_unit:
            for uni1 in unit1:
                for uni2 in unit2:

                    keras.utils.set_random_seed(7)
                    optimizerMSE = keras.optimizers.Adam(learning_rate=0.0001)

                    model = Sequential()
                    model.add(GRU(units = gru, input_shape = input_shape, activation = keras.layers.LeakyReLU()))
                    model.add(Dense(units = uni1, activation=keras.layers.LeakyReLU()))
                    model.add(Dense(units = uni2, activation=keras.layers.LeakyReLU()))
                    model.add(Dense(units = 1, activation=keras.layers.LeakyReLU(), bias_initializer='zeros', kernel_initializer='normal'))
                    model.compile(loss='mean_squared_error', optimizer = optimizerMSE)

                    model.fit(train_X, train_y, epochs = 10, batch_size = batch, verbose = 2, shuffle = False)
                    test_predict_MSE = model.predict(val_x)

                    
                    
                    #zato sto smo uzeli 20% od kraja, ne pocinje indeks od samog pocetka rada masine
                    #radimo evaluaciju na mean 3 sigma testu
                    i =(61000-step) - val_x.shape[0]%(61000-step) -1
                    mean_3std = 0
                    for j in range(len(test_predict_MSE)):
                        if i%61000 == 0:
                            i = step
                        if sr_vrednost[i] - 3*std_dev[i] <= test_predict_MSE[j] <= sr_vrednost[i] + 3*std_dev[i]:
                                mean_3std += 1
                        i += 1

                    
                    
                    if mean_3std > best_skor:
                        best_skor = mean_3std
                        best_gru = gru
                        best_unit1 = uni1
                        best_unit2 = uni2
                        best_step = step
                        best_batch = batch

                        print('best_skor: ', best_skor,'best_gru: ', best_gru,'best_unit1: ', best_unit1,'best_unit2: ', best_unit2, 'best_batch', best_batch, 'best_step', best_step)
print('best_skor: ', best_skor)                    
print('best_gru: ', best_gru)
print('best_unit1: ', best_unit1)
print('best_unit2: ', best_unit2)
print('best_batch: ', best_batch)
print('best_step: ', best_step)
# Out:
# Epoch 1/10
# 9149/9149 - 28s - loss: 170.9635 - 28s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 26s - loss: 48.2810 - 26s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 26s - loss: 47.6061 - 26s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 25s - loss: 209.5241 - 25s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 24s - loss: 47.1762 - 24s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 24s - loss: 46.5292 - 24s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 24s - loss: 127.4994 - 24s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 25s - loss: 48.0240 - 25s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 24s - loss: 47.9830 - 24s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 24s - loss: 41.1506 - 24s/epoch - 3ms/step
# 9149/9149 [==============================] - 12s 1ms/step
# best_skor:  278640 best_gru:  8 best_unit1:  8 best_unit2:  8 best_batch 128 best_step 8
# Epoch 1/10
# 9149/9149 - 26s - loss: 452.3971 - 26s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 24s - loss: 54.0700 - 24s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 24s - loss: 138.7952 - 24s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 24s - loss: 45.9564 - 24s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 24s - loss: 45.6274 - 24s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 24s - loss: 44.7028 - 24s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 29s - loss: 43.0419 - 29s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 29s - loss: 39.3359 - 29s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 26s - loss: 38.2307 - 26s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 27s - loss: 38.2777 - 27s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# best_skor:  280966 best_gru:  8 best_unit1:  8 best_unit2:  16 best_batch 128 best_step 8
# Epoch 1/10
# 9149/9149 - 61s - loss: 5130.1694 - 61s/epoch - 7ms/step
# Epoch 2/10
# 9149/9149 - 30s - loss: 44.5776 - 30s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 28s - loss: 40.0680 - 28s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 29s - loss: 39.0678 - 29s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 29s - loss: 37.2576 - 29s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 30s - loss: 37.0627 - 30s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 29s - loss: 37.7593 - 29s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 28s - loss: 37.1843 - 28s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 29s - loss: 37.0415 - 29s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 29s - loss: 37.1603 - 29s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 9149/9149 - 31s - loss: 61.4557 - 31s/epoch - 3ms/step
# Epoch 2/10
# 9149/9149 - 28s - loss: 55.4223 - 28s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 28s - loss: 54.3502 - 28s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 28s - loss: 50.6831 - 28s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 28s - loss: 47.3195 - 28s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 27s - loss: 45.9544 - 27s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 27s - loss: 46.0883 - 27s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 30s - loss: 45.7012 - 30s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 29s - loss: 44.9972 - 29s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 29s - loss: 44.7413 - 29s/epoch - 3ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# best_skor:  282009 best_gru:  8 best_unit1:  16 best_unit2:  16 best_batch 128 best_step 8
# Epoch 1/10
# 9149/9149 - 37s - loss: 157.0670 - 37s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 35s - loss: 75.7340 - 35s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 34s - loss: 48.3342 - 34s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 35s - loss: 47.6360 - 35s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 36s - loss: 49.0973 - 36s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 33s - loss: 56.4688 - 33s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 35s - loss: 47.3468 - 35s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 33s - loss: 43.3681 - 33s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 36s - loss: 38.3526 - 36s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 33s - loss: 39.9320 - 33s/epoch - 4ms/step
# 9149/9149 [==============================] - 14s 2ms/step
# Epoch 1/10
# 9149/9149 - 43s - loss: 68.1217 - 43s/epoch - 5ms/step
# Epoch 2/10
# 9149/9149 - 31s - loss: 47.2521 - 31s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 31s - loss: 45.8360 - 31s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 31s - loss: 44.5701 - 31s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 32s - loss: 42.5175 - 32s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 31s - loss: 114.2518 - 31s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 31s - loss: 40.4126 - 31s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 32s - loss: 37.9486 - 32s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 31s - loss: 37.9967 - 31s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 33s - loss: 36.7403 - 33s/epoch - 4ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 9149/9149 - 38s - loss: 54.6145 - 38s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 35s - loss: 55.8779 - 35s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 37s - loss: 48.2908 - 37s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 36s - loss: 47.3836 - 36s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 35s - loss: 45.4085 - 35s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 36s - loss: 41.2276 - 36s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 35s - loss: 39.7671 - 35s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 36s - loss: 40.1396 - 36s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 33s - loss: 38.0648 - 33s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 33s - loss: 37.2934 - 33s/epoch - 4ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 9149/9149 - 33s - loss: 69.4084 - 33s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 29s - loss: 72.1074 - 29s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 30s - loss: 49.6342 - 30s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 31s - loss: 65.0176 - 31s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 32s - loss: 56.0690 - 32s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 31s - loss: 51.9659 - 31s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 29s - loss: 50.6438 - 29s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 29s - loss: 49.4261 - 29s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 31s - loss: 214.0905 - 31s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 32s - loss: 47.4925 - 32s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 2ms/step
# Epoch 1/10
# 4575/4575 - 19s - loss: 671.8893 - 19s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 16s - loss: 59.3188 - 16s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 17s - loss: 87.9817 - 17s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 17s - loss: 50.1131 - 17s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 16s - loss: 50.4420 - 16s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 16s - loss: 49.3577 - 16s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 15s - loss: 49.1178 - 15s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 16s - loss: 48.8563 - 16s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 16s - loss: 48.8655 - 16s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 47.4831 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 26s - loss: 3390.7427 - 26s/epoch - 6ms/step
# Epoch 2/10
# 4575/4575 - 16s - loss: 65.8177 - 16s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 16s - loss: 65.3125 - 16s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 63.6953 - 16s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 16s - loss: 60.1426 - 16s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 16s - loss: 58.4907 - 16s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 16s - loss: 56.8080 - 16s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 16s - loss: 57.5733 - 16s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 15s - loss: 54.0880 - 15s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 15s - loss: 53.7704 - 15s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 19s - loss: 17637.0215 - 19s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 16s - loss: 43.5898 - 16s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 16s - loss: 44.9918 - 16s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 43.6343 - 16s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 15s - loss: 43.8939 - 15s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 42.8462 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 16s - loss: 41.4786 - 16s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 17s - loss: 39.4892 - 17s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 16s - loss: 37.9905 - 16s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 16s - loss: 37.4460 - 16s/epoch - 4ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 20s - loss: 77.8391 - 20s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 18s - loss: 74.4748 - 18s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 18s - loss: 71.6206 - 18s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 68.9703 - 16s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 18s - loss: 63.4957 - 18s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 18s - loss: 58.5226 - 18s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 17s - loss: 57.5096 - 17s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 17s - loss: 71.7046 - 17s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 16s - loss: 48.6494 - 16s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 17s - loss: 5865.5811 - 17s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 22s - loss: 455.9253 - 22s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 19s - loss: 54.3809 - 19s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 19s - loss: 811.2426 - 19s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 18s - loss: 60.3256 - 18s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 19s - loss: 70.1271 - 19s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 19s - loss: 65.6309 - 19s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 17s - loss: 59.8523 - 17s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 18s - loss: 49.9439 - 18s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 18s - loss: 57.3171 - 18s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 18s - loss: 53.9285 - 18s/epoch - 4ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 20s - loss: 262.9905 - 20s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 18s - loss: 57.8619 - 18s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 18s - loss: 48.3597 - 18s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 18s - loss: 45.5932 - 18s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 18s - loss: 42.4762 - 18s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 18s - loss: 45.2471 - 18s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 19s - loss: 392.4352 - 19s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 18s - loss: 39.1784 - 18s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 18s - loss: 50.4495 - 18s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 19s - loss: 50.7677 - 19s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 4575/4575 - 21s - loss: 69.2772 - 21s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 20s - loss: 104.4513 - 20s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 19s - loss: 53.4178 - 19s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 19s - loss: 53.7346 - 19s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 19s - loss: 70.5218 - 19s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 18s - loss: 48.9500 - 18s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 19s - loss: 49.4745 - 19s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 19s - loss: 46.1404 - 19s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 19s - loss: 43.5808 - 19s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 19s - loss: 43.0748 - 19s/epoch - 4ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 23s - loss: 122.2438 - 23s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 20s - loss: 373.3220 - 20s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 19s - loss: 55.3703 - 19s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 20s - loss: 71.8628 - 20s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 20s - loss: 203.5183 - 20s/epoch - 4ms/step
# Epoch 6/10
# 4575/4575 - 20s - loss: 51.9941 - 20s/epoch - 4ms/step
# Epoch 7/10
# 4575/4575 - 19s - loss: 65.5182 - 19s/epoch - 4ms/step
# Epoch 8/10
# 4575/4575 - 19s - loss: 70.6373 - 19s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 19s - loss: 66.7166 - 19s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 19s - loss: 56.5988 - 19s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 9149/9149 - 37s - loss: 313.3121 - 37s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 33s - loss: 47.5226 - 33s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 33s - loss: 46.8664 - 33s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 35s - loss: 52.9016 - 35s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 34s - loss: 53.0994 - 34s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 34s - loss: 47.5330 - 34s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 33s - loss: 46.7662 - 33s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 35s - loss: 111.9993 - 35s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 35s - loss: 47.1779 - 35s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 34s - loss: 40.5128 - 34s/epoch - 4ms/step
# 9149/9149 [==============================] - 17s 2ms/step
# Epoch 1/10
# 9149/9149 - 37s - loss: 451.5632 - 37s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 34s - loss: 50.5680 - 34s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 35s - loss: 53.3961 - 35s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 34s - loss: 50.8218 - 34s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 29s - loss: 50.0507 - 29s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 31s - loss: 279.5434 - 31s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 33s - loss: 47.7008 - 33s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 34s - loss: 48.3243 - 34s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 31s - loss: 46.7788 - 31s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 33s - loss: 42.4089 - 33s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 9149/9149 - 36s - loss: 5126.0825 - 36s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 32s - loss: 48.0124 - 32s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 32s - loss: 40.1661 - 32s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 29s - loss: 37.7589 - 29s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 28s - loss: 37.6843 - 28s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 28s - loss: 37.5953 - 28s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 28s - loss: 37.6071 - 28s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 30s - loss: 36.9612 - 30s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 33s - loss: 36.8282 - 33s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 32s - loss: 39.3945 - 32s/epoch - 3ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 9149/9149 - 34s - loss: 61.1405 - 34s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 31s - loss: 55.8715 - 31s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 31s - loss: 76.5160 - 31s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 31s - loss: 67.8665 - 31s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 32s - loss: 50.0166 - 32s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 31s - loss: 46.9446 - 31s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 31s - loss: 45.6786 - 31s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 30s - loss: 45.8029 - 30s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 29s - loss: 43.7354 - 29s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 29s - loss: 2715.4502 - 29s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 9149/9149 - 36s - loss: 116.1628 - 36s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 34s - loss: 76.9938 - 34s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 34s - loss: 47.3852 - 34s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 34s - loss: 59.3818 - 34s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 34s - loss: 50.3477 - 34s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 34s - loss: 47.2313 - 34s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 34s - loss: 51.6080 - 34s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 34s - loss: 42.2545 - 34s/epoch - 4ms/step
# Epoch 9/10
# 9149/9149 - 34s - loss: 40.3700 - 34s/epoch - 4ms/step
# Epoch 10/10
# 9149/9149 - 34s - loss: 40.2625 - 34s/epoch - 4ms/step
# 9149/9149 [==============================] - 15s 2ms/step
# Epoch 1/10
# 9149/9149 - 37s - loss: 59.4458 - 37s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 34s - loss: 45.4326 - 34s/epoch - 4ms/step
# Epoch 3/10
# 9149/9149 - 34s - loss: 48.4125 - 34s/epoch - 4ms/step
# Epoch 4/10
# 9149/9149 - 34s - loss: 44.7124 - 34s/epoch - 4ms/step
# Epoch 5/10
# 9149/9149 - 34s - loss: 42.1238 - 34s/epoch - 4ms/step
# Epoch 6/10
# 9149/9149 - 34s - loss: 41.1571 - 34s/epoch - 4ms/step
# Epoch 7/10
# 9149/9149 - 34s - loss: 38.8744 - 34s/epoch - 4ms/step
# Epoch 8/10
# 9149/9149 - 31s - loss: 37.1585 - 31s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 31s - loss: 36.1781 - 31s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 31s - loss: 35.5071 - 31s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 9149/9149 - 32s - loss: 55.1999 - 32s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 30s - loss: 49.4148 - 30s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 30s - loss: 49.7763 - 30s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 30s - loss: 47.2645 - 30s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 30s - loss: 47.1465 - 30s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 30s - loss: 45.4526 - 30s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 30s - loss: 40.9721 - 30s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 30s - loss: 40.0542 - 30s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 30s - loss: 38.6542 - 30s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 30s - loss: 37.7218 - 30s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 9149/9149 - 32s - loss: 457.6441 - 32s/epoch - 4ms/step
# Epoch 2/10
# 9149/9149 - 30s - loss: 52.7983 - 30s/epoch - 3ms/step
# Epoch 3/10
# 9149/9149 - 30s - loss: 54.1177 - 30s/epoch - 3ms/step
# Epoch 4/10
# 9149/9149 - 30s - loss: 49.7751 - 30s/epoch - 3ms/step
# Epoch 5/10
# 9149/9149 - 30s - loss: 48.8193 - 30s/epoch - 3ms/step
# Epoch 6/10
# 9149/9149 - 30s - loss: 47.3833 - 30s/epoch - 3ms/step
# Epoch 7/10
# 9149/9149 - 30s - loss: 48.3120 - 30s/epoch - 3ms/step
# Epoch 8/10
# 9149/9149 - 31s - loss: 48.2357 - 31s/epoch - 3ms/step
# Epoch 9/10
# 9149/9149 - 30s - loss: 46.9278 - 30s/epoch - 3ms/step
# Epoch 10/10
# 9149/9149 - 30s - loss: 44.4836 - 30s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 1ms/step
# Epoch 1/10
# 4575/4575 - 20s - loss: 775.0820 - 20s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 16s - loss: 45.7513 - 16s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 16s - loss: 48.4393 - 16s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 47.8370 - 16s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 16s - loss: 47.9908 - 16s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 16s - loss: 262.3976 - 16s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 16s - loss: 44.9564 - 16s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 16s - loss: 44.6528 - 16s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 16s - loss: 109.6812 - 16s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 16s - loss: 42.9897 - 16s/epoch - 3ms/step
# 9149/9149 [==============================] - 13s 1ms/step
# Epoch 1/10
# 4575/4575 - 19s - loss: 3389.9346 - 19s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 16s - loss: 61.6371 - 16s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 16s - loss: 62.5268 - 16s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 62.5680 - 16s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 16s - loss: 56.0754 - 16s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 16s - loss: 52.0183 - 16s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 16s - loss: 47.6313 - 16s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 16s - loss: 46.1655 - 16s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 16s - loss: 42.2120 - 16s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 16s - loss: 41.9590 - 16s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 1ms/step
# Epoch 1/10
# 4575/4575 - 18s - loss: 17653.3945 - 18s/epoch - 4ms/step
# Epoch 2/10
# 4575/4575 - 16s - loss: 43.8483 - 16s/epoch - 3ms/step
# Epoch 3/10
# 4575/4575 - 16s - loss: 43.5504 - 16s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 43.3371 - 16s/epoch - 3ms/step
# Epoch 5/10
# 4575/4575 - 16s - loss: 42.7588 - 16s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 16s - loss: 41.3747 - 16s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 16s - loss: 40.7895 - 16s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 16s - loss: 38.9645 - 16s/epoch - 3ms/step
# Epoch 9/10
# 4575/4575 - 16s - loss: 37.7044 - 16s/epoch - 3ms/step
# Epoch 10/10
# 4575/4575 - 16s - loss: 37.4416 - 16s/epoch - 3ms/step
# 9149/9149 [==============================] - 14s 1ms/step
# Epoch 1/10
# 4575/4575 - 22s - loss: 80.1122 - 22s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 16s - loss: 74.2142 - 16s/epoch - 4ms/step
# Epoch 3/10
# 4575/4575 - 16s - loss: 72.9721 - 16s/epoch - 3ms/step
# Epoch 4/10
# 4575/4575 - 16s - loss: 70.6952 - 16s/epoch - 4ms/step
# Epoch 5/10
# 4575/4575 - 16s - loss: 95.1628 - 16s/epoch - 3ms/step
# Epoch 6/10
# 4575/4575 - 15s - loss: 52.8177 - 15s/epoch - 3ms/step
# Epoch 7/10
# 4575/4575 - 16s - loss: 53.0500 - 16s/epoch - 3ms/step
# Epoch 8/10
# 4575/4575 - 19s - loss: 52.8136 - 19s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 18s - loss: 50.7150 - 18s/epoch - 4ms/step
# Epoch 10/10
# 4575/4575 - 17s - loss: 49.2284 - 17s/epoch - 4ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 32s - loss: 1217.5596 - 32s/epoch - 7ms/step
# Epoch 2/10
# 4575/4575 - 21s - loss: 90.3110 - 21s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 21s - loss: 54.5656 - 21s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 23s - loss: 53.3445 - 23s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 21s - loss: 50.5093 - 21s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 23s - loss: 49.0886 - 23s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 24s - loss: 48.9284 - 24s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 24s - loss: 44.3571 - 24s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 23s - loss: 50.4862 - 23s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 24s - loss: 41.3792 - 24s/epoch - 5ms/step
# 9149/9149 [==============================] - 20s 2ms/step
# best_skor:  282516 best_gru:  16 best_unit1:  8 best_unit2:  8 best_batch 256 best_step 10
# Epoch 1/10
# 4575/4575 - 26s - loss: 268.3036 - 26s/epoch - 6ms/step
# Epoch 2/10
# 4575/4575 - 23s - loss: 50.5699 - 23s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 23s - loss: 46.0970 - 23s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 22s - loss: 60.8667 - 22s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 21s - loss: 46.9464 - 21s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 23s - loss: 42.1734 - 23s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 21s - loss: 41.5270 - 21s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 21s - loss: 66.8224 - 21s/epoch - 4ms/step
# Epoch 9/10
# 4575/4575 - 23s - loss: 50.1346 - 23s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 23s - loss: 45.9159 - 23s/epoch - 5ms/step
# 9149/9149 [==============================] - 18s 2ms/step
# Epoch 1/10
# 4575/4575 - 44s - loss: 283.2124 - 44s/epoch - 10ms/step
# Epoch 2/10
# 4575/4575 - 22s - loss: 56.4127 - 22s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 21s - loss: 56.2405 - 21s/epoch - 5ms/step
# Epoch 4/10
# 4575/4575 - 21s - loss: 54.7367 - 21s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 21s - loss: 50.5316 - 21s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 22s - loss: 50.6019 - 22s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 22s - loss: 52.1436 - 22s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 22s - loss: 51.6105 - 22s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 22s - loss: 49.9587 - 22s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 21s - loss: 46.3442 - 21s/epoch - 5ms/step
# 9149/9149 [==============================] - 16s 2ms/step
# Epoch 1/10
# 4575/4575 - 24s - loss: 466.4594 - 24s/epoch - 5ms/step
# Epoch 2/10
# 4575/4575 - 21s - loss: 69.2488 - 21s/epoch - 5ms/step
# Epoch 3/10
# 4575/4575 - 21s - loss: 53.9298 - 21s/epoch - 4ms/step
# Epoch 4/10
# 4575/4575 - 22s - loss: 56.7208 - 22s/epoch - 5ms/step
# Epoch 5/10
# 4575/4575 - 22s - loss: 63.1445 - 22s/epoch - 5ms/step
# Epoch 6/10
# 4575/4575 - 22s - loss: 64.5909 - 22s/epoch - 5ms/step
# Epoch 7/10
# 4575/4575 - 22s - loss: 57.1816 - 22s/epoch - 5ms/step
# Epoch 8/10
# 4575/4575 - 22s - loss: 55.3117 - 22s/epoch - 5ms/step
# Epoch 9/10
# 4575/4575 - 22s - loss: 55.4816 - 22s/epoch - 5ms/step
# Epoch 10/10
# 4575/4575 - 22s - loss: 5698.6597 - 22s/epoch - 5ms/step
# 9149/9149 [==============================] - 18s 2ms/step
# best_skor:  282516
# best_gru:  16
# best_unit1:  8
# best_unit2:  8
# best_batch:  256
# best_step:  10

# %% [raw]
# best_skor:  282516
# best_gru:  16
# best_unit1:  8
# best_unit2:  8
# best_batch:  256
# best_step:  10

# %%
282516/len(test_predict_MSE)
# Out:
# 0.9650352516806033
